# %% [markdown]
# <a href="https://colab.research.google.com/github/Saputoa21/Introduction_Machine_Learning-Information_Retrieval/blob/main/Retrieval_System_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Retrieval System Project**: Agatha Christie's Books

# %% [markdown]
# ## 1. Downloading Texts

# %%
# !git clone https://github.com/Saputoa21/Machine-Learning.git
# !ls Machine-Learning
# Out:
# Cloning into 'Machine-Learning'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 133 (delta 78), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (133/133), 12.89 MiB | 4.81 MiB/s, done.
# Resolving deltas: 100% (78/78), done.
#  01_LM_NLP_python_basics_Anastasiya_SAPUTO.ipynb
#  02_Gender_Identification_with_Decision_Tree_Anastasiya_SAPUTO.ipynb
#  03_Probabelistic_Modeling_Naive_Bayes_Anastasiya_SAPUTO.ipynb
#  Agatha_Christie_Corpus.zip
#  Inverted_index_exercise.ipynb
# 'O4_LM_LDA_Topic_modelling_SAPUTO_2024 (1).ipynb'
#  Retrieval_System_Project.ipynb

# %%
import zipfile
import os

zip_path = "Machine-Learning/Agatha_Christie_Corpus.zip"
extract_path = "Machine-Learning/extracted_files"

# Create a directory to extract if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List extracted files
# !ls Machine-Learning/extracted_files
# Out:
# 'Poirot Investigates_pg61262.txt'
# 'The Big Four_pg70114.txt'
# "The Hunter's Lodge Case_pg67160.txt"
# 'The man in the Brown Suit_pg61168.txt'
# 'The Missing Will_pg67173.txt'
# 'The Murder of Roger Ackroyd_pg69087.txt'
# 'The Murder on the Links_pg58866.txt'
# 'The Mysterious Affair at Styles_pg863.txt'
# 'The Mystery of the Blue Train_pg72824.txt'
# 'The Plymouth Express Affair_pg66446.txt'
# 'The Secret Adversary_pg1155.txt'
# 'The Secret of Chimneys_pg65238.txt'
# 'The Seven Dials Mystery_pg75288.txt'

# %%
file_path = "Machine-Learning/extracted_files/Poirot Investigates_pg61262.txt"

with open(file_path, "r", encoding="utf-8") as file:
    content = file.read()
    print(content[:1000])
# Out:
# ﻿The Project Gutenberg eBook of Poirot Investigates
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Poirot Investigates
#
# Author: Agatha Christie
#
# Release date: January 28, 2020 [eBook #61262]
#                 Most recently updated: October 17, 2024
#
# Language: English
#
# Credits: Produced by an anonymous Project Gutenberg volunteer.
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK POIROT INVESTIGATES ***
#
#   POIROT INVESTIGATES
#
#
#
#
#   BY THE SAME AUTHOR
#
#   THE MYSTERIOUS AFFAIR AT STYLES
#
#   THE SECRET ADVERSARY
#
#   THE MURDER ON THE LINKS
#
#   THE BODLEY HEAD
#
#
#
#
#   POIROT INVESTIGATES
#
#   BY AGATHA CH

# %% [markdown]
# ## 2. Creating the Dataframe from Texts

# %%
import pandas as pd

# Lists to store filenames and text contents
filenames = []
texts = []

# Loop through all .txt files in the directory
for filename in os.listdir(extract_path):
  if filename.endswith(".txt"):
    division = filename.find("_")
    file_path = os.path.join(extract_path, filename[:])
    with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
            filenames.append(filename)
            texts.append(file.read())

# Create a DataFrame
df = pd.DataFrame({"book_title": filenames, "content": texts})

df.insert(0, 'book_id', range(0, len(df)))

# %%
print(df) #print the dataframe
# Out:
#     book_id                                 book_title  \
# 0         0      The man in the Brown Suit_pg61168.txt
# 1         1         The Secret of Chimneys_pg65238.txt
# 2         2            The Secret Adversary_pg1155.txt
# 3         3  The Mystery of the Blue Train_pg72824.txt
# 4         4    The Murder of Roger Ackroyd_pg69087.txt
# 5         5        The Seven Dials Mystery_pg75288.txt
# 6         6                   The Big Four_pg70114.txt
# 7         7               The Missing Will_pg67173.txt
# 8         8        The Hunter's Lodge Case_pg67160.txt
# 9         9  The Mysterious Affair at Styles_pg863.txt
# 10       10            Poirot Investigates_pg61262.txt
# 11       11        The Murder on the Links_pg58866.txt
# 12       12    The Plymouth Express Affair_pg66446.txt
#
#                                               content
# 0   ﻿The Project Gutenberg eBook of The Man in the...
# 1   ﻿The Project Gutenberg eBook of The Secret of ...
# 2   ﻿The Project Gutenberg eBook of The Secret Adv...
# 3   ﻿The Project Gutenberg eBook of The mystery of...
# 4   ﻿The Project Gutenberg eBook of The murder of ...
# 5   ﻿The Project Gutenberg eBook of The Seven Dial...
# 6   ﻿The Project Gutenberg eBook of The Big Four\n...
# 7   ﻿The Project Gutenberg eBook of The Missing Wi...
# 8   ﻿The Project Gutenberg eBook of The Hunter's L...
# 9   ﻿The Project Gutenberg eBook of The Mysterious...
# 10  ﻿The Project Gutenberg eBook of Poirot Investi...
# 11  ﻿The Project Gutenberg eBook of The Murder on ...
# 12  ﻿The Project Gutenberg eBook of The Plymouth E...

# %%
# Clean book title by removing the "_pgXXXXX.txt" part
df["book_title"] = df["book_title"].str.replace(r"_pg\d+\.txt$", "", regex=True)

# %%
print(df)
# Out:
#     book_id                       book_title  \
# 0         0        The man in the Brown Suit
# 1         1           The Secret of Chimneys
# 2         2             The Secret Adversary
# 3         3    The Mystery of the Blue Train
# 4         4      The Murder of Roger Ackroyd
# 5         5          The Seven Dials Mystery
# 6         6                     The Big Four
# 7         7                 The Missing Will
# 8         8          The Hunter's Lodge Case
# 9         9  The Mysterious Affair at Styles
# 10       10              Poirot Investigates
# 11       11          The Murder on the Links
# 12       12      The Plymouth Express Affair
#
#                                               content
# 0   ﻿The Project Gutenberg eBook of The Man in the...
# 1   ﻿The Project Gutenberg eBook of The Secret of ...
# 2   ﻿The Project Gutenberg eBook of The Secret Adv...
# 3   ﻿The Project Gutenberg eBook of The mystery of...
# 4   ﻿The Project Gutenberg eBook of The murder of ...
# 5   ﻿The Project Gutenberg eBook of The Seven Dial...
# 6   ﻿The Project Gutenberg eBook of The Big Four\n...
# 7   ﻿The Project Gutenberg eBook of The Missing Wi...
# 8   ﻿The Project Gutenberg eBook of The Hunter's L...
# 9   ﻿The Project Gutenberg eBook of The Mysterious...
# 10  ﻿The Project Gutenberg eBook of Poirot Investi...
# 11  ﻿The Project Gutenberg eBook of The Murder on ...
# 12  ﻿The Project Gutenberg eBook of The Plymouth E...

# %%
print(df['content'][0][:3000]) #printing the first book content
# Out:
# ﻿The Project Gutenberg eBook of The Man in the Brown Suit
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: The Man in the Brown Suit
#
# Author: Agatha Christie
#
# Release date: January 14, 2020 [eBook #61168]
#                 Most recently updated: October 17, 2024
#
# Language: English
#
# Credits: an anonymous Project Gutenberg volunteer
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK THE MAN IN THE BROWN SUIT ***
#
#   THE MAN IN THE BROWN SUIT
#
#
#
#
#   BY THE SAME AUTHOR
#
#   THE MYSTERIOUS AFFAIR AT STYLES
#
#   THE SECRET ADVERSARY
#
#   THE MURDER ON THE LINKS
#
#
#
#
#   THE MAN IN THE BROWN SUIT
#   by
#   AGATHA CHRISTIE
#
#   NEW YORK
#
#   DODD, MEAD AND COMPANY
#
#   1924
#
#
#
#
#
#   Copyright, 1924,
#   By DODD, MEAD AND COMPANY, Inc.
#
#   PRINTED IN THE U. S. A. BY
#   The Quinn & Boden Company
#   BOOK MANUFACTURERS
#   RAHWAY   NEW JERSEY
#
#
#
#
#   To E. A. B.
#
#   IN MEMORY OF A JOURNEY, SOME
#   LION STORIES AND A REQUEST THAT
#   I SHOULD SOME DAY WRITE THE
#   “MYSTERY OF THE MILL HOUSE”
#
#
#
#   THE MAN IN THE BROWN SUIT
#
#
#
#
#   THE MAN IN THE BROWN SUIT
#
#
#   PROLOGUE
#
#
# Nadina, the Russian dancer who had taken Paris by storm, swayed to
# the sound of the applause, bowed and bowed again. Her narrow black
# eyes narrowed themselves still more, the long line of her scarlet
# mouth curved faintly upwards. Enthusiastic Frenchmen continued to
# beat the ground appreciatively as the curtain fell with a swish,
# hiding the reds and blues and magentas of the bizarre _décors._ In
# a swirl of blue and orange draperies the dancer left the stage. A
# bearded gentleman received her enthusiastically in his arms. It
# was the Manager.
#
# “Magnificent, _petite,_ magnificent,” he cried. “To-night you have
# surpassed yourself.” He kissed her gallantly on both cheeks in a
# somewhat matter-of-fact manner.
#
# Madame Nadina accepted the tribute with the ease of long habit and
# passed on to her dressing-room, where bouquets were heaped
# carelessly everywhere, marvellous garments of futuristic design
# hung on pegs, and the air was hot and sweet with the scent of the
# massed blossoms and with more sophisticated perfumes and essences.
# Jeanne, the dresser, ministered to her mistress, talking incessantly
# and pouring out a stream of fulsome compliment.
#
# A knock at the door interrupted the flow. Jeanne went to answer
# it, and returned with a card in her hand.
#
# “Madame will receive?”
#
# “Let me see.”
#
# The dancer stretched out a languid hand, but at the sight of the
# name on the card, “Count Sergius Paulovitch,” a sudden flicker of
# interest came into her eyes.
#
# “I will see him. The maize _peignoir,_ Jeanne, and quickly. And
# when the Count comes you may go.”
#
# _“Bien, M

# %% [markdown]
# Problem with paragraphing - possible if not removing empty lines first

# %%
paragraphs = [p.strip() for p in book_1.split('\n\n') if p.strip()]

# Create DataFrame
df_par = pd.DataFrame(paragraphs, columns=["Paragraph"])

df_par.tail()
# Out:
#                                               Paragraph
# 2695  Section 5. General Information About Project G...
# 2696  Professor Michael S. Hart was the originator o...
# 2697  Project Gutenberg™ eBooks are often created fr...
# 2698  Most people start at our website which has the...
# 2699  This website includes information about Projec...

# %% [markdown]
# ## 3. Testing Cleaning and Splitting on One Book

# %%
book_1 = df['content'][0]

# %%
# Remove empty lines and join all lines into one
cleaned_book_1 = "\n".join([line.strip() for line in book_1.split("\n") if line.strip()])

print(cleaned_book_1[:2000])
# Out:
# ﻿The Project Gutenberg eBook of The Man in the Brown Suit
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
# Title: The Man in the Brown Suit
# Author: Agatha Christie
# Release date: January 14, 2020 [eBook #61168]
# Most recently updated: October 17, 2024
# Language: English
# Credits: an anonymous Project Gutenberg volunteer
# *** START OF THE PROJECT GUTENBERG EBOOK THE MAN IN THE BROWN SUIT ***
# THE MAN IN THE BROWN SUIT
# BY THE SAME AUTHOR
# THE MYSTERIOUS AFFAIR AT STYLES
# THE SECRET ADVERSARY
# THE MURDER ON THE LINKS
# THE MAN IN THE BROWN SUIT
# by
# AGATHA CHRISTIE
# NEW YORK
# DODD, MEAD AND COMPANY
# 1924
# Copyright, 1924,
# By DODD, MEAD AND COMPANY, Inc.
# PRINTED IN THE U. S. A. BY
# The Quinn & Boden Company
# BOOK MANUFACTURERS
# RAHWAY   NEW JERSEY
# To E. A. B.
# IN MEMORY OF A JOURNEY, SOME
# LION STORIES AND A REQUEST THAT
# I SHOULD SOME DAY WRITE THE
# “MYSTERY OF THE MILL HOUSE”
# THE MAN IN THE BROWN SUIT
# THE MAN IN THE BROWN SUIT
# PROLOGUE
# Nadina, the Russian dancer who had taken Paris by storm, swayed to
# the sound of the applause, bowed and bowed again. Her narrow black
# eyes narrowed themselves still more, the long line of her scarlet
# mouth curved faintly upwards. Enthusiastic Frenchmen continued to
# beat the ground appreciatively as the curtain fell with a swish,
# hiding the reds and blues and magentas of the bizarre _décors._ In
# a swirl of blue and orange draperies the dancer left the stage. A
# bearded gentleman received her enthusiastically in his arms. It
# was the Manager.
# “Magnificent, _petite,_ magnificent,” he cried. “To-night you have
# surpassed yourself.” He kissed her gallantly on both cheeks in a
# somew

# %%
paragraphs = [p.strip() for p in cleaned_book_1.split('\n\n') if p.strip()]

# Create DataFrame
df_par = pd.DataFrame(paragraphs, columns=["Paragraph"])

df_par.tail()
# Out:
#                                            Paragraph
# 0  ﻿The Project Gutenberg eBook of The Man in the...

# %% [markdown]
# ### Deleting Irrelevant Book Parts

# %%
import re

# Splitting lines and deleting metadata of the Guteberg's project
lines = cleaned_book_1.split("\n")
start_idx = 0
end_idx = 0

for i, line in enumerate(lines):
  if "*** START OF THE PROJECT GUTENBERG EBOOK" in line:
    start_idx = i + 1
  if "*** END OF THE PROJECT GUTENBERG EBOOK" in line:
    end_idx = i
    break

# %%
book_1_wo_metadata = "\n".join(lines[start_idx:end_idx])

print(book_1_wo_metadata[:1500])

lines = book_1_wo_metadata.split("\n")
# Out:
# THE MAN IN THE BROWN SUIT
# BY THE SAME AUTHOR
# THE MYSTERIOUS AFFAIR AT STYLES
# THE SECRET ADVERSARY
# THE MURDER ON THE LINKS
# THE MAN IN THE BROWN SUIT
# by
# AGATHA CHRISTIE
# NEW YORK
# DODD, MEAD AND COMPANY
# 1924
# Copyright, 1924,
# By DODD, MEAD AND COMPANY, Inc.
# PRINTED IN THE U. S. A. BY
# The Quinn & Boden Company
# BOOK MANUFACTURERS
# RAHWAY   NEW JERSEY
# To E. A. B.
# IN MEMORY OF A JOURNEY, SOME
# LION STORIES AND A REQUEST THAT
# I SHOULD SOME DAY WRITE THE
# “MYSTERY OF THE MILL HOUSE”
# THE MAN IN THE BROWN SUIT
# THE MAN IN THE BROWN SUIT
# PROLOGUE
# Nadina, the Russian dancer who had taken Paris by storm, swayed to
# the sound of the applause, bowed and bowed again. Her narrow black
# eyes narrowed themselves still more, the long line of her scarlet
# mouth curved faintly upwards. Enthusiastic Frenchmen continued to
# beat the ground appreciatively as the curtain fell with a swish,
# hiding the reds and blues and magentas of the bizarre _décors._ In
# a swirl of blue and orange draperies the dancer left the stage. A
# bearded gentleman received her enthusiastically in his arms. It
# was the Manager.
# “Magnificent, _petite,_ magnificent,” he cried. “To-night you have
# surpassed yourself.” He kissed her gallantly on both cheeks in a
# somewhat matter-of-fact manner.
# Madame Nadina accepted the tribute with the ease of long habit and
# passed on to her dressing-room, where bouquets were heaped
# carelessly everywhere, marvellous garments of futuristic design
# hung on pegs, and the air was hot and sweet with the scent of the

# %%
lines
# Out:
# ['THE MAN IN THE BROWN SUIT',
#  'BY THE SAME AUTHOR',
#  'THE MYSTERIOUS AFFAIR AT STYLES',
#  'THE SECRET ADVERSARY',
#  'THE MURDER ON THE LINKS',
#  'THE MAN IN THE BROWN SUIT',
#  'by',
#  'AGATHA CHRISTIE',
#  'NEW YORK',
#  'DODD, MEAD AND COMPANY',
#  '1924',
#  'Copyright, 1924,',
#  'By DODD, MEAD AND COMPANY, Inc.',
#  'PRINTED IN THE U. S. A. BY',
#  'The Quinn & Boden Company',
#  'BOOK MANUFACTURERS',
#  'RAHWAY   NEW JERSEY',
#  'To E. A. B.',
#  'IN MEMORY OF A JOURNEY, SOME',
#  'LION STORIES AND A REQUEST THAT',
#  'I SHOULD SOME DAY WRITE THE',
#  '“MYSTERY OF THE MILL HOUSE”',
#  'THE MAN IN THE BROWN SUIT',
#  'THE MAN IN THE BROWN SUIT',
#  'PROLOGUE',
#  'Nadina, the Russian dancer who had taken Paris by storm, swayed to',
#  'the sound of the applause, bowed and bowed again. Her narrow black',
#  'eyes narrowed themselves still more, the long line of her scarlet',
#  'mouth curved faintly upwards. Enthusiastic Frenchmen continued to',
#  'beat the ground appreciatively as the curtain fell with a swish,',
#  'hiding the reds and blues and magentas of the bizarre _décors._ In',
#  'a swirl of blue and orange draperies the dancer left the stage. A',
#  'bearded gentleman received her enthusiastically in his arms. It',
#  'was the Manager.',
#  '“Magnificent, _petite,_ magnificent,” he cried. “To-night you have',
#  'surpassed yourself.” He kissed her gallantly on both cheeks in a',
#  'somewhat matter-of-fact manner.',
#  'Madame Nadina accepted the tribute with the ease of long habit and',
#  'passed on to her dressing-room, where bouquets were heaped',
#  'carelessly everywhere, marvellous garments of futuristic design',
#  'hung on pegs, and the air was hot and sweet with the scent of the',
#  'massed blossoms and with more sophisticated perfumes and essences.',
#  'Jeanne, the dresser, ministered to her mistress, talking incessantly',
#  'and pouring out a stream of fulsome compliment.',
#  'A knock at the door interrupted the flow. Jeanne went to answer',
#  'it, and returned with a card in her hand.',
#  '“Madame will receive?”',
#  '“Let me see.”',
#  'The dancer stretched out a languid hand, but at the sight of the',
#  'name on the card, “Count Sergius Paulovitch,” a sudden flicker of',
#  'interest came into her eyes.',
#  '“I will see him. The maize _peignoir,_ Jeanne, and quickly. And',
#  'when the Count comes you may go.”',
#  '_“Bien, Madame.”_',
#  'Jeanne brought the _peignoir,_ an exquisite wisp of corn-coloured',
#  'chiffon and ermine. Nadina slipped into it, and sat smiling to',
#  'herself, whilst one long white hand beat a slow tattoo on the glass',
#  'of the dressing-table.',
#  'The Count was prompt to avail himself of the privilege accorded to',
#  'him—a man of medium height, very slim, very elegant, very pale,',
#  'extraordinarily weary. In feature, little to take hold of, a man',
#  'difficult to recognize again if one left his mannerisms out of',
#  'account. He bowed over the dancer’s hand with exaggerated',
#  'courtliness.',
#  '“Madame, this is a pleasure indeed.”',
#  'So much Jeanne heard before she went out closing the door behind',
#  'her. Alone with her visitor, a subtle change came over Nadina’s',
#  'smile.',
#  '“Compatriots though we are, we will not speak Russian, I think,”',
#  'she observed.',
#  '“Since we neither of us know a word of the language, it might be',
#  'as well,” agreed her guest.',
#  'By common consent, they dropped into English, and nobody, now that',
#  'the Count’s mannerisms had dropped from him, could doubt that it',
#  'was his native language. He had, indeed, started life as a',
#  'quick-change music-hall artiste in London.',
#  '“You had a great success to-night,” he remarked. “I congratulate',
#  'you.”',
#  '“All the same,” said the woman, “I am disturbed. My position is',
#  'not what it was. The suspicions aroused during the War have never',
#  'died down. I am continually watched and spied upon.”',
#  '“But no charge of espionage was ever brought against you?”',
#  '“Our chief lays his plans too carefully for that.”',
#  '“Long life to the ‘Colonel,’” said the Count, smiling. “Amazing',
#  'news, is it not, that he means to retire? To retire! Just like a',
#  'doctor, or a butcher, or a plumber——”',
#  '“Or any other business man,” finished Nadina. “It should not',
#  'surprise us. That is what the ‘Colonel’ has always been—an excellent',
#  'man of business. He has organized crime as another man might',
#  'organize a boot factory. Without committing himself, he has planned',
#  'and directed a series of stupendous _coups,_ embracing every branch',
#  'of what we might call his ‘profession.’ Jewel robberies, forgery,',
#  'espionage (the latter very profitable in war-time), sabotage,',
#  'discreet assassination, there is hardly anything he has not touched.',
#  'Wisest of all, he knows when to stop. The game begins to be',
#  'dangerous?—he retires gracefully—with an enormous fortune!”',
#  '“H’m!” said the Count doubtfully. “It is rather—upsetting for all',
#  'of us. We are at a loose end, as it were.”',
#  '“But we are being paid off—on a most generous scale!” Something,',
#  'some undercurrent of mockery in her tone, made the man look at her',
#  'sharply. She was smiling to herself, and the quality of her smile',
#  'aroused his curiosity. But he proceeded diplomatically:',
#  '“Yes, the ‘Colonel’ has always been a generous paymaster. I',
#  'attribute much of his success to that—and to his invariable plan',
#  'of providing a suitable scapegoat. A great brain, undoubtedly a',
#  'great brain! And an apostle of the maxim, ‘If you want a thing done',
#  'safely, do not do it yourself!’ Here are we, every one of us',
#  'incriminated up to the hilt and absolutely in his power, and not',
#  'one of us has anything on him.”',
#  'He paused, almost as though he were expecting her to disagree with',
#  'him, but she remained silent, smiling to herself as before.',
#  '“Not one of us,” he mused. “Still, you know, he is superstitious,',
#  'the old man. Years ago, I believe, he went to one of these',
#  'fortune-telling people. She prophesied a lifetime of success, but',
#  'declared that his downfall would be brought about through a woman.”',
#  'He had interested her now. She looked up eagerly.',
#  '“That is strange, very strange! Through a woman, you say?”',
#  'He smiled and shrugged his shoulders.',
#  '“Doubtless, now that he has—retired, he will marry. Some young',
#  'society beauty, who will disperse his millions faster than he',
#  'acquired them.”',
#  'Nadina shook her head.',
#  '“No, no, that is not the way of it. Listen, my friend, to-morrow',
#  'I go to London.”',
#  '“But your contract here?”',
#  '“I shall be away only one night. And I go incognito, like Royalty.',
#  'No one will ever know that I have left France. And why do you think',
#  'that I go?”',
#  '“Hardly for pleasure at this time of year. January, a detestable',
#  'foggy month! It must be for profit, eh?”',
#  '“Exactly.” She rose and stood in front of him, every graceful line',
#  'of her arrogant with pride. “You said just now that none of us had',
#  'anything on the chief. You were wrong. I have. I, a woman, have',
#  'had the wit and, yes, the courage—for it needs courage—to',
#  'double-cross him. You remember the De Beer diamonds?”',
#  '“Yes, I remember. At Kimberley, just before the war broke out? I',
#  'had nothing to do with it, and I never heard the details, the case',
#  'was hushed up for some reason, was it not? A fine haul too.”',
#  '“A hundred thousand pounds worth of stones. Two of us worked',
#  'it—under the ‘Colonel’s’ orders, of course. And it was then that',
#  'I saw my chance. You see, the plan was to substitute some of the',
#  'De Beer diamonds for some sample diamonds brought from South',
#  'America by two young prospectors who happened to be in Kimberley',
#  'at the time. Suspicion was then bound to fall on them.”',
#  '“Very clever,” interpolated the Count approvingly.',
#  '“The ‘Colonel’ is always clever. Well, I did my part—but I also',
#  'did one thing which the ‘Colonel’ had not foreseen. I kept back',
#  'some of the South American stones—one or two are unique and could',
#  'easily be proved never to have passed through De Beer’s hands. With',
#  'these diamonds in my possession, I have the whip-hand of my esteemed',
#  'chief. Once the two young men are cleared, his part in the matter',
#  'is bound to be suspected. I have said nothing all these years, I',
#  'have been content to know that I had this weapon in reserve, but',
#  'now matters are different. I want my price—and it will be a big,',
#  'I might almost say a staggering price.”',
#  '“Extraordinary,” said the Count. “And doubtless you carry these',
#  'diamonds about with you everywhere?”',
#  'His eyes roamed gently round the disordered room.',
#  'Nadina laughed softly. “You need suppose nothing of the sort. I am',
#  'not a fool. The diamonds are in a safe place where no one will',
#  'dream of looking for them.”',
#  '“I never thought you a fool, my dear lady, but may I venture to',
#  'suggest that you are somewhat foolhardy? The ‘Colonel’ is not the',
#  'type of man to take kindly to being blackmailed, you know.”',
#  '“I am not afraid of him,” she laughed. “There is only one man I',
#  'have ever feared—and he is dead.”',
#  'The man looked at her curiously.',
#  '“Let us hope that he will not come to life again, then,” he remarked',
#  'lightly.',
#  '“What do you mean?” cried the dancer sharply.',
#  'The Count looked slightly surprised.',
#  '“I only meant that a resurrection would be awkward for you,” he',
#  'explained. “A foolish joke.”',
#  'She gave a sigh of relief.',
#  '“Oh, no, he is dead all right. Killed in the war. He was a man who',
#  'once—loved me.”',
#  '“In South Africa?” asked the Count negligently.',
#  '“Yes, since you ask it, in South Africa.”',
#  '“That is your native country, is it not?”',
#  'She nodded. Her visitor rose and reached for his hat.',
#  '“Well,” he remarked, “you know your own business best, but, if I',
#  'were you, I should fear the ‘Colonel’ far more than any disillusioned',
#  'lover. He is a man whom it is particularly easy to—underestimate.”',
#  'She laughed scornfully.',
#  '“As if I did not know him after all these years!”',
#  '“I wonder if you do?” he said softly. “I very much wonder if you',
#  'do.”',
#  '“Oh, I am not a fool! And I am not alone in this. The South African',
#  'mail-boat docks at Southampton to-morrow, and on board her is a',
#  'man who has come specially from Africa at my request and who has',
#  'carried out certain orders of mine. The ‘Colonel’ will have not',
#  'one of us to deal with, but two.”',
#  '“Is that wise?”',
#  '“It is necessary.”',
#  '“You are sure of this man?”',
#  'A rather peculiar smile played over the dancer’s face.',
#  '“I am quite sure of him. He is inefficient, but perfectly',
#  'trustworthy.” She paused, and then added in an indifferent tone of',
#  'voice: “As a matter of fact, he happens to be my husband.”',
#  'CHAPTER I',
#  'Everybody has been at me, right and left, to write this story from',
#  'the great (represented by Lord Nasby) to the small (represented by',
#  'our late maid of all work, Emily, whom I saw when I was last in',
#  'England. “Lor’, miss, what a beyewtiful book you might make out of',
#  'it all—just like the pictures!”).',
#  'I’ll admit that I’ve certain qualifications for the task. I was',
#  'mixed up in the affair from the very beginning, I was in the thick',
#  'of it all through, and I was triumphantly “in at the death.” Very',
#  'fortunately, too, the gaps that I cannot supply from my own',
#  'knowledge are amply covered by Sir Eustace Pedler’s diary, of which',
#  'he has kindly begged me to make use.',
#  'So here goes. Anne Beddingfeld starts to narrate her adventures.',
#  'I’d always longed for adventures. You see, my life had such a',
#  'dreadful sameness. My father, Professor Beddingfeld, was one of',
#  'England’s greatest living authorities on Primitive Man. He really',
#  'was a genius—every one admits that. His mind dwelt in Palaeolithic',
#  'times, and the inconvenience of life for him was that his body',
#  'inhabited the modern world. Papa did not care for modern man—even',
#  'Neolithic Man he despised as a mere herder of cattle, and he did',
#  'not rise to enthusiasm until he reached the Mousterian period.',
#  'Unfortunately one cannot entirely dispense with modern men. One is',
#  'forced to have some kind of truck with butchers and bakers and',
#  'milkmen and greengrocers. Therefore, Papa being immersed in the',
#  'past, Mamma having died when I was a baby, it fell to me to',
#  'undertake the practical side of living. Frankly, I hate Palaeolithic',
#  'Man, be he Aurignacian, Mousterian, Chellian, or anything else,',
#  'and though I typed and revised most of Papa’s _Neanderthal Man and',
#  'his Ancestors,_ Neanderthal men themselves fill me with loathing,',
#  'and I always reflect what a fortunate circumstance it was that they',
#  'became extinct in remote ages.',
#  'I do not know whether Papa guessed my feelings on the subject,',
#  'probably not, and in any case he would not have been interested.',
#  'The opinion of other people never interested him in the slightest',
#  'degree. I think it was really a sign of his greatness. In the same',
#  'way, he lived quite detached from the necessities of daily life.',
#  'He ate what was put before him in an exemplary fashion, but seemed',
#  'mildly pained when the question of paying for it arose. We never',
#  'seemed to have any money. His celebrity was not of the kind that',
#  'brought in a cash return. Although he was a fellow of almost every',
#  'important society, and had rows of letters after his name, the',
#  'general public scarcely knew of his existence, and his long learned',
#  'books, though adding signally to the sum-total of human knowledge,',
#  'had no attraction for the masses. Only on one occasion did he leap',
#  'into the public gaze. He had read a paper before some society on',
#  'the subject of the young of the chimpanzee. The young of the human',
#  'race show some anthropoid features, whereas the young of the',
#  'chimpanzee approach more nearly to the human than the adult',
#  'chimpanzee does. That seems to show that whereas our ancestors were',
#  'more Simian than we are, the chimpanzee’s were of a higher type',
#  'than the present species—in other words, the chimpanzee is a',
#  'degenerate. That enterprising newspaper, the _Daily Budget,_ being',
#  'hard up for something spicy, immediately brought itself out with',
#  'large headlines. “We are not descended from monkeys, but are',
#  'monkeys descended from _us?_ Eminent Professor says chimpanzees',
#  'are decadent humans.” Shortly afterwards a reporter called to see',
#  'Papa, and endeavoured to induce him to write a series of popular',
#  'articles on the theory. I have seldom seen Papa so angry. He turned',
#  'the reporter out of the house with scant ceremony, much to my',
#  'secret sorrow, as we were particularly short of money at the',
#  'moment. In fact, for a moment I meditated running after the young',
#  'man and informing him that my father had changed his mind and would',
#  'send the articles in question. I could easily have written them',
#  'myself, and the probabilities were that Papa would never have',
#  'learnt of the transaction, not being a reader of the _Daily Budget._',
#  'However, I rejected this course as being too risky, so I merely',
#  'put on my best hat and went sadly down the village to interview',
#  'our justly irate grocer.',
#  'The reporter from the _Daily Budget_ was the only young man who',
#  'ever came to our house. There were times when I envied Emily, our',
#  'little servant, who “walked out” whenever occasion offered with a',
#  'large sailor to whom she was affianced. In between times, to “keep',
#  'her hand in” as she expressed it, she walked out with the',
#  'greengrocer’s young man, and the chemist’s assistant. I reflected',
#  'sadly that I had no one to “keep my hand in” with. All Papa’s',
#  'friends were aged Professors—usually with long beards. It is true',
#  'that Professor Peterson once clasped me affectionately and said I',
#  'had a “neat little waist” and then tried to kiss me. The phrase',
#  'alone dated him hopelessly. No self-respecting female has had a',
#  '“neat little waist” since I was in my cradle.',
#  'I yearned for adventure, for love, for romance, and I seemed',
#  'condemned to an existence of drab utility. The village possessed',
#  'a lending library, full of tattered works of fiction, and I enjoyed',
#  'perils and love-making at second hand, and went to sleep dreaming',
#  'of stern, silent Rhodesians, and of strong men who always “felled',
#  'their opponent with a single blow.” There was no one in the village',
#  'who even looked as though he could “fell” an opponent, with a',
#  'single blow or with several.',
#  'There was the Kinema too, with a weekly episode of “The Perils of',
#  'Pamela.” Pamela was a magnificent young woman. Nothing daunted her.',
#  'She fell out of aeroplanes, adventured in submarines, climbed',
#  'skyscrapers and crept about in the Underworld without turning a',
#  'hair. She was not really clever, the Master Criminal of the',
#  'Underworld caught her each time, but as he seemed loath to knock',
#  'her on the head in a simple way, and always doomed her to death in',
#  'a sewer-gas chamber or by some new and marvellous means, the hero',
#  'was always able to rescue her at the beginning of the following',
#  'week’s episode. I used to come out with my head in a delirious',
#  'whirl—and then I would get home and find a notice from the Gas',
#  'Company threatening to cut us off if the outstanding account was',
#  'not paid!',
#  'And yet, though I did not suspect it, every moment was bringing',
#  'adventure nearer to me.',
#  'It is possible that there are many people in the world who have',
#  'never heard of the finding of an antique skull at the Broken Hill',
#  'Mine in Northern Rhodesia. I came down one morning to find Papa',
#  'excited to the point of apoplexy. He poured out the whole story to',
#  'me.',
#  '“You understand, Anne? There are undoubtedly certain resemblances',
#  'to the Java skull, but superficial—superficial only. No, here we',
#  'have what I have always maintained—the ancestral form of the',
#  'Neanderthal race. You grant that the Gibraltar skull is the most',
#  'primitive of the Neanderthal skulls found? Why? The cradle of the',
#  'race was in Africa. They passed to Europe——”',
#  '“Not marmalade on kippers, papa,” I said hastily, arresting my',
#  'parent’s absent-minded hand. “Yes, you were saying?”',
#  '“They passed to Europe on——”',
#  'Here he broke down with a bad fit of choking, the result of an',
#  'immoderate mouthful of kipper-bones.',
#  '“But we must start at once,” he declared, as he rose to his feet',
#  'at the conclusion of the meal. “There is no time to be lost. We',
#  'must be on the spot—there are doubtless incalculable finds to be',
#  'found in the neighbourhood. I shall be interested to note whether',
#  'the implements are typical of the Mousterian period—there will be',
#  'the remains of the primitive ox, I should say, but not those of',
#  'the woolly rhinoceros. Yes, a little army will be starting soon.',
#  'We must get ahead of them. You will write to Cook’s to-day, Anne?”',
#  '“What about money, papa?” I hinted delicately.',
#  'He turned a reproachful eye upon me.',
#  '“Your point of view always depresses me, my child. We must not be',
#  'sordid. No, no, in the cause of science one must not be sordid.”',
#  '“I feel Cook’s might be sordid, papa.”',
#  'Papa looked pained.',
#  '“My dear Anne, you will pay them in ready money.”',
#  '“I haven’t got any ready money.”',
#  'Papa looked thoroughly exasperated.',
#  '“My child, I really cannot be bothered with these vulgar money',
#  'details. The bank—I had something from the Manager yesterday,',
#  'saying I had twenty-seven pounds.”',
#  '“That’s your overdraft, I fancy.”',
#  '“Ah, I have it! Write to my publishers.”',
#  'I acquiesced doubtfully, Papa’s books bringing in more glory than',
#  'money. I liked the idea of going to Rhodesia immensely. “Stern',
#  'silent men,” I murmured to myself in an ecstasy. Then something in',
#  'my parent’s appearance struck me as unusual.',
#  '“You have odd boots on, papa,” I said. “Take off the brown one and',
#  'put on the other black one. And don’t forget your muffler. It’s a',
#  'very cold day.”',
#  'In a few minutes Papa stalked off, correctly booted and well',
#  'mufflered.',
#  'He returned late that evening, and, to my dismay, I saw his muffler',
#  'and overcoat were missing.',
#  '“Dear me, Anne, you are quite right. I took them off to go into',
#  'the cavern. One gets so dirty there.”',
#  'I nodded feelingly, remembering an occasion when Papa had returned',
#  'literally plastered from head to foot with rich Pleiocene clay.',
#  'Our principal reason for settling in Little Hampsly had been the',
#  'neighbourhood of Hampsly Cavern, a buried cave rich in deposits of',
#  'the Aurignacian culture. We had a tiny Museum in the village, and',
#  'the curator and Papa spent most of their days messing about',
#  'underground and bringing to light portions of woolly rhinoceros',
#  'and cave bear.',
#  'Papa coughed badly all the evening, and the following morning I',
#  'saw he had a temperature and sent for the doctor.',
#  'Poor Papa, he never had a chance. It was double pneumonia. He died',
#  'four days later.',
#  'CHAPTER II',
#  'Every one was very kind to me. Dazed as I was, I appreciated that.',
#  'I felt no overwhelming grief. Papa had never loved me, I knew that',
#  'well enough. If he had, I might have loved him in return. No, there',
#  'had not been love between us, but we had belonged together, and I',
#  'had looked after him, and had secretly admired his learning and',
#  'his uncompromising devotion to science. And it hurt me that Papa',
#  'should have died just when the interest of life was at its height',
#  'for him. I should have felt happier if I could have buried him in',
#  'a cave, with paintings of reindeer and flint implements, but the',
#  'force of public opinion constrained a neat tomb (with marble slab)',
#  'in our hideous local churchyard. The vicar’s consolations, though',
#  'well meant, did not console me in the least.',
#  'It took some time to dawn upon me that the thing I had always',
#  'longed for—freedom—was at last mine. I was an orphan, and',
#  'practically penniless, but free. At the same time I realized the',
#  'extraordinary kindness of all these good people. The vicar did his',
#  'best to persuade me that his wife was in urgent need of a companion',
#  'help. Our tiny local library suddenly made up its mind to have an',
#  'assistant librarian. Finally, the doctor called upon me, and after',
#  'making various ridiculous excuses for failing to send in a proper',
#  'bill, he hummed and hawed a good deal and suddenly suggested that',
#  'I should marry him.',
#  'I was very much astonished. The doctor was nearer forty than',
#  'thirty, and a round, tubby little man. He was not at all like the',
#  'hero of “The Perils of Pamela,” and even less like a stern and',
#  'silent Rhodesian. I reflected a minute and then asked him why he',
#  'wanted to marry me. That seemed to fluster him a good deal, and he',
#  'murmured that a wife was a great help to a General Practitioner.',
#  'The position seemed even more unromantic than before, and yet',
#  'something in me urged towards its acceptance. Safety, that was what',
#  'I was being offered. Safety—and a Comfortable Home. Thinking it',
#  'over now, I believe I did the little man an injustice. He was',
#  'honestly in love with me, but a mistaken delicacy prevented him',
#  'from pressing his suit on those lines. Anyway, my love of romance',
#  'rebelled.',
#  '“It’s extremely kind of you,” I said. “But it’s impossible. I could',
#  'never marry a man unless I loved him madly.”',
#  '“You don’t think——?”',
#  '“No, I don’t,” I said firmly.',
#  'He sighed.',
#  '“But, my dear child, what do you propose to do?”',
#  '“Have adventures and see the world,” I replied, without the least',
#  'hesitation.',
#  '“Miss Anne, you are very much of a child still. You don’t',
#  'understand——”',
#  '“The practical difficulties? Yes, I do, doctor. I’m not a',
#  'sentimental schoolgirl—I’m a hard-headed mercenary shrew! You’d',
#  'know it if you married me!”',
#  '“I wish you would reconsider——”',
#  '“I can’t.”',
#  'He sighed again.',
#  '“I have another proposal to make. An aunt of mine who lives in',
#  'Wales is in want of a young lady to help her. How would that suit',
#  'you?”',
#  '“No, doctor, I’m going to London. If things happen anywhere, they',
#  'happen in London. I shall keep my eyes open and you’ll see,',
#  'something will turn up! You’ll hear of me next in China or',
#  'Timbuctoo.”',
#  'My next visitor was Mr. Flemming, Papa’s London solicitor. He came',
#  'down specially from town to see me. An ardent anthropologist',
#  'himself, he was a great admirer of Papa’s works. He was a tall,',
#  'spare man with a thin face and grey hair. He rose to meet me as I',
#  'entered the room and, taking both my hands in his, patted them',
#  'affectionately.',
#  '“My poor child,” he said. “My poor, poor child.”',
#  'Without conscious hypocrisy, I found myself assuming the demeanour',
#  'of a bereaved orphan. He hypnotized me into it. He was benignant,',
#  'kind and fatherly—and without the least doubt he regarded me as a',
#  'perfect fool of a girl left adrift to face an unkind world. From',
#  'the first I felt that it was quite useless to try to convince him',
#  'of the contrary. As things turned out, perhaps it was just as well',
#  'I didn’t.',
#  '“My dear child, do you think you can listen to me whilst I try to',
#  'make a few things clear to you?”',
#  '“Oh, yes.”',
#  '“Your father, as you know, was a very great man. Posterity will',
#  'appreciate him. But he was not a good man of business.”',
#  'I knew that quite as well, if not better than Mr. Flemming, but I',
#  'restrained myself from saying so. He continued:',
#  '“I do not suppose you understand much of these matters. I will try',
#  'to explain as clearly as I can.”',
#  'He explained at unnecessary length. The upshot seemed to be that',
#  'I was left to face life with the sum of £87, 17s. 4d. It seemed a',
#  'strangely unsatisfying amount. I waited in some trepidation for',
#  'what was coming next. I feared that Mr. Flemming would be sure to',
#  'have an aunt in Scotland who was in want of a bright young',
#  'companion. Apparently, however, he hadn’t.',
#  '“The question is,” he went on, “the future. I understand you have',
#  'no living relatives?”',
#  '“I’m alone in the world,” I said, and was struck anew by my likeness',
#  'to a film heroine.',
#  '“You have friends?”',
#  '“Every one has been very kind to me,” I said gratefully.',
#  '“Who would not be kind to one so young and charming?” said Mr.',
#  'Flemming gallantly. “Well, well, my dear, we must see what can be',
#  'done.” He hesitated a minute, and then said: “Supposing—how would',
#  'it be if you came to us for a time?”',
#  'I jumped at the chance. London! The place for things to happen.',
#  '“It’s awfully kind of you,” I said. “Might I really? Just while',
#  'I’m looking round. I must start out to earn my living, you know?”',
#  '“Yes, yes, my dear child. I quite understand. We will look round',
#  'for something—suitable.”',
#  'I felt instinctively that Mr. Flemming’s ideas of “something',
#  'suitable” and mine were likely to be widely divergent, but it was',
#  'certainly not the moment to air my views.',
#  '“That is settled then. Why not return with me to-day?”',
#  '“Oh, thank you, but will Mrs. Flemming——”',
#  '“My wife will be delighted to welcome you.”',
#  'I wonder if husbands know as much about their wives as they think',
#  'they do. If I had a husband, I should hate him to bring home',
#  'orphans without consulting me first.',
#  '“We will send her a wire from the station,” continued the lawyer.',
#  'My few personal belongings were soon packed. I contemplated my hat',
#  'sadly before putting it on. It had originally been what I call a',
#  '“Mary” hat, meaning by that the kind of hat a housemaid ought to',
#  'wear on her day out—but doesn’t! A limp thing of black straw with',
#  'a suitably depressed brim. With the inspiration of genius, I had',
#  'kicked it once, punched it twice, dented in the crown and affixed',
#  'to it a thing like a cubist’s dream of a jazz carrot. The result',
#  'had been distinctly chic. The carrot I had already removed, of',
#  'course, and now I proceeded to undo the rest of my handiwork. The',
#  '“Mary” hat resumed its former status with an additional battered',
#  'appearance which made it even more depressing than formerly. I',
#  'might as well look as much like the popular conception of an orphan',
#  'as possible. I was just a shade nervous of Mrs. Flemming’s',
#  'reception, but hoped my appearance might have a sufficiently',
#  'disarming effect.',
#  'Mr. Flemming was nervous too. I realized that as we went up the',
#  'stairs of the tall house in a quiet Kensington Square. Mrs. Flemming',
#  'greeted me pleasantly enough. She was a stout, placid woman of the',
#  '“good wife and mother” type. She took me up to a spotless',
#  'chintz-hung bedroom, hoped I had everything I wanted, informed me',
#  'that tea would be ready in about a quarter of an hour, and left me',
#  'to my own devices.',
#  'I heard her voice, slightly raised, as she entered the drawing-room',
#  'below on the first floor.',
#  '“Well, Henry, why on earth——” I lost the rest, but the acerbity of',
#  'the tone was evident. And a few minutes later another phrase',
#  'floated up to me, in an even more acid voice:',
#  '“I agree with you! She is certainly _very_ good-looking.”',
#  'It is really a very hard life. Men will not be nice to you if you',
#  'are not good-looking, and women will not be nice to you if you are.',
#  'With a deep sigh I proceeded to do things to my hair. I have nice',
#  'hair. It is black—a real black, not dark brown, and it grows well',
#  'back from my forehead and down over the ears. With a ruthless hand',
#  'I dragged it upwards. As ears, my ears are quite all right, but',
#  'there is no doubt about it, ears are _démodé_ nowadays. They are',
#  'like the “Queen of Spain’s legs” in Professor Peterson’s young day.',
#  'When I had finished I looked almost unbelievably like the kind of',
#  'orphan that walks out in a queue with a little bonnet and a red',
#  'cloak.',
#  'I noticed when I went down that Mrs. Flemming’s eyes rested on my',
#  'exposed ears with quite a kindly glance. Mr. Flemming seemed',
#  'puzzled. I had no doubt that he was saying to himself, “What _has_',
#  'the child done to herself?”',
#  'On the whole the rest of the day passed off well. It was settled',
#  'that I was to start at once to look for something to do.',
#  'When I went to bed, I stared earnestly at my face in the glass.',
#  'Was I really good-looking? Honestly, I couldn’t say I thought so!',
#  'I hadn’t got a straight Grecian nose, or a rosebud mouth, or any',
#  'of the things you ought to have. It is true that a curate once told',
#  'me that my eyes were like “imprisoned sunshine in a dark, dark',
#  'wood”—but curates always know so many quotations, and fire them',
#  'off at random. I’d much prefer to have Irish blue eyes than dark',
#  'green ones with yellow flecks! Still, green is a good colour for',
#  'adventuresses.',
#  'I wound a black garment tightly round me, leaving my arms and',
#  'shoulders bare. Then I brushed back my hair and pulled it well down',
#  'over my ears again. I put a lot of powder on my face, so that the',
#  'skin seemed even whiter than usual. I fished about until I found',
#  'some old lip-salve, and I put oceans of it on my lips. Then I did',
#  'under my eyes with burnt cork. Finally, I draped a red ribbon over',
#  'my bare shoulder, stuck a scarlet feather in my hair, and placed',
#  'a cigarette in one corner of my mouth. The whole effect pleased me',
#  'very much.',
#  '“Anna the Adventuress,” I said aloud, nodding at my reflection.',
#  '“Anna the Adventuress. Episode I, ‘The House in Kensington’!”',
#  'Girls are foolish things.',
#  'CHAPTER III',
#  'In the succeeding weeks I was a good deal bored.',
#  'Mrs. Flemming and her friends seemed to me to be supremely',
#  'uninteresting. They talked for hours of themselves and their',
#  'children and of the difficulties of getting good milk for the',
#  'children and of what they said to the Dairy when the milk wasn’t',
#  'good. Then they would go on to servants, and the difficulties of',
#  'getting good servants and of what they had said to the woman at',
#  'the Registry Office and of what the woman at the Registry Office',
#  'had said to them. They never seemed to read the papers or to care',
#  'about what went on in the world. They disliked travelling—everything',
#  'was so different to England. The Riviera was all right, of course,',
#  'because one met all one’s friends there.',
#  'I listened and contained myself with difficulty. Most of these',
#  'women were rich. The whole wide beautiful world was theirs to',
#  'wander in and they deliberately stayed in dirty dull London and',
#  'talked about milkmen and servants! I think now, looking back, that',
#  'I was perhaps a shade intolerant. But they _were_ stupid—stupid',
#  'even at their chosen job: most of them kept the most extraordinarily',
#  'inadequate and muddled housekeeping accounts.',
#  'My affairs did not progress very fast. The house and furniture had',
#  'been sold, and the amount realized had just covered our debts. As',
#  'yet, I had not been successful in finding a post. Not that I really',
#  'wanted one! I had the firm conviction that, if I went about looking',
#  'for adventure, adventure would meet me halfway. It is a theory of',
#  'mine that one always gets what one wants. My theory was about to',
#  'be proved in practice.',
#  'It was early in January—the 8th, to be exact. I was returning from',
#  'an unsuccessful interview with a lady who said she wanted a',
#  'secretary-companion, but really seemed to require a strong charwoman',
#  'who would work twelve hours a day for £25 a year. Having parted',
#  'with mutual veiled impolitenesses, I walked down Edgware Road (the',
#  'interview had taken place in a house in St. John’s Wood) and across',
#  'Hyde Park to St. George’s Hospital. There I entered Hyde Park',
#  'Corner Tube Station and took a ticket to Gloucester Road.',
#  'Once on the platform I walked to the extreme end of it. My inquiring',
#  'mind wished to satisfy itself as to whether there really _were_',
#  'points and an opening between the two tunnels just beyond the',
#  'station in the direction of Down Street. I was foolishly pleased',
#  'to find I was right. There were not many people on the platform,',
#  'and at the extreme end there was only myself and one man. As I',
#  'passed him, I sniffed dubiously. If there is one smell I cannot',
#  'bear it is that of moth balls! This man’s heavy overcoat simply',
#  'reeked of them. And yet most men begin to wear their winter',
#  'overcoats before January, and consequently by this time the smell',
#  'ought to have worn off. The man was beyond me, standing close to',
#  'the edge of the tunnel. He seemed lost in thought, and I was able',
#  'to stare at him without rudeness. He was a small thin man, very',
#  'brown of face, with light blue eyes and a small dark beard.',
#  '“Just come from abroad,” I deduced. “That’s why his overcoat smells',
#  'so. He’s come from India. Not an officer, or he wouldn’t have a',
#  'beard. Perhaps a tea-planter.”',
#  'At this moment the man turned as though to retrace his steps along',
#  'the platform. He glanced at me and then his eyes went on to',
#  'something behind me, and his face changed. It was distorted by',
#  'fear—almost panic. He stood a step backwards as though involuntarily',
#  'recoiling from some danger, forgetting that he was standing on the',
#  'extreme edge of the platform, and went down and over.',
#  'There was a vivid flash from the rails and a crackling sound. I',
#  'shrieked. People came running up. Two station officials seemed to',
#  'materialize from nowhere and took command.',
#  'I remained where I was, rooted to the spot by a sort of horrible',
#  'fascination. Part of me was appalled at the sudden disaster, and',
#  'another part of me was coolly and dispassionately interested in',
#  'the methods employed for lifting the man off the live rail and back',
#  'onto the platform.',
#  '“Let me pass, please. I am a medical man.”',
#  'A tall man with a brown beard pressed past me and bent over the',
#  'motionless body.',
#  'As he examined it, a curious sense of unreality seemed to possess',
#  'me. The thing wasn’t real—couldn’t be. Finally, the doctor stood',
#  'upright and shook his head.',
#  '“Dead as a door-nail. Nothing to be done.”',
#  'We had all crowded nearer, and an aggrieved porter raised his',
#  'voice.',
#  '“Now then, stand back there, will you? What’s the sense in crowding',
#  'round.”',
#  'A sudden nausea seized me, and I turned blindly and ran up the',
#  'stairs again towards the lift. I felt that it was too horrible. I',
#  'must get out into the open air. The doctor who had examined the',
#  'body was just ahead of me. The lift was just about to go up,',
#  'another having descended, and he broke into a run. As he did so,',
#  'he dropped a piece of paper.',
#  'I stopped, picked it up, and ran after him. But the lift gates',
#  'clanged in my face, and I was left holding the paper in my hand.',
#  'By the time the second lift reached the street level, there was no',
#  'sign of my quarry. I hoped it was nothing important that he had',
#  'lost, and for the first time I examined it.',
#  'It was a plain half-sheet of notepaper with some figures and words',
#  'scrawled upon it in pencil. This is a facsimile of it:',
#  '[Indistinct cursive script which appears to say something like:',
#  '"1 7 . 1 2 2 Kilmorden Castle"]',
#  'On the face of it, it certainly did not appear to be of any',
#  'importance. Still, I hesitated to throw it away. As I stood there',
#  'holding it, I involuntarily wrinkled my nose in displeasure. Moth',
#  'balls again! I held the paper gingerly to my nose. Yes, it smelt',
#  'strongly of them. But, then——',
#  'I folded up the paper carefully and put it in my bag. I walked home',
#  'slowly and did a good deal of thinking.',
#  'I explained to Mrs. Flemming that I had witnessed a nasty accident',
#  'in the Tube and that I was rather upset and would go to my room',
#  'and lie down. The kind woman insisted on my having a cup of tea.',
#  'After that I was left to my own devices, and I proceeded to carry',
#  'out a plan I had formed coming home. I wanted to know what it was',
#  'that had produced that curious feeling of unreality whilst I was',
#  'watching the doctor examine the body. First I lay down on the floor',
#  'in the attitude of the corpse, then I laid a bolster down in my',
#  'stead, and proceeded to duplicate, so far as I could remember,',
#  'every motion and gesture of the doctor. When I had finished I had',
#  'got what I wanted. I sat back on my heels and frowned at the',
#  'opposite walls.',
#  'There was a brief notice in the evening papers that a man had been',
#  'killed in the Tube, and a doubt was expressed whether it was',
#  'suicide or accident. That seemed to me to make my duty clear, and',
#  'when Mr. Flemming heard my story he quite agreed with me.',
#  '“Undoubtedly you will be wanted at the inquest. You say no one else',
#  'was near enough to see what happened?”',
#  '“I had the feeling some one was coming up behind me, but I can’t',
#  'be sure—and, anyway, they wouldn’t be as near as I was.”',
#  'The inquest was held. Mr. Flemming made all the arrangements and',
#  'took me there with him. He seemed to fear that it would be a great',
#  'ordeal to me, and I had to conceal from him my complete composure.',
#  'The deceased had been identified as L. B. Carton. Nothing had been',
#  'found in his pockets except a house-agent’s order to view a house',
#  'on the river near Marlow. It was in the name of L. B. Carton,',
#  'Russell Hotel. The bureau clerk from the hotel identified the man',
#  'as having arrived the day before and booked a room under that name.',
#  'He had registered as L. B. Carton, Kimberley, S. Africa. He had',
#  'evidently come straight off the steamer.',
#  'I was the only person who had seen anything of the affair.',
#  '“You think it was an accident?” the coroner asked me.',
#  '“I am positive of it. Something alarmed him, and he stepped',
#  'backwards blindly without thinking what he was doing.”',
#  '“But what could have alarmed him?”',
#  '“That I don’t know. But there was something. He looked',
#  'panic-stricken.”',
#  'A stolid juryman suggested that some men were terrified of cats.',
#  'The man might have seen a cat. I didn’t think his suggestion a very',
#  'brilliant one, but it seemed to pass muster with the jury, who were',
#  'obviously impatient to get home and only too pleased at being able',
#  'to give a verdict of accident as opposed to suicide.',
#  '“It is extraordinary to me,” said the coroner, “that the doctor',
#  'who first examined the body has not come forward. His name and',
#  'address should have been taken at the time. It was most irregular',
#  'not to do so.”',
#  'I smiled to myself. I had my own theory in regard to the doctor.',
#  'In pursuance of it, I determined to make a call upon Scotland Yard',
#  'at an early date.',
#  'But the next morning brought a surprise. The Flemmings took in the',
#  '_Daily Budget,_ and the _Daily Budget_ was having a day after its',
#  'own heart.',
#  'EXTRAORDINARY SEQUEL TO TUBE ACCIDENT.',
#  'WOMAN FOUND STABBED IN LONELY HOUSE.',
#  'I read eagerly.',
#  '“A sensational discovery was made yesterday at the Mill House,',
#  'Marlow. The Mill House, which is the property of Sir Eustace',
#  'Pedler, M.P., is to be let unfurnished, and an order to view this',
#  'property was found in the pocket of the man who was at first',
#  'thought to have committed suicide by throwing himself on the live',
#  'rail at Hyde Park Corner Tube Station. In an upper room of the Mill',
#  'House the body of a beautiful young woman was discovered yesterday,',
#  'strangled. She is thought to be a foreigner, but so far has not',
#  'been identified. The police are reported to have a clue. Sir',
#  'Eustace Pedler, the owner of the Mill House, is wintering on the',
#  'Riviera.”',
#  'CHAPTER IV',
#  'Nobody came forward to identify the dead woman. The inquest elicited',
#  'the following facts.',
#  'Shortly after one o’clock on January 8th, a well-dressed woman with',
#  'a slight foreign accent had entered the offices of Messrs. Butler',
#  'and Park, house-agents, in Knightsbridge. She explained that she',
#  'wanted to rent or purchase a house on the Thames within easy reach',
#  'of London. The particulars of several were given to her, including',
#  'those of the Mill House. She gave the name of Mrs. de Castina and',
#  'her address as the Ritz, but there proved to be no one of that name',
#  'staying there, and the hotel people failed to identify the body.',
#  'Mrs. James, the wife of Sir Eustace Pedler’s gardener, who acted',
#  'as caretaker to the Mill House and inhabited the small lodge',
#  'opening on the main road, gave evidence. About three o’clock that',
#  'afternoon, a lady came to see over the house. She produced an order',
#  'from the house-agents, and, as was the usual custom, Mrs. James',
#  'gave her the keys of the house. It was situated at some distance',
#  'from the lodge, and she was not in the habit of accompanying',
#  'prospective tenants. A few minutes later a young man arrived. Mrs.',
#  'James described him as tall and broad-shouldered, with a bronzed',
#  'face and light grey eyes. He was clean-shaven and was wearing a',
#  'brown suit. He explained to Mrs. James that he was a friend of the',
#  'lady who had come to look over the house, but had stopped at the',
#  'post office to send a telegram. She directed him to the house, and',
#  'thought no more about the matter.',
#  'Five minutes later he reappeared, handed her back the keys and',
#  'explained that he feared the house would not suit them. Mrs. James',
#  'did not see the lady, but thought that she had gone on ahead. What',
#  'she did notice was that the young man seemed very much upset about',
#  'something. “He looked like a man who’d seen a ghost. I thought he',
#  'was taken ill.”',
#  'On the following day another lady and gentleman came to see the',
#  'property and discovered the body lying on the floor in one of the',
#  'upstairs rooms. Mrs. James identified it as that of the lady who',
#  'had come the day before. The house-agents also recognized it as',
#  'that of “Mrs. de Castina.” The police surgeon gave it as his',
#  'opinion that the woman had been dead about twenty-four hours. The',
#  '_Daily Budget_ had jumped to the conclusion that the man in the',
#  'Tube had murdered the woman and afterwards committed suicide.',
#  'However, as the Tube victim was dead at two o’clock, and the woman',
#  'was alive and well at three o’clock, the only logical conclusion',
#  'to come to was that the two occurrences had nothing to do with each',
#  'other, and that the order to view the house at Marlow found in the',
#  'dead man’s pocket was merely one of those coincidences which so',
#  'often occur in this life.',
#  'A verdict of “Wilful Murder against some person or persons unknown”',
#  'was returned, and the police (and the _Daily Budget_) were left to',
#  'look for “the man in the brown suit.” Since Mrs. James was positive',
#  'that there was no one in the house when the lady entered it, and',
#  'that nobody except the young man in question entered it until the',
#  'following afternoon, it seemed only logical to conclude that he',
#  'was the murderer of the unfortunate Mrs. de Castina. She had been',
#  'strangled with a piece of stout black cord, and had evidently been',
#  'caught unawares with no time to cry out. The black silk handbag',
#  'which she carried contained a well-filled notecase and some loose',
#  'change, a fine lace handkerchief, unmarked, and the return half of',
#  'a first-class ticket to London. Nothing much there to go upon.',
#  'Such were the details published broadcast by the _Daily Budget,_',
#  'and “Find the Man in the Brown Suit” was their daily war-cry. On',
#  'an average about five hundred people wrote daily to announce their',
#  'success in the quest, and tall young men with well-tanned faces',
#  'cursed the day when their tailors had persuaded them to a brown',
#  'suit. The accident in the Tube, dismissed as a coincidence, faded',
#  'out of the public mind.',
#  'Was it a coincidence? I was not so sure. No doubt I was',
#  'prejudiced—the Tube incident was my own pet mystery—but there',
#  'certainly seemed to me to be a connection of some kind between the',
#  'two fatalities. In each there was a man with a tanned face—evidently',
#  'an Englishman living abroad, and there were other things. It was',
#  'the consideration of these other things that finally impelled me',
#  'to what I considered a dashing step. I presented myself at Scotland',
#  'Yard and demanded to see whoever was in charge of the Mill House',
#  'case.',
#  'My request took some time to understand, as I had inadvertently',
#  'selected the department for lost umbrellas, but eventually I was',
#  'ushered into a small room and presented to Detective Inspector',
#  'Meadows.',
#  'Inspector Meadows was a small man with a ginger head and what I',
#  'considered a peculiarly irritating manner. A satellite, also in',
#  'plain clothes, sat unobtrusively in a corner.',
#  '“Good morning,” I said nervously.',
#  '“Good morning. Will you take a seat? I understand you’ve something',
#  'to tell me that you think may be of use to us.”',
#  'His tone seemed to indicate that such a thing was unlikely in the',
#  'extreme. I felt my temper stirred.',
#  '“Of course you know about the man who was killed in the Tube? The',
#  'man who had an order to view this same house at Marlow in his',
#  'pocket.”',
#  '“Ah!” said the inspector. “You are the Miss Beddingfeld who gave',
#  'evidence at the inquest. Certainly the man had an order in his',
#  'pocket. A lot of other people may have had too—only they didn’t',
#  'happen to be killed.”',
#  'I rallied my forces.',
#  '“You don’t think it odd that this man had no ticket in his pocket?”',
#  '“Easiest thing in the world to drop your ticket. Done it myself.”',
#  '“And no money.”',
#  '“He had some loose change in his trousers pocket.”',
#  '“But no notecase.”',
#  '“Some men don’t carry a pocket-book or notecase of any kind.”',
#  'I tried another tack.',
#  '“You don’t think it’s odd that the doctor never came forward',
#  'afterwards?”',
#  '“A busy medical man very often doesn’t read the papers. He probably',
#  'forgot all about the accident.”',
#  '“In fact, inspector, you are determined to find nothing odd,” I',
#  'said sweetly.',
#  '“Well, I’m inclined to think you’re a little too fond of the word,',
#  'Miss Beddingfeld. Young ladies are romantic, I know—fond of',
#  'mysteries and such-like. But as I’m a busy man——”',
#  'I took the hint and rose.',
#  'The man in the corner raised a meek voice.',
#  '“Perhaps the young lady would tell us briefly what her ideas really',
#  'are on the subject, inspector?”',
#  'The inspector fell in with the suggestion readily enough.',
#  '“Yes, come now, Miss Beddingfeld, don’t be offended. You’ve asked',
#  'questions and hinted things. Just say straight out what it is',
#  'you’ve got in your head.”',
#  'I wavered between injured dignity and the overwhelming desire to',
#  'express my theories. Injured dignity went to the wall.',
#  '“You said at the inquest you were positive it wasn’t suicide?”',
#  '“Yes, I’m quite certain of that. The man was frightened. What',
#  'frightened him? It wasn’t me. But some one might have been walking',
#  'up the platform towards us—some one he recognized.”',
#  '“You didn’t see any one?”',
#  '“No,” I admitted. “I didn’t turn my head. Then, as soon as the body',
#  'was recovered from the line, a man pushed forward to examine it,',
#  'saying he was a doctor.”',
#  '“Nothing unusual in that,” said the inspector dryly.',
#  '“But he wasn’t a doctor.”',
#  '“What?”',
#  '“He wasn’t a doctor,” I repeated.',
#  '“How do you know that, Miss Beddingfeld?”',
#  '“It’s difficult to say, exactly. I’ve worked in Hospital during',
#  'the war, and I’ve seen doctors handle bodies. There’s a sort of',
#  'deft professional callousness that this man hadn’t got. Besides,',
#  'a doctor doesn’t usually feel for the heart on the right side of',
#  'the body.”',
#  '“He did that?”',
#  '“Yes, I didn’t notice it specially at the time—except that I felt',
#  'there was something wrong. But I worked it out when I got home,',
#  'and then I saw why the whole thing had looked so unhandy to me at',
#  'the time.”',
#  '“H’m,” said the inspector. He was reaching slowly for pen and',
#  'paper.',
#  '“In running his hands over the upper part of the man’s body he',
#  'would have ample opportunity to take anything he wanted from the',
#  'pockets.”',
#  '“Doesn’t sound likely to me,” said the inspector. “But—well, can',
#  'you describe him at all?”',
#  '“He was tall and broad-shouldered, wore a dark overcoat and black',
#  'boots, a bowler hat. He had a dark pointed beard and gold-rimmed',
#  'eyeglasses.”',
#  '“Take away the overcoat, the beard and the eyeglasses, and there',
#  'wouldn’t be much to know him by,” grumbled the inspector. “He could',
#  'alter his appearance easy enough in five minutes if he wanted',
#  'to—which he would do if he’s the swell pickpocket you suggest.”',
#  'I had not intended to suggest anything of the kind. But from this',
#  'moment I gave the inspector up as hopeless.',
#  '“Nothing more you can tell us about him?” he demanded, as I rose',
#  'to depart.',
#  '“Yes,” I said. I seized my opportunity to fire a parting shot. “His',
#  'head was markedly brachycephalic. He will not find it so easy to',
#  'alter that.”',
#  'I observed with pleasure that Inspector Meadow’s pen wavered. It',
#  'was clear that he did not know how to spell brachycephalic.',
#  'CHAPTER V',
#  'In the first heat of indignation I found my next step unexpectedly',
#  'easy to tackle. I had had a half-formed plan in my head when I went',
#  'into Scotland Yard. One to be carried out if my interview there',
#  'was unsatisfactory (it had been profoundly unsatisfactory). That',
#  'is, if I had the nerve to go through with it.',
#  'Things that one would shrink from attempting normally are easily',
#  'tackled in a flush of anger. Without giving myself time to reflect,',
#  'I walked straight to the house of Lord Nasby.',
#  'Lord Nasby was the millionaire owner of the _Daily Budget._ He',
#  'owned other papers—several of them, but the _Daily Budget_ was his',
#  'special child. It was as the owner of the _Daily Budget_ that he',
#  'was known to every householder in the United Kingdom. Owing to the',
#  'fact that an itinerary of the great man’s daily proceedings had',
#  'just been published, I knew exactly where to find him at this',
#  'moment. It was his hour for dictating to his secretary in his own',
#  'house.',
#  'I did not, of course, suppose that any young woman who chose to',
#  'come and ask for him would be at once admitted to the august',
#  'presence. But I had attended to that side of the matter. In the',
#  'card-tray in the hall of the Flemmings’ house I had observed the',
#  'card of the Marquis of Loamsley, England’s most famous sporting',
#  'peer. I had removed the card, cleaned it carefully with bread-crumbs,',
#  'and pencilled upon it the words: “Please give Miss Beddingfeld a',
#  'few moments of your time.” Adventuresses must not be too scrupulous',
#  'in their methods.',
#  'The thing worked. A powdered footman received the card and bore it',
#  'away. Presently a pale secretary appeared. I fenced with him',
#  'successfully. He retired defeated. He again reappeared and begged',
#  'me to follow him. I did so. I entered a large room, a',
#  'frightened-looking shorthand-typist fled past me like a visitant',
#  'from the spirit-world. Then the door shut and I was face to face',
#  'with Lord Nasby.',
#  'A big man. Big head. Big face. Big moustache. Big stomach. I pulled',
#  'myself together. I had not come here to comment on Lord Nasby’s',
#  'stomach. He was already roaring at me.',
#  '“Well, what is it? What does Loamsley want? You his secretary?',
#  'What’s it all about?”',
#  '“To begin with,” I said with as great an appearance of coolness as',
#  'I could manage, “I don’t know Lord Loamsley, and he certainly knows',
#  'nothing about me. I took his card from the tray in the house of',
#  'the people I’m staying with, and I wrote those words on it myself.',
#  'It was important that I should see you.”',
#  'For a moment it appeared to be a toss up as to whether Lord Nasby',
#  'had apoplexy or not. In the end, he swallowed twice and got over',
#  'it.',
#  '“I admire your coolness, young woman. Well, you see me! If you',
#  'interest me, you will continue to see me for exactly two minutes',
#  'longer.”',
#  '“That will be ample,” I replied. “And I shall interest you. It’s',
#  'the Mill House Mystery.”',
#  '“If you’ve found ‘The Man in the Brown Suit,’ write to the Editor,”',
#  'he interrupted hastily.',
#  '“If you will interrupt, I shall be more than two minutes,” I said',
#  'sternly. “I haven’t found ‘The Man in the Brown Suit,’ but I’m',
#  'quite likely to do so.”',
#  'In as few words as possible I put the facts of the Tube accident',
#  'and the conclusions I had drawn from them before him. When I had',
#  'finished he said unexpectedly:',
#  '“What do you know of brachycephalic heads?”',
#  'I mentioned Papa.',
#  '“The Monkey man? Eh? Well, you seem to have a head of some kind',
#  'upon your own shoulders, young woman. But it’s all pretty thin,',
#  'you know. Not much to go upon. And no use to us—as it stands.”',
#  '“I’m perfectly aware of that.”',
#  '“What d’you want, then?”',
#  '“I want a job on your paper to investigate this matter.”',
#  '“Can’t do that. We’ve got our own special man on it.”',
#  '“And I’ve got my own special knowledge.”',
#  '“What you’ve just told me, eh?”',
#  '“Oh, no, Lord Nasby. I’ve still got something up my sleeve.”',
#  '“Oh, you have, have you? You seem a bright sort of girl. Well, what',
#  'is it?”',
#  '“When this so-called doctor got into the lift, he dropped a piece',
#  'of paper. I picked it up. It smelt of moth balls. So did the dead',
#  'man. The doctor didn’t. So I saw at once that the doctor must have',
#  'taken it off the body. It had two words written on it and some',
#  'figures.”',
#  '“Let’s see it.”',
#  'Lord Nasby stretched out a careless hand.',
#  '“I think not,” I said, smiling. “It’s my find, you see.”',
#  '“I’m right. You _are_ a bright girl. Quite right to hang on to it.',
#  'No scruples about not handing it over to the police?”',
#  '“I went there to do so this morning. They persisted in regarding',
#  'the whole thing as having nothing to do with the Marlow affair, so',
#  'I thought that in the circumstances I was justified in retaining',
#  'the paper. Besides, the inspector put my back up.”',
#  '“Short-sighted man. Well, my dear girl, here’s all I can do for',
#  'you. Go on working on this line of yours. If you get',
#  'anything—anything that’s publishable—send it along and you shall',
#  'have your chance. There’s always room for real talent on the',
#  '_Daily Budget._ But you’ve got to make good first. See?”',
#  'I thanked him, and apologized for my methods.',
#  '“Don’t mention it. I rather like cheek—from a pretty girl. By the',
#  'way, you said two minutes and you’ve been three, allowing for',
#  'interruptions. For a woman, that’s quite remarkable! Must be your',
#  'scientific training.”',
#  'I was in the street again, breathing hard as though I had been',
#  'running. I found Lord Nasby rather wearing as a new acquaintance.',
#  'CHAPTER VI',
#  'I went home with a feeling of exultation. My scheme had succeeded',
#  'far better than I could possibly have hoped. Lord Nasby had been',
#  'positively genial. It only now remained for me to “Make good,” as',
#  'he expressed it. Once locked in my own room, I took out my precious',
#  'piece of paper and studied it attentively. Here was the clue to',
#  'the mystery.',
#  'To begin with, what did the figures represent? There were five of',
#  'them, and a dot after the first two. “Seventeen—one hundred and',
#  'twenty-two,” I murmured.',
#  'That did not seem to lead to anything.',
#  'Next I added them up. That is often done in works of fiction and',
#  'leads to surprising deductions.',
#  '“One and seven make eight and one is nine and two are eleven and',
#  'two are thirteen.”',
#  'Thirteen! Fateful number! Was this a warning to me to leave the',
#  'whole thing alone? Very possibly. Anyway, except as a warning, it',
#  'seemed to be singularly useless. I declined to believe that any',
#  'conspirator would take that way of writing thirteen in real life.',
#  'If he meant thirteen, he would write thirteen. “13”—like that.',
#  'There was a space between the one and the two. I accordingly',
#  'subtracted twenty-two from a hundred and seventy-one. The result',
#  'was a hundred and fifty-nine. I did it again and made it a hundred',
#  'and forty-nine. These arithmetical exercises were doubtless',
#  'excellent practice, but as regarded the solution of the mystery,',
#  'they seemed totally ineffectual. I left arithmetic alone, not',
#  'attempting fancy division or multiplication, and went on to the',
#  ...]

# %% [markdown]
# problem with paragraphing texts - no more possible due to removing /n fisrt

# %%
paragraphs = [p.strip() for p in book_1_wo_metadata.split('\n\n') if p.strip()]

# Create DataFrame
df_par = pd.DataFrame(paragraphs, columns=["Paragraph"])

# %%
df_par.tail()
# Out:
#                                            Paragraph
# 0  THE MAN IN THE BROWN SUIT\nBY THE SAME AUTHOR\...

# %% [markdown]
# ### Finding chapters

# %%
import re

# Extracting chapters

"""
# As some books are formatted differently, I need to have several options for identification the chapters, e.g:
PROLOGUE
CHAPTER I. I GO TO STYLES
I  DR. SHEPPARD AT THE BREAKFAST TABLE
I The Adventure of “The Western Star”
CHAPTER I.   THE YOUNG ADVENTURERS, LTD.
1 A Fellow Traveller
XVIII JIMMY'S ADVENTURES
1. The Man with the White Hair
CHAPTER I
11. A CHESS PROBLEM
1 ANTHONY CADE SIGNS ON
*       *       *       *       *

"""

chapter_regex = re.compile(
    r"^("
    r"PROLOGUE$|"
    r"CHAPTER\s+[IVXLCDM]+\.\s+[^\n]+|"    # CHAPTER I. Title
    r"CHAPTER\s+[IVXLCDM]+$|"              # CHAPTER I
    r"[IVXLCDM]{1,4}\s{1,}[A-Z][^\n]+|"    # I Title
    r"\d+\.\s+[A-Z][^\n]+|"                # 1. Title
    r"\d+\s+[A-Z][^\n]+|"                  # 1 Title
    r"\*+(\s+\*+)+$"                       # * * * * *
    r")$",
    re.MULTILINE
)

# %%
matches = re.findall(chapter_regex, book_1_wo_metadata)

print(matches)
# Out:
# [('1924\nCopyright, 1924,', ''), ('I SHOULD SOME DAY WRITE THE', ''), ('PROLOGUE', ''), ('CHAPTER I', ''), ('CHAPTER II', ''), ('CHAPTER III', ''), ('CHAPTER IV', ''), ('CHAPTER V', ''), ('CHAPTER VI', ''), ('CHAPTER VII', ''), ('CHAPTER VIII', ''), ('CHAPTER IX', ''), ('17. How the number persisted. It was on the 17th I had sailed from', ''), ('CHAPTER X', ''), ('CHAPTER XI', ''), ('CHAPTER XII', ''), ('CHAPTER XIII', ''), ('CHAPTER XIV', ''), ('CHAPTER XV', ''), ('CHAPTER XVI', ''), ('CHAPTER XVII', ''), ('CHAPTER XVIII', ''), ('CHAPTER XIX', ''), ('CHAPTER XX', ''), ('CHAPTER XXI', ''), ('CHAPTER XXII', ''), ('CHAPTER XXIII', ''), ('CHAPTER XXIV', ''), ('CHAPTER XXV', ''), ('CHAPTER XXVI', ''), ('CHAPTER XXVII', ''), ('CHAPTER XXVIII', ''), ('CHAPTER XXIX', ''), ('CHAPTER XXX', ''), ('CHAPTER XXXI', ''), ('CHAPTER XXXII', ''), ('CHAPTER XXXIII', ''), ('CHAPTER XXXIV', ''), ('CHAPTER XXXV', ''), ('CHAPTER XXXVI', '')]

# %%
# There are sometimes lines breaks which should be avoided

def contains_newline(text):
    return '\n' in text

# %%
matches = re.findall(chapter_regex, book_1_wo_metadata)

chapters = [m[0] for m in matches if not contains_newline(m[0])] # The outputs are tuples so we need the 1 part from them

# %%
print(chapters)
print(type(chapters))
print(len(chapters))
# Out:
# ['I SHOULD SOME DAY WRITE THE', 'PROLOGUE', 'CHAPTER I', 'CHAPTER II', 'CHAPTER III', 'CHAPTER IV', 'CHAPTER V', 'CHAPTER VI', 'CHAPTER VII', 'CHAPTER VIII', 'CHAPTER IX', '17. How the number persisted. It was on the 17th I had sailed from', 'CHAPTER X', 'CHAPTER XI', 'CHAPTER XII', 'CHAPTER XIII', 'CHAPTER XIV', 'CHAPTER XV', 'CHAPTER XVI', 'CHAPTER XVII', 'CHAPTER XVIII', 'CHAPTER XIX', 'CHAPTER XX', 'CHAPTER XXI', 'CHAPTER XXII', 'CHAPTER XXIII', 'CHAPTER XXIV', 'CHAPTER XXV', 'CHAPTER XXVI', 'CHAPTER XXVII', 'CHAPTER XXVIII', 'CHAPTER XXIX', 'CHAPTER XXX', 'CHAPTER XXXI', 'CHAPTER XXXII', 'CHAPTER XXXIII', 'CHAPTER XXXIV', 'CHAPTER XXXV', 'CHAPTER XXXVI']
# <class 'list'>
# 39

# %%
for m in chapters:
    print(m)
# Out:
# I SHOULD SOME DAY WRITE THE
# PROLOGUE
# CHAPTER I
# CHAPTER II
# CHAPTER III
# CHAPTER IV
# CHAPTER V
# CHAPTER VI
# CHAPTER VII
# CHAPTER VIII
# CHAPTER IX
# 17. How the number persisted. It was on the 17th I had sailed from
# CHAPTER X
# CHAPTER XI
# CHAPTER XII
# CHAPTER XIII
# CHAPTER XIV
# CHAPTER XV
# CHAPTER XVI
# CHAPTER XVII
# CHAPTER XVIII
# CHAPTER XIX
# CHAPTER XX
# CHAPTER XXI
# CHAPTER XXII
# CHAPTER XXIII
# CHAPTER XXIV
# CHAPTER XXV
# CHAPTER XXVI
# CHAPTER XXVII
# CHAPTER XXVIII
# CHAPTER XXIX
# CHAPTER XXX
# CHAPTER XXXI
# CHAPTER XXXII
# CHAPTER XXXIII
# CHAPTER XXXIV
# CHAPTER XXXV
# CHAPTER XXXVI

# %% [markdown]
# ### Finding the main content of the book

# %%
contents_start_idx = 0
contents_end_idx = 0
found_contents = False

# 1. Try to find the Contents section
for i, line in enumerate(lines):
    if "Contents" in line or "CONTENTS" in line:
        contents_start_idx = i + 1
        found_contents = True
    if line.strip() == list(chapters)[-1]:  # last chapter in list
        contents_end_idx = i
        break

# 2. If no "Contents" section was found, fall back to first chapter
if not found_contents:
    for i, line in enumerate(lines):
        if line.strip() in chapters:
            contents_start_idx = i
            break
    contents_end_idx = len(lines)  # default to end of file

# %%
# 3. Extract and join content
book_1_main_lines = lines[contents_start_idx:contents_end_idx]
book_1_main_content = "\n".join(book_1_main_lines)

# %%
print(book_1_main_content[:1000])
# Out:
# I SHOULD SOME DAY WRITE THE
# “MYSTERY OF THE MILL HOUSE”
# THE MAN IN THE BROWN SUIT
# THE MAN IN THE BROWN SUIT
# PROLOGUE
# Nadina, the Russian dancer who had taken Paris by storm, swayed to
# the sound of the applause, bowed and bowed again. Her narrow black
# eyes narrowed themselves still more, the long line of her scarlet
# mouth curved faintly upwards. Enthusiastic Frenchmen continued to
# beat the ground appreciatively as the curtain fell with a swish,
# hiding the reds and blues and magentas of the bizarre _décors._ In
# a swirl of blue and orange draperies the dancer left the stage. A
# bearded gentleman received her enthusiastically in his arms. It
# was the Manager.
# “Magnificent, _petite,_ magnificent,” he cried. “To-night you have
# surpassed yourself.” He kissed her gallantly on both cheeks in a
# somewhat matter-of-fact manner.
# Madame Nadina accepted the tribute with the ease of long habit and
# passed on to her dressing-room, where bouquets were heaped
# carelessly everywhere, marvellous garments of fu

# %% [markdown]
# ### Splitting the book into chapters and paragraphs

# %%
chapters
# Out:
# ['I SHOULD SOME DAY WRITE THE',
#  'PROLOGUE',
#  'CHAPTER I',
#  'CHAPTER II',
#  'CHAPTER III',
#  'CHAPTER IV',
#  'CHAPTER V',
#  'CHAPTER VI',
#  'CHAPTER VII',
#  'CHAPTER VIII',
#  'CHAPTER IX',
#  '17. How the number persisted. It was on the 17th I had sailed from',
#  'CHAPTER X',
#  'CHAPTER XI',
#  'CHAPTER XII',
#  'CHAPTER XIII',
#  'CHAPTER XIV',
#  'CHAPTER XV',
#  'CHAPTER XVI',
#  'CHAPTER XVII',
#  'CHAPTER XVIII',
#  'CHAPTER XIX',
#  'CHAPTER XX',
#  'CHAPTER XXI',
#  'CHAPTER XXII',
#  'CHAPTER XXIII',
#  'CHAPTER XXIV',
#  'CHAPTER XXV',
#  'CHAPTER XXVI',
#  'CHAPTER XXVII',
#  'CHAPTER XXVIII',
#  'CHAPTER XXIX',
#  'CHAPTER XXX',
#  'CHAPTER XXXI',
#  'CHAPTER XXXII',
#  'CHAPTER XXXIII',
#  'CHAPTER XXXIV',
#  'CHAPTER XXXV',
#  'CHAPTER XXXVI']

# %%
import pandas as pd

def extract_chapters_and_paragraphs(text, chapters_list, book_id=1, book_title="Unknown Title", paragraph_num = 5):
    lines = text.splitlines()
    stripped_lines = [line.strip() for line in lines]

    # Step 1: Find indexes of each chapter title in the lines
    chapter_indices = []
    for i, line in enumerate(stripped_lines):
        if line in chapters_list:
            chapter_indices.append((line, i))

    # Step 2: Build chapter blocks
    chapters = []
    for idx, (chapter_title, start_idx) in enumerate(chapter_indices):
        end_idx = chapter_indices[idx + 1][1] if idx + 1 < len(chapter_indices) else len(stripped_lines)
        chapter_lines = stripped_lines[start_idx + 1:end_idx]
        chapter_text = "\n".join(chapter_lines).strip()

        chapters.append({
            "chapter_title": chapter_title,
            "chapter_text": chapter_text
        })

    final_rows = []

    for chap_id, chap in enumerate(chapters, 1):
      # Remove newlines and split text into words
      words = chap["chapter_text"].replace('\n', ' ').split()
      total_words = len(words)

      # Compute base chunk size
      chunk_size = total_words // paragraph_num
      remainder = total_words % paragraph_num

      start = 0
      for para_id in range(1, paragraph_num + 1):
        # Distribute the remainder across first few paragraphs
        end = start + chunk_size + (1 if para_id <= remainder else 0)
        para_words = words[start:end]
        paragraph_text = " ".join(para_words)

        final_rows.append({
            "book_id": book_id,
            "book_title": book_title,
            "chapter_id": chap_id,
            "chapter_title": chap["chapter_title"],
            "paragraph_id": para_id,
            "paragraph_text": paragraph_text
        })

        start = end

    return pd.DataFrame(final_rows)

# %%
book_text = book_1_main_content
book_title = df.loc[0,"book_title"]
book_id = df.loc[0,"book_id"]
chapter_list = chapters
paragraph_num = 5

chapter_df = extract_chapters_and_paragraphs(book_text, chapter_list, book_id, book_title, paragraph_num)

# %%
chapter_df
# Out:
#      book_id                 book_title  chapter_id  \
# 0          0  The man in the Brown Suit           1
# 1          0  The man in the Brown Suit           1
# 2          0  The man in the Brown Suit           1
# 3          0  The man in the Brown Suit           1
# 4          0  The man in the Brown Suit           1
# ..       ...                        ...         ...
# 190        0  The man in the Brown Suit          39
# 191        0  The man in the Brown Suit          39
# 192        0  The man in the Brown Suit          39
# 193        0  The man in the Brown Suit          39
# 194        0  The man in the Brown Suit          39
#
#                    chapter_title  paragraph_id  \
# 0    I SHOULD SOME DAY WRITE THE             1
# 1    I SHOULD SOME DAY WRITE THE             2
# 2    I SHOULD SOME DAY WRITE THE             3
# 3    I SHOULD SOME DAY WRITE THE             4
# 4    I SHOULD SOME DAY WRITE THE             5
# ..                           ...           ...
# 190                CHAPTER XXXVI             1
# 191                CHAPTER XXXVI             2
# 192                CHAPTER XXXVI             3
# 193                CHAPTER XXXVI             4
# 194                CHAPTER XXXVI             5
#
#                                         paragraph_text
# 0                                 “MYSTERY OF THE MILL
# 1                                    HOUSE” THE MAN IN
# 2                                       THE BROWN SUIT
# 3                                           THE MAN IN
# 4                                       THE BROWN SUIT
# ..                                                 ...
# 190  That was two years ago. We still live on the i...
# 191  comfortably putting on weight amidst the flesh...
# 192  Park Lane. I should just like to say that I be...
# 193  point on which he and I do not see eye to eye....
# 194  but women shouldn’t pretend to be in love when...
#
# [195 rows x 6 columns]

# %%
# all_books_df = pd.concat([df, chapter_df], ignore_index=True)

# %%
# all_books_df

# %% [markdown]
# ## Cleaning and Splitting All Books to Create a Common Dataframe

# %%
# Functions created based on 1 book testing
def delete_metadata(book):
  cleaned_book = "\n".join([line.strip() for line in book.split("\n") if line.strip()])
  lines = cleaned_book_1.split("\n")
  start_idx = 0
  end_idx = 0
  for i, line in enumerate(lines):
    if "*** START OF THE PROJECT GUTENBERG EBOOK" in line:
      start_idx = i + 1
    if "*** END OF THE PROJECT GUTENBERG EBOOK" in line:
      end_idx = i
      break
  book_wo_metadata = "\n".join(lines[start_idx:end_idx])
  return book_wo_metadata

def contains_newline(text):
    return '\n' in text

def find_chapters(book_wo_metadata, chapter_regex):
  matches = re.findall(chapter_regex, book_wo_metadata)
  chapters = [m[0] for m in matches if not contains_newline(m[0])] # The outputs are tuples so we need the 1 part from them
  return chapters

def find_main_content(book_wo_metadata, chapters):
  lines = book_1_wo_metadata.split("\n")
  contents_start_idx = 0
  contents_end_idx = 0
  found_contents = False
  for i, line in enumerate(lines):
    if "Contents" in line or "CONTENTS" in line:
        contents_start_idx = i + 1
        found_contents = True
    if line.strip() == list(chapters)[-1]:  # last chapter in list
        contents_end_idx = i
        break
  if not found_contents:
    for i, line in enumerate(lines):
        if line.strip() in chapters:
            contents_start_idx = i
            break
    contents_end_idx = len(lines)
    book_main_lines = lines[contents_start_idx:contents_end_idx]
    book_main_content = "\n".join(book_main_lines)
    return book_main_content

# %%
print(chapter_regex)
# Out:
# re.compile('^(PROLOGUE$|CHAPTER\\s+[IVXLCDM]+\\.\\s+[^\\n]+|CHAPTER\\s+[IVXLCDM]+$|[IVXLCDM]{1,4}\\s{1,}[A-Z][^\\n]+|\\d+\\.\\s+[A-Z][^\\n]+|\\d+\\s+[A-Z][^\\n]+|\\*+(\\s+\\*+)+$)$', re.MULTILINE)

# %%
book_dfs = []

for i in range(len(df)):
    try:
        # Get book data from DataFrame row
        book_text = df.iloc[i]["content"]
        book_title = df.iloc[i]["book_title"]
        book_id = df.iloc[i]["book_id"]

        # Step-by-step processing
        book_wo_metadata = delete_metadata(book_text)
        chapter_list = find_chapters(book_wo_metadata, chapter_regex)
        book_main_content = find_main_content(book_wo_metadata, chapter_list)

        # Split into paragraphs
        paragraph_num = 5
        book_df = extract_chapters_and_paragraphs(
            text=book_main_content,
            chapters_list=chapter_list,
            book_id=book_id,
            book_title=book_title,
            paragraph_num=paragraph_num
        )

        book_dfs.append(book_df)

    except Exception as e:
        print(f"[ERROR] Book ID {df.iloc[i]['book_id']} - {df.iloc[i]['book_title']}: {e}")

# %%
final_df = pd.concat(book_dfs, ignore_index=True)

# %%
final_df
# Out:
#       book_id                   book_title  chapter_id  \
# 0           0    The man in the Brown Suit           1
# 1           0    The man in the Brown Suit           1
# 2           0    The man in the Brown Suit           1
# 3           0    The man in the Brown Suit           1
# 4           0    The man in the Brown Suit           1
# ...       ...                          ...         ...
# 2530       12  The Plymouth Express Affair          39
# 2531       12  The Plymouth Express Affair          39
# 2532       12  The Plymouth Express Affair          39
# 2533       12  The Plymouth Express Affair          39
# 2534       12  The Plymouth Express Affair          39
#
#                     chapter_title  paragraph_id  \
# 0     I SHOULD SOME DAY WRITE THE             1
# 1     I SHOULD SOME DAY WRITE THE             2
# 2     I SHOULD SOME DAY WRITE THE             3
# 3     I SHOULD SOME DAY WRITE THE             4
# 4     I SHOULD SOME DAY WRITE THE             5
# ...                           ...           ...
# 2530                CHAPTER XXXVI             1
# 2531                CHAPTER XXXVI             2
# 2532                CHAPTER XXXVI             3
# 2533                CHAPTER XXXVI             4
# 2534                CHAPTER XXXVI             5
#
#                                          paragraph_text
# 0                                  “MYSTERY OF THE MILL
# 1                                     HOUSE” THE MAN IN
# 2                                        THE BROWN SUIT
# 3                                            THE MAN IN
# 4                                        THE BROWN SUIT
# ...                                                 ...
# 2530  That was two years ago. We still live on the i...
# 2531  comfortably putting on weight amidst the flesh...
# 2532  Park Lane. I should just like to say that I be...
# 2533  point on which he and I do not see eye to eye....
# 2534  but women shouldn’t pretend to be in love when...
#
# [2535 rows x 6 columns]

# %%
# Save to CSV
final_df.to_csv("processed_books.csv", index=False)

# Load it back later
final_df = pd.read_csv("processed_books.csv")

# %%
final_df.to_excel("processed_books.xlsx", index=False)
from google.colab import files
files.download("processed_books.xlsx")

# %% [markdown]
# ### Tokenization and Lemmatisation

# %%
! python -m spacy download en_core_web_trf
# Out:
# Collecting en-core-web-trf==3.7.3
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.11/dist-packages (from en-core-web-trf==3.7.3) (3.7.5)
# Requirement already satisfied: spacy-curated-transformers<0.3.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from en-core-web-trf==3.7.3) (0.2.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.26.4)
# Requirement already satisfied: curated-transformers<0.2.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (0.1.1)
# Requirement already satisfied: curated-tokenizers<0.1.0,>=0.0.9 in /usr/local/lib/python3.11/dist-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (0.0.9)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.5.1+cu124)
# Requirement already satisfied: regex>=2022 in /usr/local/lib/python3.11/dist-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2024.11.6)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load("en_core_web_trf")

import en_core_web_trf
nlp = en_core_web_trf.load()

doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])
# Out:
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# [('This', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('sentence', 'NOUN'), ('.', 'PUNCT')]

# %%
import spacy
print(spacy.info())  # Lists installed models
# Out:
# {'spacy_version': '3.7.5', 'location': '/usr/local/lib/python3.11/dist-packages/spacy', 'platform': 'Linux-6.1.85+-x86_64-with-glibc2.35', 'python_version': '3.11.11', 'pipelines': {'en_core_web_lg': '3.7.1', 'en_core_web_trf': '3.7.3', 'en_core_web_sm': '3.7.1'}}

# %%
processed_book_1 = nlp(book_1_main_content)
# Out:
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):

# %%
# Tokenization

tokens = []

for token in processed_book_1:
  tokens.append(token.text)

unique_tokens = set(tokens)

print(f'Number of tokens in the preproccessed text: {len(tokens)}')
print(f'Number of unique tokens  in the preproccessed text: {len(unique_tokens)}\n')

print(tokens[:200])

# Lemmatisation

# lemmatised_tokens = []

# for token in processed_book_1:
#   lemmatised_tokens.append(token.lemma_)

# print(lemmatised_tokens[:200])
# Out:
# Number of tokens in the preproccessed text: 87240
# Number of unique tokens  in the preproccessed text: 6476
#
# ['The', 'Seven', 'Dials', 'Mystery', 'Agatha', 'Christie', 'PRINTING', 'HISTORY', '_', 'Dodd', ',', 'Mead', 'edition', 'published', 'March', '1929', '_', '_', 'Grosset', '&', 'Dunlap', 'edition', 'published', 'February', '1930', '_', '_', 'American', 'Mercury', 'edition', 'published', 'October', '1942', '_', '_', 'Bantam', 'edition', '/', 'January', '1964', '_', '_', 'New', 'Bantam', 'edition', '/', 'March', '1976', '_', '_', 'The', 'Agatha', 'Christie', 'Mystery', 'Collection', '/', 'September', '1986', '_', '_', 'All', 'rights', 'reserved', '.', '_', '_', 'Copyright', '1929', 'by', 'Dodd', ',', 'Mead', '&', 'Company', ',', 'Inc.', '_', '_', 'Copyright', 'renewed', '©', '1957', 'by', 'Agatha', 'Christie', 'Mallowan', '.', '_', 'PRINTED', 'IN', 'THE', 'UNITED', 'STATES', 'OF', 'AMERICA', 'CONTENTS', 'I', 'ON', 'EARLY', 'RISING', 'II', 'CONCERNING', 'ALARUM', 'CLOCKS', 'III', 'THE', 'JOKE', 'THAT', 'FAILED', 'IV', 'A', 'LETTER', 'V', 'THE', 'MAN', 'IN', 'THE', 'ROAD', 'VI', 'SEVEN', 'DIALS', 'AGAIN', 'VII', 'BUNDLE', 'PAYS', 'A', 'CALL', 'VIII', 'VISITORS', 'FOR', 'JIMMY', 'IX', 'PLANS', 'X', 'BUNDLE', 'VISITS', 'SCOTLAND', 'YARD', 'XI', 'DINNER', 'WITH', 'BILL', 'XII', 'INQUIRIES', 'AT', 'CHIMNEYS', 'XIII', 'THE', 'SEVEN', 'DIALS', 'CLUB', 'XIV', 'THE', 'MEETING', 'OF', 'THE', 'SEVEN', 'DIALS', 'XV', 'THE', 'INQUEST', 'XVI', 'THE', 'HOUSE', 'PARTY', 'AT', 'THE', 'ABBEY', 'XVII', 'AFTER', 'DINNER', 'XVIII', 'JIMMY', "'S", 'ADVENTURES', 'XIX', 'BUNDLE', "'S", 'ADVENTURES', 'XX', 'LORAINE', "'S", 'ADVENTURES', 'XXI', 'THE', 'RECOVERY', 'OF', 'THE', 'FORMULA', 'XXII', 'THE', 'COUNTESS', 'RADZKY', "'S", 'STORY', 'XXIII', 'SUPERINTENDENT', 'BATTLE', 'IN', 'CHARGE']

# %%
# true casing

def truecase_text(text):
    doc = nlp(text)
    truecased_tokens = []
    for token in doc:
        if token.ent_type_ in ["PERSON", "GPE", "ORG"]:  # Named Entities should be capitalized
            truecased_tokens.append(token.text.title())
        elif token.is_sent_start:  # Capitalize the first word of each sentence
            truecased_tokens.append(token.text.capitalize())
        else:
            truecased_tokens.append(token.text.lower())

    return " ".join(truecased_tokens)

# Example usage
text = "john and mary went to new york city last summer."
truecased_text = truecase_text(text)
print(truecased_text)
# Out:
# John and Mary went to New York City last summer .
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):

# %% [markdown]
# ### Removing stopwords and punctuation

# %%
import nltk
import string
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(stop_words)
print(punctuation)
# Out:
# {'or', 'the', 'these', 'ours', "it's", 'for', "mustn't", 've', 'few', 'those', 'they', 'yourselves', 'myself', 're', 'most', "you'll", 'mustn', 'not', 'where', 'no', 'but', 'own', 'up', 'was', "hasn't", 'm', "he'll", 'has', 'mightn', 'off', "that'll", 'both', 'him', 'until', 'in', 'some', 'hers', 'who', 'does', "didn't", 'too', 'our', "weren't", 'once', "she's", 'very', 'only', 'a', "we'll", 'didn', "should've", 'before', 'should', 'why', 'whom', "doesn't", 'yours', 'an', 'been', 'because', 'we', 'below', 'of', 'their', 'against', 'don', 'hasn', 'while', "it'll", 'such', "shouldn't", "don't", 'there', 'being', "i've", "shan't", "he'd", 'needn', 'she', "haven't", 'he', 'himself', 'i', 'y', 'themselves', "you've", 'so', 'then', 'wouldn', 'about', 'ain', 'all', 'wasn', 'won', 'above', "she'll", 'isn', 'theirs', 'through', 'during', 'other', "wouldn't", 'can', 'me', 'this', 'll', 'yourself', 'each', 'its', "we're", 'again', 'you', 'your', 'down', 'had', "couldn't", 'did', 'shan', 'out', "i'll", "he's", 'ma', 'on', "they'll", 'which', "it'd", 'now', 'herself', 'over', 'more', 'her', 'is', "mightn't", 'o', 'it', "they've", "we've", 'be', 'itself', 'if', "they'd", 'my', "you'd", 'd', "needn't", 'after', 'shouldn', 'from', 'how', 'nor', 'at', 'further', 'haven', "isn't", 'than', "aren't", 'that', 'under', 'and', "hadn't", 'his', "wasn't", 'were', "i'd", 'hadn', 'having', 'between', "i'm", 'ourselves', 'doing', 'by', 's', 'any', "she'd", 'couldn', "they're", 'them', 'aren', 'as', 'do', 'same', 'here', 'into', "we'd", 'just', 't', 'weren', "you're", "won't", 'with', 'when', 'are', 'doesn', 'will', 'what', 'have', 'to', 'am'}
# {'<', '=', '&', '}', ':', '/', '~', '$', '>', '+', ']', ')', ';', '@', '\\', '|', '(', '.', '%', '!', ',', '*', '-', '`', '_', '#', '^', '{', '[', '?', "'", '"'}

# %%
# Removing punctutation and stopwords

clean_tokens = []
for token in tokens:
  if token in punctuation or token in stop_words:
    continue
  else:
    clean_tokens.append(token)

print(clean_tokens[:100])

# clean_lemmatised_tokens = []
# for token in lemmatised_tokens:
#   if token in punctuation or token in stop_words:
#     continue
#   else:
#     clean_lemmatised_tokens.append(token)

# print(clean_lemmatised_tokens[:100])

print(len(tokens))
print(len(clean_tokens))
# print(len(clean_lemmatised_tokens))
# Out:
# ['The', 'Seven', 'Dials', 'Mystery', 'Agatha', 'Christie', 'PRINTING', 'HISTORY', 'Dodd', 'Mead', 'edition', 'published', 'March', '1929', 'Grosset', 'Dunlap', 'edition', 'published', 'February', '1930', 'American', 'Mercury', 'edition', 'published', 'October', '1942', 'Bantam', 'edition', 'January', '1964', 'New', 'Bantam', 'edition', 'March', '1976', 'The', 'Agatha', 'Christie', 'Mystery', 'Collection', 'September', '1986', 'All', 'rights', 'reserved', 'Copyright', '1929', 'Dodd', 'Mead', 'Company', 'Inc.', 'Copyright', 'renewed', '©', '1957', 'Agatha', 'Christie', 'Mallowan', 'PRINTED', 'IN', 'THE', 'UNITED', 'STATES', 'OF', 'AMERICA', 'CONTENTS', 'I', 'ON', 'EARLY', 'RISING', 'II', 'CONCERNING', 'ALARUM', 'CLOCKS', 'III', 'THE', 'JOKE', 'THAT', 'FAILED', 'IV', 'A', 'LETTER', 'V', 'THE', 'MAN', 'IN', 'THE', 'ROAD', 'VI', 'SEVEN', 'DIALS', 'AGAIN', 'VII', 'BUNDLE', 'PAYS', 'A', 'CALL', 'VIII', 'VISITORS', 'FOR']
# 87240
# 42098

# %%
#Converting roman numbers into arabic

import roman

print(roman.fromRoman("XIV"))  # Output: 14
print(roman.toRoman(27))  # Output: XXVII

for token in tokens:
  if token in roman:
    token = roman.fromRoman(token)
  continue

print(tokens)

# %% [markdown]
# ## NER on book content

# %% [markdown]
# ### NER or raw book main content

# %%
# NER to find all entities

ner_list = []

i = 1
entities_list = []
entities_freq_dict = {}

for ent in processed_book_1.ents:
    print(f'{i}) {ent.text} = {ent.label_}')
    i += 1
    entities_list.append(ent.label_)

for ent_label in entities_list:
  if ent_label not in entities_freq_dict:
    entities_freq_dict[ent_label] = 0
  entities_freq_dict[ent_label] += 1

print(f'The frequencies of unique named entity labels: {entities_freq_dict}')
# Out:
# 1) The Seven Dials Mystery = WORK_OF_ART
# 2) Agatha Christie = PERSON
# 3) Dodd = PERSON
# 4) Mead = PERSON
# 5) March 1929 = DATE
# 6) Grosset & Dunlap = ORG
# 7) February 1930 = DATE
# 8) American Mercury = ORG
# 9) October 1942 = DATE
# 10) Bantam = ORG
# 11) /January 1964 = DATE
# 12) Bantam = ORG
# 13) March 1976 = DATE
# 14) The Agatha Christie Mystery Collection = WORK_OF_ART
# 15) September 1986 = DATE
# 16) 1929 = DATE
# 17) Dodd, Mead & Company, Inc. = ORG
# 18) 1957 = DATE
# 19) Agatha Christie Mallowan = PERSON
# 20) THE UNITED STATES OF AMERICA = GPE
# 21) II = CARDINAL
# 22) III = CARDINAL
# 23) SCOTLAND = GPE
# 24) XVI = DATE
# 25) THE ABBEY XVII = EVENT
# 26) XXIII = DATE
# 27) GEORGE LOMAX XXX = PERSON
# 28) CATERHAM = PERSON
# 29) SEVEN = CARDINAL
# 30) Jimmy Thesiger = PERSON
# 31) Chimneys = FAC
# 32) two = CARDINAL
# 33) Tredwell = PERSON
# 34) Tredwell = PERSON
# 35) Jimmy = PERSON
# 36) Tredwell = PERSON
# 37) Wade = PERSON
# 38) Jimmy = PERSON
# 39) Jimmy = PERSON
# 40) a punctual nine-thirty = TIME
# 41) a quarter past eleven = TIME
# 42) Coote = PERSON
# 43) Coote = PERSON
# 44) the first ten years = DATE
# 45) Oswald Coote = PERSON
# 46) morning = TIME
# 47) eight o'clock = TIME
# 48) Coote = PERSON
# 49) Oswald = PERSON
# 50) Coote = PERSON
# 51) Rachel = PERSON
# 52) Coote = PERSON
# 53) Coote = PERSON
# 54) Oswald = PERSON
# 55) Oswald Coote = PERSON
# 56) first = ORDINAL
# 57) Works = ORG
# 58) Oswald = PERSON
# 59) Works = ORG
# 60) England = GPE
# 61) Chimneys = ORG
# 62) two years = DATE
# 63) Oswald = PERSON
# 64) Coote = PERSON
# 65) three = CARDINAL
# 66) Coote = PERSON
# 67) Coote = PERSON
# 68) Jimmy Thesiger = PERSON
# 69) Coote = PERSON
# 70) a few moments = TIME
# 71) MacDonald = PERSON
# 72) MacDonald = PERSON
# 73) Coote = PERSON
# 74) morning = TIME
# 75) MacDonald = PERSON
# 76) night = TIME
# 77) MacDonald = PERSON
# 78) Coote = PERSON
# 79) yesterday = DATE
# 80) MacDonald = PERSON
# 81) Caterham = GPE
# 82) MacDonald = PERSON
# 83) Coote = PERSON
# 84) Coote = PERSON
# 85) MacDonald = PERSON
# 86) Coote = PERSON
# 87) Oswald = PERSON
# 88) Coote = PERSON
# 89) England = GPE
# 90) Francis Drake = PERSON
# 91) Armada = PRODUCT
# 92) MacDonald = PERSON
# 93) MacDonald = PERSON
# 94) Coote = PERSON
# 95) MacDonald = PERSON
# 96) William = PERSON
# 97) Coote = PERSON
# 98) Scottish = NORP
# 99) MacDonald = PERSON
# 100) MacDonald = PERSON
# 101) Coote = PERSON
# 102) MacDonald = PERSON
# 103) Coote = PERSON
# 104) MacDonald = PERSON
# 105) William = PERSON
# 106) Coote = PERSON
# 107) MacDonald = PERSON
# 108) Coote = PERSON
# 109) MacDonald = PERSON
# 110) Coote = PERSON
# 111) Jimmy Thesiger = PERSON
# 112) morning = TIME
# 113) Coote = PERSON
# 114) Coote = PERSON
# 115) Tredwell = PERSON
# 116) Coote = PERSON
# 117) Wade = PERSON
# 118) Wade = PERSON
# 119) Tredwell = PERSON
# 120) eleven thirty = TIME
# 121) yesterday = DATE
# 122) morning = TIME
# 123) Wade = PERSON
# 124) Coote = PERSON
# 125) twenty minutes to twelve = TIME
# 126) Tredwell = PERSON
# 127) one o'clock = TIME
# 128) Church = ORG
# 129) Turk = NORP
# 130) Coote = PERSON
# 131) second = ORDINAL
# 132) that morning = TIME
# 133) Coote = PERSON
# 134) Oswald = PERSON
# 135) Bateman = PERSON
# 136) Coote = PERSON
# 137) Rupert Bateman = PERSON
# 138) Oswald = PERSON
# 139) Jimmy Thesiger = PERSON
# 140) Morning = TIME
# 141) Pongo = PERSON
# 142) Jimmy = PERSON
# 143) Bateman = PERSON
# 144) Jimmy = PERSON
# 145) Bateman = PERSON
# 146) Bateman = PERSON
# 147) Pongo = PERSON
# 148) Pongo = PERSON
# 149) Jimmy = PERSON
# 150) Jimmy = PERSON
# 151) three = CARDINAL
# 152) two = CARDINAL
# 153) one = CARDINAL
# 154) Helen = PERSON
# 155) Nancy = PERSON
# 156) third = ORDINAL
# 157) Socks = PERSON
# 158) two = CARDINAL
# 159) Bill Eversleigh = PERSON
# 160) Ronny Devereux = PERSON
# 161) Nancy = PERSON
# 162) Helen = PERSON
# 163) Jimmy = PERSON
# 164) Bill Eversleigh = PERSON
# 165) Gerry Wade = PERSON
# 166) Ronny Devereux = PERSON
# 167) Socks = PERSON
# 168) Coote = PERSON
# 169) Bill = PERSON
# 170) Jimmy = PERSON
# 171) Socks = PERSON
# 172) Jimmy = PERSON
# 173) to-morrow morning = TIME
# 174) Ronny = PERSON
# 175) seven = TIME
# 176) Tredwell = PERSON
# 177) Coote = PERSON
# 178) Bill = PERSON
# 179) Bill = PERSON
# 180) Oswald = PERSON
# 181) Pongo = PERSON
# 182) Gerry = PERSON
# 183) Jimmy = PERSON
# 184) Socks = PERSON
# 185) Ronny = PERSON
# 186) Bill = PERSON
# 187) Pongo = PERSON
# 188) Jimmy = PERSON
# 189) Pongo = PERSON
# 190) Pongo = PERSON
# 191) Bateman = PERSON
# 192) Ronny = PERSON
# 193) about a dozen = CARDINAL
# 194) Gerry Wade = PERSON
# 195) Bill = PERSON
# 196) Market Basing = FAC
# 197) Bill = PERSON
# 198) Ronny = PERSON
# 199) Jimmy = PERSON
# 200) Coote = PERSON
# 201) Jimmy = PERSON
# 202) Nancy = PERSON
# 203) Helen = PERSON
# 204) Coote = PERSON
# 205) next week = DATE
# 206) Caterham = PERSON
# 207) Bill = PERSON
# 208) Coote = PERSON
# 209) Bundle Brent = PERSON
# 210) Caterham = PERSON
# 211) Socks = PERSON
# 212) Coote = PERSON
# 213) Gerald Wade = PERSON
# 214) Jimmy Thesiger = PERSON
# 215) Gerald Wade = PERSON
# 216) Jimmy = PERSON
# 217) Morning = TIME
# 218) Coote = PERSON
# 219) Gerald Wade = PERSON
# 220) Market Basing = FAC
# 221) Coote = PERSON
# 222) Coote = PERSON
# 223) early in the morning = TIME
# 224) Wade = PERSON
# 225) Coote = PERSON
# 226) Wade = PERSON
# 227) Coote = PERSON
# 228) Wade = PERSON
# 229) Coote = PERSON
# 230) Wade = PERSON
# 231) Coote = PERSON
# 232) Oswald = PERSON
# 233) Wade = PERSON
# 234) Foreign Office = ORG
# 235) eleven o'clock = TIME
# 236) Coote = PERSON
# 237) Coote = PERSON
# 238) Coote = PERSON
# 239) Market Basing = ORG
# 240) Bundle = PRODUCT
# 241) Bill = PERSON
# 242) Jimmy = PERSON
# 243) Ronny = PERSON
# 244) Ronny = PERSON
# 245) Bundle = PERSON
# 246) Bill = PERSON
# 247) Socks = PERSON
# 248) Murgatroyd = PERSON
# 249) Murgatroyd's Stores = ORG
# 250) 10/6 = CARDINAL
# 251) Murgatroyd = PERSON
# 252) Nancy = PERSON
# 253) one day = DATE
# 254) Helen = PERSON
# 255) Socks = PERSON
# 256) Bill = PERSON
# 257) Jimmy = PERSON
# 258) the next five minutes = TIME
# 259) six = CARDINAL
# 260) Ronny = PERSON
# 261) Pongo = PERSON
# 262) Bill = PERSON
# 263) Coote = PERSON
# 264) Gerry = PERSON
# 265) Coote = PERSON
# 266) MacDonald = PERSON
# 267) Murgatroyd = PERSON
# 268) II = CARDINAL
# 269) Coote = PERSON
# 270) Oswald = PERSON
# 271) Oswald = PERSON
# 272) one = CARDINAL
# 273) Our Captains of Industry = WORK_OF_ART
# 274) 7 = CARDINAL
# 275) Rupert Bateman = PERSON
# 276) Oswald = PERSON
# 277) Coote = PERSON
# 278) Gerald Wade = PERSON
# 279) Oswald = PERSON
# 280) Bateman = PERSON
# 281) Two = CARDINAL
# 282) Double = ORDINAL
# 283) Three = CARDINAL
# 284) Gerald Wade = PERSON
# 285) Coote = PERSON
# 286) Gerald Wade's = PERSON
# 287) Jimmy = PERSON
# 288) Bill = PERSON
# 289) one = CARDINAL
# 290) One = CARDINAL
# 291) Gerry Wade = PERSON
# 292) eight = CARDINAL
# 293) the day = DATE
# 294) 6:30 A.M. = TIME
# 295) Bill = PERSON
# 296) Socks = PERSON
# 297) Jimmy = PERSON
# 298) Jimmy = PERSON
# 299) Pongo = PERSON
# 300) Bateman = PERSON
# 301) Jimmy = PERSON
# 302) Pongo = PERSON
# 303) Ronny Devereux = PERSON
# 304) Eight = CARDINAL
# 305) Gerry = PERSON
# 306) Jimmy Thesiger = PERSON
# 307) Ronny = PERSON
# 308) Gerald = PERSON
# 309) Jimmy = PERSON
# 310) Gerry = PERSON
# 311) Ronny = PERSON
# 312) Jimmy = PERSON
# 313) second = ORDINAL
# 314) Pongo = PRODUCT
# 315) Bill = PERSON
# 316) Jimmy = PERSON
# 317) Socks = PERSON
# 318) Pongo = PERSON
# 319) Jimmy = PERSON
# 320) Pongo = PERSON
# 321) Pongo = PERSON
# 322) Jimmy = PERSON
# 323) one = CARDINAL
# 324) Bridge = FAC
# 325) Oswald = PERSON
# 326) Coote = PERSON
# 327) Gerald Wade = PERSON
# 328) Pongo = PERSON
# 329) Bill Eversleigh = PERSON
# 330) Ronny Devereux = PERSON
# 331) about twelve = TIME
# 332) about an hour = TIME
# 333) three in the morning = TIME
# 334) Maria = PERSON
# 335) Oswald = PERSON
# 336) Coote = PERSON
# 337) Oswald = PERSON
# 338) Gerald Wade's = PERSON
# 339) Four = CARDINAL
# 340) four = CARDINAL
# 341) Gerald Wade = PERSON
# 342) Coote = PERSON
# 343) Maria = PERSON
# 344) Oswald = PERSON
# 345) Coote = PERSON
# 346) Gerald Wade = PERSON
# 558) Jimmy = PERSON
# 559) Gerry = PERSON
# 560) Ronny = PERSON
# 561) Chimneys = FAC
# 562) Jimmy = PERSON
# 563) Coote = PERSON
# 564) Jimmy = PERSON
# 565) Coote = PERSON
# 566) Jimmy = PERSON
# 567) Ronny = PERSON
# 568) Gerald Wade's = PERSON
# 569) Jimmy = PERSON
# 570) Jimmy = PERSON
# 571) Jimmy = PERSON
# 572) Ronny Devereux = PERSON
# 573) Jimmy = PERSON
# 574) Jimmy = PERSON
# 575) one = CARDINAL
# 576) Gerry Wade = PERSON
# 577) Ronny = PERSON
# 578) Jimmy = PERSON
# 579) Ronny = PERSON
# 580) Jimmy = PERSON
# 581) seven = CARDINAL
# 582) eight = CARDINAL
# 583) One = CARDINAL
# 584) Ronny = PERSON
# 585) Seven = CARDINAL
# 586) eight = CARDINAL
# 587) Jimmy = PERSON
# 588) IV = CARDINAL
# 589) Caterham = PERSON
# 590) Eileen Brent = PERSON
# 591) Bundle = PERSON
# 592) Coote = PERSON
# 593) Caterham = PERSON
# 594) Bundle = PERSON
# 595) Bundle = PERSON
# 596) Caterham = PERSON
# 597) Bundle = PERSON
# 598) Bundle = PERSON
# 599) Caterham = PERSON
# 600) Caterham = PERSON
# 601) Brents = PERSON
# 602) second = ORDINAL
# 603) four years ago = DATE
# 604) George Lomax = PERSON
# 605) Coote = PERSON
# 606) Caterham = PERSON
# 607) Bundle = PERSON
# 608) Bundle = PERSON
# 609) four years ago = DATE
# 610) Tredwell = ORG
# 611) Gerry Wade = PERSON
# 612) Bundle = PERSON
# 613) Bill = PERSON
# 614) Caterham = PERSON
# 615) Bundle = PERSON
# 616) Caterham = PERSON
# 617) Raglan = PERSON
# 618) Bundle = PERSON
# 619) Caterham = PERSON
# 620) Wade = PERSON
# 621) one = CARDINAL
# 622) Bundle = PERSON
# 623) Caterham = PERSON
# 624) Bundle = PERSON
# 625) MacDonald = PERSON
# 626) Bundle = PERSON
# 627) MacDonald = PERSON
# 628) Bundle = PERSON
# 629) MacDonald = PERSON
# 630) MacDonald = PERSON
# 631) William = PERSON
# 632) Bundle = PERSON
# 633) Bundle = PERSON
# 634) MacDonald = PERSON
# 635) Caterham = PERSON
# 636) MacDonald = PERSON
# 637) Cootes = PERSON
# 638) MacDonald = PERSON
# 639) one hoot = QUANTITY
# 640) two = CARDINAL
# 641) Coote = PERSON
# 642) Caterham = PERSON
# 643) Siddons = PERSON
# 644) Tredwell = ORG
# 645) Wade = PERSON
# 646) Bundle = PERSON
# 647) Tredwell = PERSON
# 648) Caterham = PERSON
# 649) Bundle = PERSON
# 650) Caterham = PERSON
# 651) Bundle = PERSON
# 652) Caterham = PERSON
# 653) half = CARDINAL
# 654) Tredwell = PERSON
# 655) Bundle = PERSON
# 656) Bundle = PERSON
# 657) Caterham = PERSON
# 658) Bundle = PERSON
# 659) Bundle = PERSON
# 660) Louisa = PERSON
# 661) Caterham = PERSON
# 662) Bundle = PERSON
# 663) evening = TIME
# 664) Gerry Wade = PERSON
# 665) Gerry Wade = PERSON
# 666) second = ORDINAL
# 667) Tredwell = PERSON
# 668) Caterham = PERSON
# 669) Bundle = PERSON
# 670) Seven = CARDINAL
# 671) Bundle = PERSON
# 672) one = CARDINAL
# 673) Gerry Wade = PERSON
# 674) first = ORDINAL
# 675) Bundle = PERSON
# 676) the early hours of the morning = TIME
# 677) Bundle = PERSON
# 678) Bill Eversleigh = PERSON
# 679) Bundle = PERSON
# 680) Bundle = PERSON
# 681) half = CARDINAL
# 682) Bundle = PERSON
# 683) Bundle = PERSON
# 684) Bundle = PERSON
# 685) Sept. 21st = DATE
# 686) September 21st = DATE
# 687) Bundle = PERSON
# 688) The 22nd = DATE
# 689) the day = DATE
# 690) Gerry Wade = PERSON
# 691) the very evening = TIME
# 692) Bundle = PERSON
# 693) Wednesday = DATE
# 694) Seven = CARDINAL
# 695) Lurcher = LOC
# 696) Bundle = PERSON
# 697) Seven = CARDINAL
# 698) London = GPE
# 699) two = CARDINAL
# 700) that very night = TIME
# 701) Gerry Wade = PERSON
# 702) Bundle = PERSON
# 703) Gerry Wade = PERSON
# 704) Bundle = PERSON
# 705) seven = CARDINAL
# 706) Bundle = PERSON
# 707) Caterham = PERSON
# 708) Hispano = LOC
# 709) yesterday = DATE
# 710) Caterham = PERSON
# 711) a hundred years = DATE
# 712) Caterham = PERSON
# 713) Tredwell = ORG
# 714) only this morning = TIME
# 715) Bundle = PERSON
# 716) Tredwell = ORG
# 717) Bundle = PERSON
# 718) Caterham = PERSON
# 719) four years ago = DATE
# 720) Bundle = PERSON
# 721) Caterham = PERSON
# 722) Bundle = PERSON
# 723) Caterham = PERSON
# 724) Bundle = PERSON
# 725) Caterham = PERSON
# 726) Hispano = PRODUCT
# 727) Bundle = PERSON
# 728) Tredwell = PERSON
# 729) the Boys' Brigade = ORG
# 730) Caterham = PERSON
# 731) this morning = TIME
# 732) Caterham = PERSON
# 733) Tredwell = PERSON
# 734) Tredwell = PERSON
# 735) Bundle = PERSON
# 736) Klaxon = PRODUCT
# 737) Katie = PERSON
# 738) Bundle = PERSON
# 739) a crisp October day = DATE
# 740) Bundle = PERSON
# 741) that morning = TIME
# 742) Gerald Wade's = PERSON
# 743) Loraine Wade = PERSON
# 744) Deane Priory = FAC
# 745) Bill Eversleigh = PERSON
# 746) a lovely morning = TIME
# 747) Hispano = PRODUCT
# 748) Bundle = PERSON
# 749) Hispano = PRODUCT
# 750) Bundle = PERSON
# 751) Bundle = PERSON
# 752) Bundle = PERSON
# 753) Bundle = PERSON
# 754) the minute = TIME
# 755) half = CARDINAL
# 756) Bundle = PERSON
# 757) Seven = CARDINAL
# 758) Bundle = PERSON
# 759) Jimmy Thesiger = PERSON
# 760) Bundle = PERSON
# 761) first = ORDINAL
# 762) Hispano = PRODUCT
# 763) A couple of miles = QUANTITY
# 764) Cassell = PERSON
# 765) Bundle = PERSON
# 766) Bundle = PERSON
# 767) Bundle = PERSON
# 768) Five minutes = TIME
# 769) ten minutes = TIME
# 770) a quarter of an hour = TIME
# 771) twenty minutes = TIME
# 772) Cassell = PERSON
# 773) Bundle = PERSON
# 774) Bundle = PERSON
# 775) CHAPTER VI SEVEN = EVENT
# 776) Bundle = PERSON
# 777) the last three quarters of an hour = TIME
# 778) quite two minutes = TIME
# 779) Bundle = PERSON
# 780) Bundle = PERSON
# 781) Bundle = PERSON
# 782) Bundle = PERSON
# 783) Bundle = PERSON
# 784) Bundle = PERSON
# 785) Seven = CARDINAL
# 786) Cassell = PERSON
# 787) Bundle = PERSON
# 788) Bundle = PERSON
# 789) Albany = FAC
# 790) Bundle = PERSON
# 791) Ronald Devereux = PERSON
# 792) half = CARDINAL
# 793) Chimneys = LOC
# 794) Ronny Devereux = PERSON
# 795) Bill = PERSON
# 796) the Foreign Office = ORG
# 797) Bill = PERSON
# 798) Gerald Wade = PERSON
# 799) Bundle = PERSON
# 800) First = ORDINAL
# 801) Gerald Wade = PERSON
# 802) Ronny Devereux = PERSON
# 803) Gerry Wade's = PERSON
# 804) Ronny Devereux's = PERSON
# 805) Bundle = PERSON
# 806) Seven = CARDINAL
# 807) Gerald Wade = PERSON
# 808) Seven = CARDINAL
# 809) the night = TIME
# 810) Bundle = PERSON
# 811) Caterham = PERSON
# 812) Bundle = PERSON
# 813) London = GPE
# 814) London = GPE
# 815) Bundle = PERSON
# 816) Caterham = PERSON
# 817) Bundle = PERSON
# 818) Caterham = PERSON
# 819) Bundle = PERSON
# 820) Caterham = PERSON
# 821) Caterham = PERSON
# 822) Bundle = PERSON
# 823) one = CARDINAL
# 824) Caterham = PERSON
# 825) Seven = CARDINAL
# 826) the East End = LOC
# 827) Seven Sisters = FAC
# 828) a Jimmy Thesiger = PERSON
# 829) Caterham = PERSON
# 830) Seven = CARDINAL
# 831) Thesiger = PERSON
# 832) Thesiger = PERSON
# 833) the Yorkshire Thesigers = NORP
# 834) Caterham = PERSON
# 835) Selina = PERSON
# 836) Thesiger = NORP
# 837) Bundle = PERSON
# 838) Caterham = PERSON
# 839) Bundle = PERSON
# 840) Bill = PERSON
# 841) Bundle = PERSON
# 842) Seven Dials = MONEY
# 843) Caterham = PERSON
# 844) Seven Dials = QUANTITY
# 845) George Lomax = PERSON
# 846) Tredwell = PERSON
# 847) Abbey = FAC
# 848) next week = DATE
# 849) Seven = CARDINAL
# 850) Scotland Yard = ORG
# 851) George = PERSON
# 852) Bundle = PERSON
# 853) Cabinet = ORG
# 854) George Lomax = PERSON
# 855) State = ORG
# 856) Foreign Affairs = ORG
# 857) Bill Eversleigh = PERSON
# 858) Codders = PERSON
# 859) Codders = PERSON
# 860) Gerald Wade's = PERSON
# 861) Bundle = PERSON
# 862) some minutes = TIME
# 863) Loraine Wade = PERSON
# 864) Gerald Wade = PERSON
# 865) Wade = PERSON
# 866) Gerry = PERSON
# 867) Wade = PERSON
# 868) Wade = PERSON
# 869) second = ORDINAL
# 870) Courts = ORG
# 871) Wade = PERSON
# 872) Bundle = PERSON
# 873) Caterham = PERSON
# 874) Bundle = PERSON
# 875) First = ORDINAL
# 876) this Jimmy Thesiger = PERSON
# 877) Bill = PERSON
# 878) Ronny Devereux = PERSON
# 879) Bill = PERSON
# 880) Jimmy Thesiger = PERSON
# 881) Ronny = PERSON
# 882) Bill = PERSON
# 883) Loraine Wade = PERSON
# 884) Seven = CARDINAL
# 885) Gerry Wade = PERSON
# 886) BUNDLE = PERSON
# 887) Bill = PERSON
# 888) Bundle = PERSON
# 889) the following morning = TIME
# 890) Bill = PERSON
# 891) Bundle = PERSON
# 892) two = CARDINAL
# 893) Bill = PERSON
# 894) Bill = PERSON
# 895) Bundle = PERSON
# 896) Bill = PERSON
# 897) Jimmy Thesiger = PERSON
# 898) Bundle = PERSON
# 899) Jimmy = PERSON
# 900) Bundle = PERSON
# 901) Jimmy = PERSON
# 902) Bundle = PERSON
# 903) Jimmy Thesiger = PERSON
# 904) the Foreign Office = ORG
# 905) Bundle = PERSON
# 906) first = ORDINAL
# 907) Bill = PERSON
# 908) Ronny = PERSON
# 909) Ronny Devereux = PERSON
# 910) Thesiger = PERSON
# 911) Bundle = PERSON
# 912) Bill = PERSON
# 913) Bundle = PERSON
# 914) first = ORDINAL
# 915) morning = TIME
# 916) one = CARDINAL
# 917) one = CARDINAL
# 918) Bill = PERSON
# 919) Ronny = PERSON
# 920) that week-end = DATE
# 921) Gerry Wade = PERSON
# 922) Bill = PERSON
# 923) Ronny = PERSON
# 924) Bill = PERSON
# 925) Bill = PERSON
# 926) to-morrow night = TIME
# 927) Bundle = PERSON
# 928) Jimmy Thesiger's = PERSON
# 929) Jimmy Thesiger = PERSON
# 930) Jermyn Street = FAC
# 931) Jermyn Street = FAC
# 932) Jermyn Street = FAC
# 933) 103 = CARDINAL
# 934) 103 = CARDINAL
# 935) Bill = PERSON
# 936) half an hour = TIME
# 937) Sherlock = PERSON
# 938) one = CARDINAL
# 939) eleven = TIME
# 940) every morning = TIME
# 941) Codders = PERSON
# 942) Bundle = PERSON
# 943) to-morrow night = TIME
# 944) Bundle = PERSON
# 945) First = ORDINAL
# 946) five and twenty minutes to twelve = TIME
# 947) Bill = PERSON
# 948) Thesiger = PERSON
# 949) London = GPE
# 950) Bundle = PERSON
# 951) Bundle = PERSON
# 952) Thesiger = PERSON
# 953) a nice morning = TIME
# 954) an awfully nice morning = TIME
# 955) Bundle = PERSON
# 956) morning = TIME
# 957) Bundle = PERSON
# 958) Bundle = PERSON
# 959) Bundle = PERSON
# 960) second = ORDINAL
# 961) Bundle = PERSON
# 962) Loraine Wade = PERSON
# 963) Loraine = PERSON
# 964) Bundle = PERSON
# 965) yesterday = DATE
# 966) Bundle Brent = PERSON
# 967) Gerry = PERSON
# 968) Loraine = PERSON
# 969) Bundle = PERSON
# 970) Ronny Devereux = PERSON
# 971) Loraine = PERSON
# 972) the day = DATE
# 973) Gerry = PERSON
# 974) two = CARDINAL
# 975) three = CARDINAL
# 976) Gerry = PERSON
# 977) Loraine = PERSON
# 978) Bundle = PERSON
# 979) the preceding day = DATE
# 980) Loraine = PERSON
# 981) all these weeks = DATE
# 982) Gerald = PERSON
# 1787) any minute = TIME
# 1788) Tredwell = PERSON
# 1789) Bundle = PERSON
# 1790) Mosgorovsky = PERSON
# 1791) Russian = NORP
# 1792) Bundle = PERSON
# 1793) A hundred pounds = MONEY
# 1794) Alfred = PERSON
# 1795) Alfred = PERSON
# 1796) Alfred = PERSON
# 1797) Scotland = GPE
# 1798) the day before yesterday = DATE
# 1799) Bundle = PERSON
# 1800) Alfred = PERSON
# 1801) first = ORDINAL
# 1802) Bundle = PERSON
# 1803) Alfred = PERSON
# 1804) Alfred = PERSON
# 1805) Bundle = PERSON
# 1806) Alfred = PERSON
# 1807) Mosgorovsky = PERSON
# 1808) Bundle = PERSON
# 1809) one = CARDINAL
# 1810) Alfred = PERSON
# 1811) fourth = ORDINAL
# 1812) Bundle = PERSON
# 1813) Two = CARDINAL
# 1814) Alfred = PERSON
# 1815) Bundle = PERSON
# 1816) Alfred = PERSON
# 1817) Bundle = PERSON
# 1818) seven = CARDINAL
# 1819) three = CARDINAL
# 1820) one = CARDINAL
# 1821) Bundle = PERSON
# 1822) Alfred = PERSON
# 1823) Mosgorovsky = PERSON
# 1824) this morning = TIME
# 1825) Bundle = PERSON
# 1826) This morning = TIME
# 1827) Alfred = PERSON
# 1828) Next minute = TIME
# 1829) Alfred = PERSON
# 1830) Bundle = PERSON
# 1831) Alfred = PERSON
# 1832) Bundle = PERSON
# 1833) Alfred = PERSON
# 1834) Bundle = PERSON
# 1835) Alfred = PERSON
# 1836) Bundle = PERSON
# 1837) second = ORDINAL
# 1838) Bundle = PERSON
# 1839) Alfred = PERSON
# 1840) Bundle = PERSON
# 1841) Alfred = PERSON
# 1842) any minute = TIME
# 1843) Mosgo = PERSON
# 1844) midnight = TIME
# 1845) Alfred = PERSON
# 1846) Bundle = PERSON
# 1847) Alfred = PERSON
# 1848) Bundle = PERSON
# 1849) Alfred = PERSON
# 1850) Alfred = PERSON
# 1851) Bundle = PERSON
# 1852) Bundle = PERSON
# 1853) Mosgorovsky = PERSON
# 1854) Bundle = PERSON
# 1855) Alfred = PERSON
# 1856) Bundle = PERSON
# 1857) Alfred = PERSON
# 1858) Bundle = PERSON
# 1859) Alfred = PERSON
# 1860) Alfred = PERSON
# 1861) Bundle = PERSON
# 1862) that morning = TIME
# 1863) Bundle = PERSON
# 1864) hours = TIME
# 1865) XIV = CARDINAL
# 1866) SEVEN = CARDINAL
# 1867) the next four hours = TIME
# 1868) Bundle = PERSON
# 1869) between the hours of midnight and 2 A.M. = TIME
# 1870) at least six o'clock in the morning = TIME
# 1871) another minute = TIME
# 1872) Bundle = PERSON
# 1873) another minute = TIME
# 1874) Bundle = PERSON
# 1875) the preceding night = TIME
# 1876) Alfred = PERSON
# 1877) Russian = NORP
# 1878) Mosgorovsky = PERSON
# 1879) Bundle = PERSON
# 1880) this minute = TIME
# 1881) Russian = NORP
# 1882) some minutes = TIME
# 1883) Bundle = PERSON
# 1884) two = CARDINAL
# 1885) six o'clock = TIME
# 1886) Bundle = PERSON
# 1887) seven = CARDINAL
# 1888) Mosgorovsky = PERSON
# 1889) Bundle = PERSON
# 1890) four o'clock = TIME
# 1891) five o'clock = TIME
# 1892) evening = TIME
# 1893) One = CARDINAL
# 1894) evening = TIME
# 1895) English = NORP
# 1896) Bundle = PERSON
# 1897) first = ORDINAL
# 1898) American = NORP
# 1899) Irish = NORP
# 1900) English = NORP
# 1901) night = TIME
# 1902) 4 = CARDINAL
# 1903) Bundle = PERSON
# 1904) French = NORP
# 1905) French = NORP
# 1906) Austrian = NORP
# 1907) Hungarian = NORP
# 1908) Russian = NORP
# 1909) American = NORP
# 1910) Bundle = PERSON
# 1911) One o'clock = TIME
# 1912) Five o'clock = TIME
# 1913) seven taps = TIME
# 1914) Mosgorovsky = PERSON
# 1915) Russian = NORP
# 1916) Bundle = PERSON
# 1917) five o'clock = TIME
# 1918) third = ORDINAL
# 1919) Bundle = PERSON
# 1920) American = NORP
# 1921) 4 = CARDINAL
# 1922) two = CARDINAL
# 1923) only two = CARDINAL
# 1924) second = ORDINAL
# 1925) one = CARDINAL
# 1926) Mosgorovsky = PERSON
# 1927) Bundle = PERSON
# 1928) Bundle = PERSON
# 1929) first = ORDINAL
# 1930) 7 = CARDINAL
# 1931) night = TIME
# 1932) American = NORP
# 1933) seven o'clock--_I'm = TIME
# 1934) Russian = NORP
# 1935) Bundle = PERSON
# 1936) Bundle = PERSON
# 1937) Slavonic = NORP
# 1938) Russian = NORP
# 1939) First = ORDINAL
# 1940) 2 = CARDINAL
# 1941) 2 = CARDINAL
# 1942) night = TIME
# 1943) American = NORP
# 1944) five o'clock = TIME
# 1945) Russian = NORP
# 1946) Bundle = PERSON
# 1947) Chimneys = LOC
# 1948) Mosgorovsky = PERSON
# 1949) Anna = PERSON
# 1950) 7 = CARDINAL
# 1951) 7 = CARDINAL
# 1952) Russian = NORP
# 1953) Mosgorovsky = PERSON
# 1954) Mosgorovsky = PERSON
# 1955) 3 = CARDINAL
# 1956) Wyvern Abbey = FAC
# 1957) Bundle = PERSON
# 1958) 3 = CARDINAL
# 1959) Englishman = NORP
# 1960) Mosgorovsky = PERSON
# 1961) Russian = NORP
# 1962) Stanley Digby = PERSON
# 1963) Terence O'Rourke = PERSON
# 1964) Oswald = PERSON
# 1965) Coote = PERSON
# 1966) Bateman = PERSON
# 1967) Anna Radzky = PERSON
# 1968) Macatta = PERSON
# 1969) James Thesiger-- = PERSON
# 1970) James Thesiger = PERSON
# 1971) American = NORP
# 1972) Russian = NORP
# 1973) Herr Eberhard = PERSON
# 1974) Eversleigh = PERSON
# 1975) Bundle = PERSON
# 1976) Eileen Brent = PERSON
# 1977) Mosgorovsky = PERSON
# 1978) Eberhard = PERSON
# 1979) Three o'clock = TIME
# 1980) British = NORP
# 1981) millions = CARDINAL
# 1982) Russian = NORP
# 1983) Bundle = PERSON
# 1984) 5 = CARDINAL
# 1985) American = NORP
# 1986) Oswald Coote = PERSON
# 1987) Mosgorovsky = PERSON
# 1988) 5 = CARDINAL
# 1989) years = DATE
# 1990) Eberhard = PERSON
# 1991) Mosgorovsky = PERSON
# 1992) Gerald Wade's = PERSON
# 1993) Caterham = PERSON
# 1994) Eileen Brent = PERSON
# 1995) Bauer = PERSON
# 1996) Mosgorovsky = PERSON
# 1997) 3 = CARDINAL
# 1998) Mosgorovsky = PERSON
# 1999) Ronald Devereux = PERSON
# 2000) to-morrow = DATE
# 2001) American = NORP
# 2002) our dear one o'clock = TIME
# 2003) 5 = CARDINAL
# 2004) Anna = PERSON
# 2005) Bundle = PERSON
# 2006) Anna = PERSON
# 2007) One o'clock = TIME
# 2008) first = ORDINAL
# 2009) Bundle = PERSON
# 2010) 3 = CARDINAL
# 2011) Anna = PERSON
# 2012) Mosgorovsky = PERSON
# 2013) a few moments = TIME
# 2014) Bundle = PERSON
# 2015) two hours later = TIME
# 2016) Alfred = PERSON
# 2017) Bundle = PERSON
# 2018) Bundle = PERSON
# 2019) Gord = PERSON
# 2020) Bundle = PERSON
# 2021) all the evening = TIME
# 2022) Bundle = PERSON
# 2023) Alfred = PERSON
# 2024) Bundle = PERSON
# 2025) about 6 A.M. = TIME
# 2026) half-past nine = TIME
# 2027) Jimmy Thesiger = PERSON
# 2028) Bundle = PERSON
# 2029) Chimneys = LOC
# 2030) Bundle = PERSON
# 2031) Jimmy = PERSON
# 2032) Bundle = PERSON
# 2033) last night = TIME
# 2034) Russian = NORP
# 2035) Jimmy = PERSON
# 2036) Russian Jews = NORP
# 2037) last night = TIME
# 2038) Bundle = PERSON
# 2039) Bundle = PERSON
# 2040) Jimmy = PERSON
# 2041) Bundle = PERSON
# 2042) Twenty minutes later = TIME
# 2043) two = CARDINAL
# 2044) Brook Street = FAC
# 2045) Bundle = PERSON
# 2046) Jimmy = PERSON
# 2047) Bundle = PERSON
# 2048) a late night = TIME
# 2049) the night before = TIME
# 2050) Bundle = PERSON
# 2051) Jimmy = PERSON
# 2052) Bundle = PERSON
# 2053) Bundle = PERSON
# 2054) Jimmy = PERSON
# 2055) Bundle = PERSON
# 2056) Jimmy = PERSON
# 2057) 7 = CARDINAL
# 2058) hundred = CARDINAL
# 2059) Jimmy = PERSON
# 2060) Jimmy = PERSON
# 2061) Jimmy = PERSON
# 2062) Russian = NORP
# 2063) American = NORP
# 2064) Englishman = NORP
# 2065) Austrian = NORP
# 2066) Hungarian = NORP
# 2067) Russian = NORP
# 2068) Polish = NORP
# 2069) German = NORP
# 2070) Bundle = PERSON
# 2071) German = NORP
# 2072) Jimmy = PERSON
# 2073) 2 = CARDINAL
# 2074) Bauer = PERSON
# 2075) Chimneys = FAC
# 2076) Gerry Wade's = PERSON
# 2077) Jimmy = PERSON
# 2078) Bauer = PERSON
# 2079) Bundle = PERSON
# 2080) first = ORDINAL
# 2081) Bundle = PERSON
# 2082) Wyvern Abbey = FAC
# 2083) next week = DATE
# 2084) American = NORP
# 2085) Russian = NORP
# 2086) Jimmy = PERSON
# 2087) German = NORP
# 2088) Eberhard = PERSON
# 2089) a minute = TIME
# 2090) Eberhard = PERSON
# 2091) Eberhard = PERSON
# 2092) Eberhard = PERSON
# 2093) Eberhard = PERSON
# 2094) the German Government = ORG
# 2095) Bundle = PERSON
# 2096) Jimmy = PERSON
# 2097) Eberhard = PERSON
# 2098) Oswald Coote = PERSON
# 2099) Abbey = FAC
# 2100) Oswald = PERSON
# 2101) George = PERSON
# 2102) Eberhard = PERSON
# 2103) Eberhard = PERSON
# 2104) Jimmy = PERSON
# 2105) the Seven Dials = ORG
# 2106) Russian = NORP
# 2107) millions = CARDINAL
# 2108) Jimmy = PERSON
# 2109) Jimmy = PERSON
# 2110) to-day = DATE
# 2111) Bundle = PERSON
# 2112) Ronny = PERSON
# 2113) Bundle = PERSON
# 2114) Seven = CARDINAL
# ...
# 3836) Eileen = PERSON
# 3837) Caterham = PERSON
# 3838) years = DATE
# 3839) years = DATE
# 3840) Eileen = PERSON
# 3841) Caterham = PERSON
# 3842) Caterham = PERSON
# 3843) Bundle = PERSON
# 3844) Caterham = PERSON
# 3845) Lomax = PERSON
# 3846) twenty = CARDINAL
# 3847) Caterham = PERSON
# 3848) Eileen = PERSON
# 3849) Caterham = PERSON
# 3850) Eileen = PERSON
# 3851) to-morrow = DATE
# 3852) Bundle = PERSON
# 3853) George = PERSON
# 3854) Caterham = PERSON
# 3855) two minutes = TIME
# 3856) Wade = PERSON
# 3857) Caterham = PERSON
# 3858) a few minutes = TIME
# 3859) Caterham = PERSON
# 3860) Tredwell = PERSON
# 3861) Lomax = PERSON
# 3862) Tredwell = PERSON
# 3863) George = PERSON
# 3864) Caterham = PERSON
# 3865) A thousand = CARDINAL
# 3866) Caterham = PERSON
# 3867) Eversleigh = PERSON
# 3868) Bill = PERSON
# 3869) Caterham = PERSON
# 3870) Bill = PERSON
# 3871) Lomax = PERSON
# 3872) Cabinet = ORG
# 3873) Codders = PERSON
# 3874) Bill = PERSON
# 3875) Caterham = PERSON
# 3876) George = PERSON
# 3877) Caterham = PERSON
# 3878) this minute = TIME
# 3879) Caterham = PERSON
# 3880) Lomax = PERSON
# 3881) Lomax = PERSON
# 3882) Caterham = PERSON
# 3883) Bundle = PERSON
# 3884) Bill = PERSON
# 3885) Caterham = PERSON
# 3886) Bill = PERSON
# 3887) Caterham = PERSON
# 3888) five years = DATE
# 3889) Bundle = PERSON
# 3890) Caterham = PERSON
# 3891) Caterham = PERSON
# 3892) the Stone Age = DATE
# 3893) Bundle = PERSON
# 3894) Bundle = PERSON
# 3895) George = PERSON
# 3896) Caterham = PERSON
# 3897) Bill = PERSON
# 3898) Bundle = PERSON
# 3899) Jimmy Thesiger = PERSON
# 3900) Cootes = PERSON
# 3901) yesterday = DATE
# 3902) Bundle = PERSON
# 3903) Loraine = PERSON
# 3904) Saturday = DATE
# 3905) Bill = PERSON
# 3906) Caterham = PERSON
# 3907) Bill = PERSON
# 3908) Bill = PERSON
# 3909) London = GPE
# 3910) St. James's Square = FAC
# 3911) Jimmy Thesiger's = PERSON
# 3912) Jimmy = PERSON
# 3913) Bill = PERSON
# 3914) Bill = PERSON
# 3915) Jimmy = PERSON
# 3916) Bill = PERSON
# 3917) Jimmy = PERSON
# 3918) William = PERSON
# 3919) Seven = CARDINAL
# 3920) Seven = CARDINAL
# 3921) this morning = TIME
# 3922) Ronny Devereux's = PERSON
# 3923) exactly a fortnight = DATE
# 3924) Bill = PERSON
# 3925) Jimmy = PERSON
# 3926) Bill = PERSON
# 3927) Jimmy = PERSON
# 3928) six = CARDINAL
# 3929) Stevens = PERSON
# 3930) Jimmy = PERSON
# 3931) Bill = PERSON
# 3932) Jimmy = PERSON
# 3933) Stevens = PERSON
# 3934) Bill = PERSON
# 3935) XXX = CARDINAL
# 3936) Loraine = PERSON
# 3937) Bundle = PERSON
# 3938) twenty minutes = TIME
# 3939) Bundle = PERSON
# 3940) Loraine = PERSON
# 3941) George = PERSON
# 3942) George Lomax = PERSON
# 3943) George = PERSON
# 3944) Bundle = PERSON
# 3945) George = PERSON
# 3946) George = PERSON
# 3947) George = PERSON
# 3948) one quarter = CARDINAL
# 3949) Loraine = PERSON
# 3950) Caterham = PERSON
# 3951) Lomax = PERSON
# 3952) Bundle = PERSON
# 3953) George = PERSON
# 3954) Caterham = PERSON
# 3955) Bundle = PERSON
# 3956) George = PERSON
# 3957) Bundle = PERSON
# 3958) Caterham = PERSON
# 3959) Lomax = PERSON
# 3960) two = CARDINAL
# 3961) Bundle = PERSON
# 3962) sixpence = MONEY
# 3963) Loraine = PERSON
# 3964) An hour = TIME
# 3965) three = CARDINAL
# 3966) Lomax = PERSON
# 3967) Tredwell = PERSON
# 3968) Caterham = PERSON
# 3969) Tredwell = PERSON
# 3970) Bundle = PERSON
# 3971) Bundle = PERSON
# 3972) CATERHAM-- = PERSON
# 3973) Eileen = PERSON
# 3974) Caterham = PERSON
# 3975) GEORGE LOMAX = PERSON
# 3976) Bundle = PERSON
# 3977) Caterham = PERSON
# 3978) Bundle = PERSON
# 3979) Cabinet = ORG
# 3980) Bundle = PERSON
# 3981) Bundle = PERSON
# 3982) another minute = TIME
# 3983) George = PERSON
# 3984) Loraine = PERSON
# 3985) Caterham = PERSON
# 3986) Jimmy = PERSON
# 3987) Bundle = PERSON
# 3988) Jimmy = PERSON
# 3989) Loraine = PERSON
# 3990) Bill = PERSON
# 3991) the century = DATE
# 3992) the Seven Dials Club = ORG
# 3993) Alfred = PERSON
# 3994) Bill = PERSON
# 3995) Bundle = PERSON
# 3996) Loraine = PERSON
# 3997) Jimmy = PERSON
# 3998) 7 = CARDINAL
# 3999) Bundle = PERSON
# 4000) Loraine = PERSON
# 4001) Loraine = PERSON
# 4002) Bundle = PERSON
# 4003) Loraine = PERSON
# 4004) Bundle = PERSON
# 4005) Bundle = PERSON
# 4006) a minute = TIME
# 4007) Bundle = PERSON
# 4008) Hispano = PRODUCT
# 4009) London = GPE
# 4010) Bundle = PERSON
# 4011) the Seven Dials Club = FAC
# 4012) Alfred = PERSON
# 4013) Bundle = PERSON
# 4014) Loraine = PERSON
# 4015) Alfred = PERSON
# 4016) Bundle = PERSON
# 4017) Alfred = PERSON
# 4018) the other night = TIME
# 4019) Bundle = PERSON
# 4020) Mosgorovsky = PERSON
# 4021) ten pounds = MONEY
# 4022) three minutes' time = TIME
# 4023) Alfred = PERSON
# 4024) only one = CARDINAL
# 4025) Bundle = PERSON
# 4026) Loraine = PERSON
# 4027) Bundle = PERSON
# 4028) Jimmy = PERSON
# 4029) Bill = PERSON
# 4030) Alfred = PERSON
# 4031) Alfred = PERSON
# 4032) Loraine = PERSON
# 4033) Loraine = PERSON
# 4034) Jimmy Thesiger = PERSON
# 4035) Bill = PERSON
# 4036) Bundle = PERSON
# 4037) one = CARDINAL
# 4038) three = CARDINAL
# 4039) Bundle = PERSON
# 4040) seven = CARDINAL
# 4041) Jimmy = PERSON
# 4042) two = CARDINAL
# 4043) Bundle = PERSON
# 4044) Jimmy = PERSON
# 4045) Bill = PERSON
# 4046) Loraine = PERSON
# 4047) Loraine = PERSON
# 4048) Bundle = PERSON
# 4049) Jimmy = PERSON
# 4050) Bill = PERSON
# 4051) Loraine = PERSON
# 4052) Loraine = PERSON
# 4053) Bill = PERSON
# 4054) Bill = PERSON
# 4055) Bundle = PERSON
# 4056) Bill = PERSON
# 4057) Bill = PERSON
# 4058) Jimmy = PERSON
# 4059) Loraine = PERSON
# 4060) Loraine = PERSON
# 4061) Bill = PERSON
# 4062) Jimmy = PERSON
# 4063) Bill = PERSON
# 4064) Jimmy = PERSON
# 4065) Loraine = PERSON
# 4066) Jimmy = PERSON
# 4067) Bill = PERSON
# 4068) Jimmy = PERSON
# 4069) Jimmy = PERSON
# 4070) Bundle = PERSON
# 4071) three = CARDINAL
# 4072) Bill = PERSON
# 4073) Genneman = PERSON
# 4074) Jimmy = PERSON
# 4075) Bundle = PERSON
# 4076) Jimmy = PERSON
# 4077) only one = CARDINAL
# 4078) two = CARDINAL
# 4079) Bill = PERSON
# 4080) Bundle = PERSON
# 4081) Loraine = PERSON
# 4082) Loraine = PERSON
# 4083) ages = DATE
# 4084) Jimmy = PERSON
# 4085) only a minute and a half = TIME
# 4086) Bundle = PERSON
# 4087) Jimmy = PERSON
# 4088) Loraine = PERSON
# 4089) Bundle = PERSON
# 4090) Loraine = PERSON
# 4091) Bundle = PERSON
# 4092) Bill = PERSON
# 4093) Loraine = PERSON
# 4094) Bundle = PERSON
# 4095) Loraine = PERSON
# 4096) Bundle = PERSON
# 4097) Bundle = PERSON
# 4098) Bundle = PERSON
# 4099) SEVEN = CARDINAL
# 4100) Bundle = PERSON
# 4101) Bundle = PERSON
# 4102) Bundle = PERSON
# 4103) Bundle = PERSON
# 4104) Bundle = PERSON
# 4105) Bundle = PERSON
# 4106) Bundle = PERSON
# 4107) Bill = PERSON
# 4108) Bundle = PERSON
# 4109) Bundle = PERSON
# 4110) Bundle = PERSON
# 4111) Bill = PERSON
# 4112) Bundle = PERSON
# 4113) About five minutes ago = TIME
# 4114) Bill = PERSON
# 4115) Bundle = PERSON
# 4116) ages = DATE
# 4117) Bundle = PERSON
# 4118) George Lomax = PERSON
# 4119) Bundle = PERSON
# 4120) Codders = PERSON
# 4121) Bill = PERSON
# 4122) Bill = PERSON
# 4123) Bundle = PERSON
# 4124) Bundle = PERSON
# 4125) Bundle = PERSON
# 4126) Bill = PERSON
# 4127) Bill = PERSON
# 4128) Bundle = PERSON
# 4129) Bundle = PERSON
# 4130) Bundle = PERSON
# 4131) Bill = PERSON
# 4132) Bundle = PERSON
# 4133) Bill = PERSON
# 4134) Bundle = PERSON
# 4135) the next ten minutes = TIME
# 4136) Bill = PERSON
# 4137) twentieth = ORDINAL
# 4138) first = ORDINAL
# 4139) Bundle = PERSON
# 4140) Bundle = PERSON
# 4141) Bill = PERSON
# 4142) Bill = PERSON
# 4143) Bundle = PERSON
# 4144) Bill = PERSON
# 4145) Bundle = PERSON
# 4146) Bill = PERSON
# 4147) Bundle = PERSON
# 4148) Bill = PERSON
# 4149) Bundle = PERSON
# 4150) Bill = PERSON
# 4151) Bill = PERSON
# 4152) another half hour = TIME
# 4153) Bill = PERSON
# 4154) Bundle = PERSON
# 4155) Bundle = PERSON
# 4156) Jimmy = PERSON
# 4157) Mosgorovsky = PERSON
# 4158) Bill = PERSON
# 4159) Bundle = PERSON
# 4160) Russian = NORP
# 4161) two = CARDINAL
# 4162) Bundle = PERSON
# 4163) Bill = PERSON
# 4164) Bundle = PERSON
# 4165) Bill = PERSON
# 4166) Bundle = PERSON
# 4167) Bill = PERSON
# 4168) Russian = NORP
# 4169) Alfred = PERSON
# 4170) Mosgorovsky = PERSON
# 4171) Bundle = PERSON
# 4172) Bill = PERSON
# 4173) The minutes = TIME
# 4174) Bundle = PERSON
# 4175) over an hour = TIME
# 4176) Russian = NORP
# 4177) Mosgorovsky = PERSON
# 4178) Eileen Brent = PERSON
# 4179) the Seven Dials Society = ORG
# 4180) Bundle = PERSON
# 4181) Bundle = PERSON
# 4182) second = ORDINAL
# 4183) first = ORDINAL
# 4184) Mosgorovsky = PERSON
# 4185) 7 = CARDINAL
# 4186) Bundle = PERSON
# 4187) Bundle = PERSON
# 4188) Mosgorovsky = PERSON
# 4189) Eileen = PERSON
# 4190) 2 o'clock = TIME
# 4191) Bundle = PERSON
# 4192) Bundle Brent = PERSON
# 4193) Bill = PERSON
# 4194) Mosgorovsky = PERSON
# 4195) Eileen = PERSON
# 4196) Bundle = PERSON
# 4197) 7 o'clock = TIME
# 4198) Bundle = PERSON
# 4199) 7 = CARDINAL
# 4200) Bundle = PERSON
# 4201) Bundle = PERSON
# 4202) Battle = PERSON
# 4203) CHAPTER XXXII BUNDLE IS DUMFOUNDED = EVENT
# 4204) Battle = PERSON
# 4205) Mosgorovsky = PERSON
# 4206) Bundle = PERSON
# 4207) Bundle = PERSON
# 4208) Battle = PERSON
# 4209) Eileen = PERSON
# 4210) Mosgorovsky = PERSON
# 4211) Bundle = PERSON
# 4212) Battle = PERSON
# 4213) one = CARDINAL
# 4214) two = CARDINAL
# 4215) Eileen = PERSON
# 4216) Eileen = PERSON
# 4217) Department = ORG
# 4218) these Safety First days = DATE
# 4219) Eileen = PERSON
# 4220) First = ORDINAL
# 4221) Mosgorovsky = PERSON
# 4222) England = GPE
# 4223) 5 = CARDINAL
# 4224) Andras = PERSON
# 4225) the Hungarian Embassy = ORG
# 4226) Gerald Wade = PERSON
# 4227) 4 = CARDINAL
# 4228) Hayward Phelps = PERSON
# 4229) American = NORP
# 4230) British = NORP
# 4231) 3 = CARDINAL
# 4232) Bundle = PERSON
# 4233) Bill Eversleigh = PERSON
# 4234) 2 = CARDINAL
# 4235) Battle = PERSON
# 4236) Ronald Devereux = PERSON
# 4237) 1 = CARDINAL
# 4238) 1 = CARDINAL
# 4239) Gerald Wade = PERSON
# 4240) 1 = CARDINAL
# 4241) Bundle = PERSON
# 4242) Radzky = PERSON
# 4243) Bundle = PERSON
# 4244) Bill = PERSON
# 4245) Bundle = PERSON
# 4246) Babe St. Maur_--you = PERSON
# 4247) Poppa = PERSON
# 4248) Momma = PERSON
# 4249) Yurrup = LOC
# 4250) Abbey = FAC
# 4251) Ronny = PERSON
# 4252) Bundle = PERSON
# 4253) Eileen = PERSON
# 4254) Battle = PERSON
# 4255) Wade = PERSON
# 4256) first = ORDINAL
# 4257) Wade = PERSON
# 4258) Bundle = PERSON
# 4259) Wade = PERSON
# 4260) Raffles = PRODUCT
# 4261) Raffles = PRODUCT
# 4262) Two = CARDINAL
# 4263) Eversleigh = PERSON
# 4264) Bundle = PERSON
# 4265) Eileen = PERSON
# 4266) Jimmy Thesiger = PERSON
# 4267) this afternoon = TIME
# 4268) CHAPTER XXXIII = LAW
# 4269) Battle = PERSON
# 4270) Devereux = PERSON
# 4271) Devereux = PERSON
# 4272) Thesiger = PERSON
# 4273) the Seven Dials = PRODUCT
# 4274) Devereux = PERSON
# 4275) Jimmy Thesiger = PERSON
# 4276) Devereux = PERSON
# 4277) Thesiger = PERSON
# 4278) the Foreign Office = ORG
# 4279) Thesiger = PERSON
# 4280) Wade = PERSON
# 4281) Devereux = PERSON
# 4282) Chimneys = LOC
# 4283) that week-end = DATE
# 4284) Wade = PERSON
# 4285) Devereux = PERSON
# 4286) a minute = TIME
# 4287) Wade = PERSON
# 4288) Thesiger = PERSON
# 4289) seven = CARDINAL
# 4290) eighth = ORDINAL
# 4291) the Seven Dials = ORG
# 4292) one = CARDINAL
# 4293) Jimmy Thesiger = PERSON
# 4294) Gerry Wade = PERSON
# 4295) Wade = PERSON
# 4296) Wade = PERSON
# 4297) Bauer = PERSON
# 4298) Bundle = PERSON
# 4299) Bauer = PERSON
# 4300) one = CARDINAL
# 4301) Eileen = PERSON
# 4302) Herr Eberhard's = PERSON
# 4303) Bauer = PERSON
# 4304) Thesiger = PERSON
# 4305) Wade = PERSON
# 4306) Thesiger = PERSON
# 4307) Wade = PERSON
# 4308) seven = CARDINAL
# 4309) Thesiger = PERSON
# 4310) Devereux = PERSON
# 4311) a bad five minutes = TIME
# 4312) Devereux = PERSON
# 4313) Devereux = PERSON
# 4314) Wade = PERSON
# 4315) Wade = PERSON
# 4316) Thesiger = PERSON
# 4317) Loraine Wade = PERSON
# The frequencies of unique named entity labels: {'WORK_OF_ART': 12, 'PERSON': 3328, 'DATE': 123, 'ORG': 80, 'GPE': 48, 'CARDINAL': 330, 'EVENT': 9, 'FAC': 71, 'TIME': 277, 'ORDINAL': 70, 'PRODUCT': 21, 'NORP': 94, 'MONEY': 14, 'QUANTITY': 17, 'LOC': 20, 'LANGUAGE': 4, 'LAW': 2}

# %%
from spacy import displacy
displacy.render(processed_book_1, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Seven Dials Mystery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agatha Christie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  PRINTING HISTORY _
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dodd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  edition published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 1929
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grosset &amp; Dunlap
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  edition published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 1930
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American Mercury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  edition published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 1942
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bantam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  edition
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     /January 1964
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _New
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bantam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  edition/
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 1976
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Agatha Christie Mystery Collection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# /
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 1986
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _All rights reserved._ _Copyright
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1929
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dodd, Mead &amp; Company, Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# _ _Copyright renewed ©
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1957
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agatha Christie Mallowan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ._ PRINTED IN
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     THE UNITED STATES OF AMERICA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  CONTENTS I ON EARLY RISING
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  CONCERNING ALARUM CLOCKS
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     III
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  THE JOKE THAT FAILED IV A LETTER V THE MAN IN THE ROAD VI SEVEN DIALS AGAIN VII BUNDLE PAYS A CALL VIII VISITORS FOR JIMMY IX PLANS X BUNDLE VISITS
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SCOTLAND
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  YARD XI DINNER WITH BILL XII INQUIRIES AT CHIMNEYS XIII THE SEVEN DIALS CLUB XIV THE MEETING OF THE SEVEN DIALS XV THE INQUEST
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XVI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-l

# %% [markdown]
# ### NER on text out of tokens withouth punctuation and stopwords

# %%
book_1_from_clean_tokens = " ".join(clean_tokens)
print(book_1_from_clean_tokens[:200])
# Out:
# The Seven Dials Mystery Agatha Christie PRINTING HISTORY Dodd Mead edition published March 1929 Grosset Dunlap edition published February 1930 American Mercury edition published October 1942 Bantam ed

# %%
ner_list = []

i = 1
entities_list = []
entities_freq_dict = {}

for ent in nlp(book_1_from_clean_tokens).ents:
    print(f'{i}) {ent.text} = {ent.label_}')
    i += 1
    entities_list.append(ent.label_)

for ent_label in entities_list:
  if ent_label not in entities_freq_dict:
    entities_freq_dict[ent_label] = 0
  entities_freq_dict[ent_label] += 1


print(f'The frequencies of unique named entity labels: {entities_freq_dict}')
# Out:
# /usr/local/lib/python3.11/dist-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# 1) Seven = CARDINAL
# 2) Agatha Christie = PERSON
# 3) Dodd Mead = ORG
# 4) March 1929 = DATE
# 5) Grosset Dunlap = ORG
# 6) February 1930 = DATE
# 7) American Mercury = ORG
# 8) October 1942 = DATE
# 9) Bantam = ORG
# 10) January 1964 = DATE
# 11) New Bantam = ORG
# 12) March 1976 = DATE
# 13) The Agatha Christie Mystery Collection = WORK_OF_ART
# 14) September 1986 = DATE
# 15) 1929 = DATE
# 16) Dodd Mead Company Inc. = ORG
# 17) 1957 = DATE
# 18) Agatha Christie = PERSON
# 19) THE UNITED STATES OF AMERICA = GPE
# 20) II = CARDINAL
# 21) III = CARDINAL
# 22) XVI = DATE
# 23) XXV JIMMY = PERSON
# 24) GEORGE LOMAX = PERSON
# 25) CATERHAM = PERSON
# 26) SEVEN = CARDINAL
# 27) Jimmy Thesiger = PERSON
# 28) two = CARDINAL
# 29) Tredwell = PERSON
# 30) Tredwell = PERSON
# 31) Jimmy = PERSON
# 32) Tredwell = PERSON
# 33) Wade = PERSON
# 34) Jimmy = PERSON
# 35) Jimmy = PERSON
# 36) nine thirty = TIME
# 37) quarter past eleven = TIME
# 38) Coote = PERSON
# 39) Coote = PERSON
# 40) first = ORDINAL
# 41) Oswald Coote = PERSON
# 42) half minute later = TIME
# 43) eight o'clock = TIME
# 44) Lady Coote = PERSON
# 45) Oswald = PERSON
# 46) Lady Coote = PERSON
# 47) Rachel = PERSON
# 48) Lady Coote = PERSON
# 49) Lady Coote = PERSON
# 50) Oswald = PERSON
# 51) Oswald Coote = PERSON
# 52) first = ORDINAL
# 53) Oswald = PERSON
# 54) England = GPE
# 55) Marquis Caterham = PERSON
# 56) two years = DATE
# 57) Oswald = PERSON
# 58) Lady Coote = PERSON
# 59) three = CARDINAL
# 60) Lady Coote 's = PERSON
# 61) Coote = PERSON
# 62) one = CARDINAL
# 63) Jimmy Thesiger = PERSON
# 64) Lady Coote = PERSON
# 65) MacDonald = PERSON
# 66) MacDonald = PERSON
# 67) Coote = PERSON
# 68) MacDonald = PERSON
# 69) morning = TIME
# 70) MacDonald = PERSON
# 71) Coote = PERSON
# 72) yesterday = DATE
# 73) one = CARDINAL
# 74) MacDonald = PERSON
# 75) Caterham = PERSON
# 76) one = CARDINAL
# 77) MacDonald = PERSON
# 78) Coote = PERSON
# 79) Coote = PERSON
# 80) MacDonald = PERSON
# 81) Coote = PERSON
# 82) Oswald = PERSON
# 83) Coote = PERSON
# 84) England = GPE
# 85) Francis Drake = PERSON
# 86) MacDonald = PERSON
# 87) MacDonald = PERSON
# 88) Lady Coote = PERSON
# 89) MacDonald = PERSON
# 90) William = PERSON
# 91) Coote = PERSON
# 92) Scottish = NORP
# 93) MacDonald = PERSON
# 94) MacDonald = PERSON
# 95) Coote = PERSON
# 96) MacDonald = PERSON
# 97) Coote = PERSON
# 98) MacDonald = PERSON
# 99) William = PERSON
# 100) Coote = PERSON
# 101) MacDonald = PERSON
# 102) Coote = PERSON
# 103) MacDonald = PERSON
# 104) Coote = PERSON
# 105) Jimmy Thesiger = PERSON
# 106) morning = TIME
# 107) Coote = PERSON
# 108) Coote = PERSON
# 109) Tredwell = GPE
# 110) Coote = PERSON
# 111) Wade = PERSON
# 112) Wade = PERSON
# 113) Tredwell = GPE
# 114) eleven thirty = TIME
# 115) Wade = PERSON
# 116) Coote = PERSON
# 117) twenty minutes twelve = TIME
# 118) Tredwell = PERSON
# 119) one o'clock = TIME
# 120) Church = PERSON
# 121) Coote = PERSON
# 122) second = ORDINAL
# 123) Coote = PERSON
# 124) Oswald = PERSON
# 125) Bateman = PERSON
# 126) Coote = PERSON
# 127) Rupert Bateman = PERSON
# 128) Oswald = PERSON
# 129) Jimmy Thesiger = PERSON
# 130) Morning = DATE
# 131) Pongo = PERSON
# 132) Jimmy = PERSON
# 133) Bateman = PERSON
# 134) Jimmy = PERSON
# 135) Bateman = PERSON
# 136) Bateman = PERSON
# 137) Pongo = PERSON
# 138) Pongo = PERSON
# 139) Jimmy = PERSON
# 140) Jimmy = PERSON
# 141) three = CARDINAL
# 142) two = CARDINAL
# 143) one = CARDINAL
# 144) one = CARDINAL
# 145) Helen = PERSON
# 146) Nancy = PERSON
# 147) third = ORDINAL
# 148) one = CARDINAL
# 149) Socks = PERSON
# 150) two = CARDINAL
# 151) Bill Eversleigh = PERSON
# 152) Ronny Devereux = PERSON
# 153) Hallo = PERSON
# 154) Nancy = PERSON
# 155) Helen = PERSON
# 156) Jimmy = PERSON
# 157) Bill Eversleigh = PERSON
# 158) Gerry Wade = PERSON
# 159) Ronny Devereux = PERSON
# 160) Socks = PERSON
# 161) Coote = PERSON
# 162) Bill = PERSON
# 163) Jimmy = PERSON
# 164) Socks = PERSON
# 165) Jimmy = PERSON
# 166) morrow morning = TIME
# 167) Ronny = PERSON
# 168) seven = CARDINAL
# 169) Stagger = PERSON
# 170) Tredwell = PERSON
# 171) Coote = PERSON
# 172) Bill = PERSON
# 173) Bill = PERSON
# 174) Oswald = PERSON
# 175) Gerry = PERSON
# 176) Jimmy = PERSON
# 177) Socks = PERSON
# 178) Ronny = PERSON
# 179) Bill = PERSON
# 180) Pongo = PERSON
# 181) Jimmy = PERSON
# 182) Pongo = PERSON
# 183) one = CARDINAL
# 184) Pongo = PERSON
# 185) Bateman = PERSON
# 186) one = CARDINAL
# 187) one = CARDINAL
# 188) one = CARDINAL
# 189) Ronny = PERSON
# 190) One = CARDINAL
# 191) dozen = CARDINAL
# 192) Gerry Wade = PERSON
# 193) Bill = PERSON
# 194) Market Basing = PERSON
# 195) Bill Ronny = PERSON
# 196) Jimmy = PERSON
# 197) Coote = PERSON
# 198) Jimmy Nancy Helen = PERSON
# 199) Coote = PERSON
# 200) next week = DATE
# 201) Caterham = PERSON
# 202) Bill = PERSON
# 203) Coote = PERSON
# 204) Brent = PERSON
# 205) Caterham = PERSON
# 206) Socks = PERSON
# 207) Lady Coote = PERSON
# 208) Gerald Wade = PERSON
# 209) Jimmy Thesiger = PERSON
# 210) Gerald Wade = PERSON
# 211) Jimmy = PERSON
# 212) Morning = TIME
# 213) Coote = PERSON
# 214) Gerald Wade = PERSON
# 215) Market Basing = PERSON
# 216) Coote = PERSON
# 217) Lady Coote = PERSON
# 218) early morning = TIME
# 219) Wade = PERSON
# 220) early morning = TIME
# 221) Coote = PERSON
# 222) Wade = PERSON
# 223) Coote = PERSON
# 224) Wade = PERSON
# 225) Coote = PERSON
# 226) Wade = PERSON
# 227) Coote = PERSON
# 228) Oswald = PERSON
# 229) Wade = PERSON
# 230) Foreign Office = ORG
# 231) eleven o'clock = TIME
# 232) Coote = PERSON
# 233) Lady Coote = PERSON
# 234) Lady Coote = PERSON
# 235) Market Basing = ORG
# 236) Bundle = PERSON
# 237) Bill = PERSON
# 238) Jimmy Oh = PERSON
# 239) mark = PERSON
# 240) Ronny Ronny = PERSON
# 241) Bundle = PERSON
# 242) Bill = PERSON
# 243) Murgatroyd = PERSON
# 244) Murgatroyd 's Stores = ORG
# 245) Murgatroyd = PERSON
# 246) Nancy = PERSON
# 247) Helen = PERSON
# 248) Socks = PERSON
# 249) one = CARDINAL
# 250) Bill = PERSON
# 251) Jimmy = PERSON
# 252) next five minutes = TIME
# 253) six = CARDINAL
# 254) Ronny = PERSON
# 255) one = CARDINAL
# 256) Pongo = PERSON
# 257) Bill = PERSON
# 258) Coote = PERSON
# 259) Gerry = PERSON
# 260) Coote = PERSON
# 261) MacDonald = PERSON
# 262) Murgatroyd = PERSON
# 263) Coote = PERSON
# 264) Oswald = PERSON
# 265) Oswald = PERSON
# 266) Rupert Bateman = PERSON
# 267) Oswald = PERSON
# 268) Coote = PERSON
# 269) Gerald Wade = PERSON
# 270) Oswald = PERSON
# 271) Bateman = PERSON
# 272) Two = CARDINAL
# 273) Three = CARDINAL
# 274) Lady Coote = PERSON
# 275) Gerald Wade = PERSON
# 276) Coote = PERSON
# 277) Gerald Wade 's = PERSON
# 278) Jimmy = PERSON
# 279) Bill = PERSON
# 280) one = CARDINAL
# 281) One = CARDINAL
# 282) Gerry Wade = PERSON
# 283) eight = CARDINAL
# 284) latter day = DATE
# 285) one = CARDINAL
# 286) 6:30 A.M. = TIME
# 287) Bill = PERSON
# 288) Jimmy = PERSON
# 289) Jimmy = PERSON
# 290) Pongo = PERSON
# 291) Bateman = PERSON
# 292) Jimmy = PERSON
# 293) Pongo = PERSON
# 294) Ronny Devereux = PERSON
# 295) one = CARDINAL
# 296) Eight = CARDINAL
# 297) Gerry ass = PERSON
# 298) Jimmy Thesiger = PERSON
# 299) Ronny = PERSON
# 300) Gerald Do = PERSON
# 301) Jimmy = PERSON
# 302) Gerry = PERSON
# 303) Ronny = PERSON
# 304) Jimmy = PERSON
# 305) Pongo = PERSON
# 306) Bill = PERSON
# 307) Jimmy = PERSON
# 308) Pongo = PERSON
# 309) Jimmy Pongo = PERSON
# 310) Pongo = PERSON
# 311) Jimmy = PERSON
# 312) one = CARDINAL
# 313) Bridge = PERSON
# 314) Oswald = PERSON
# 315) Coote = PERSON
# 316) Gerald Wade = PERSON
# 317) Pongo = PERSON
# 318) Bill Eversleigh = PERSON
# 319) Ronny Devereux Say = PERSON
# 320) twelve = CARDINAL
# 321) three morning = TIME
# 322) night = TIME
# 323) Maria = PERSON
# 324) Oswald = PERSON
# 325) Coote = PERSON
# 326) Oswald = PERSON
# 327) Gerald Wade 's = PERSON
# 328) Four = CARDINAL
# 329) rubber = PERSON
# 330) four = CARDINAL
# 331) Lucky = PERSON
# 332) Gerald Wade = PERSON
# 333) Lucky = PERSON
# 334) Coote = PERSON
# 335) Maria = PERSON
# 336) Oswald = PERSON
# 337) Coote = PERSON
# 338) Gerald Wade = PERSON
# 339) Oswald = PERSON
# 340) Coote = PERSON
# 341) another ten shillings = MONEY
# 342) Oswald = PERSON
# 343) Oswald = PERSON
# 344) Seventeen hundred = MONEY
# 345) eight pounds = MONEY
# 346) Oswald = PERSON
# 347) Coote = PERSON
# 348) extra ten shilling = MONEY
# 349) ten shillings = MONEY
# 350) Oswald = PERSON
# 351) half past = TIME
# 352) Ronny Devereux = PERSON
# 353) Gerald Wade = PERSON
# 354) quarter two = TIME
# 355) Ronny = PERSON
# 356) One = CARDINAL
# 357) three = CARDINAL
# 358) Bill Eversleigh = PERSON
# 359) Jimmy Thesiger = PERSON
# 360) Ronny Devereux = PERSON
# 361) Rupert Bateman = PERSON
# 362) Pongo = PERSON
# 363) Jimmy = PERSON
# 364) Gerry = PERSON
# 365) Pongo = PERSON
# 366) Socks = PERSON
# 367) Jimmy Pongo = PERSON
# 368) two = CARDINAL
# 369) two = CARDINAL
# 370) two = CARDINAL
# 371) Gerald Wade = PERSON
# 372) Murgatroyd = PERSON
# 373) eight = CARDINAL
# 374) III = CARDINAL
# 375) Twelve o'clock = TIME
# 376) Socks = PERSON
# 377) Ronny Devereux = PERSON
# 378) day = DATE
# 379) Ronny = PERSON
# 593) Gerry Wade = PERSON
# 594) Bundle = PERSON
# 595) Bill = PERSON
# 596) Caterham = PERSON
# 597) Bundle = PERSON
# 598) Caterham = PERSON
# 599) Raglan = PERSON
# 600) Bundle = PERSON
# 601) Caterham = PERSON
# 602) Half = CARDINAL
# 603) Wade = PERSON
# 604) one = CARDINAL
# 605) Bundle = PERSON
# 606) Caterham = PERSON
# 607) Bundle = PERSON
# 608) MacDonald = PERSON
# 609) Bundle = PERSON
# 610) MacDonald = PERSON
# 611) Bundle = PERSON
# 612) verra grand = PERSON
# 613) MacDonald = PERSON
# 614) MacDonald = PERSON
# 615) William = PERSON
# 616) m'lady = PERSON
# 617) Bundle = PERSON
# 618) Bundle = PERSON
# 619) MacDonald = PERSON
# 620) Caterham = PERSON
# 621) MacDonald = PERSON
# 622) Cootes = PERSON
# 623) MacDonald = PERSON
# 624) one = CARDINAL
# 625) two = CARDINAL
# 626) Coote = PERSON
# 627) Caterham = PERSON
# 628) Siddons = PERSON
# 629) Tredwell = PERSON
# 630) Wade = PERSON
# 631) Bundle = PERSON
# 632) Tredwell = PERSON
# 633) Caterham = PERSON
# 634) Bundle = PERSON
# 635) Caterham = PERSON
# 636) Bundle = PERSON
# 637) Caterham = PERSON
# 638) half = CARDINAL
# 639) Tredwell = PERSON
# 640) Bundle = PERSON
# 641) Bundle = PERSON
# 642) Caterham = PERSON
# 643) Bundle = PERSON
# 644) Bundle = PERSON
# 645) Louisa = PERSON
# 646) Caterham = PERSON
# 647) Bundle = PERSON
# 648) evening = TIME
# 649) Gerry Wade = PERSON
# 650) Gerry Wade = PERSON
# 651) second = ORDINAL
# 652) Tredwell = PERSON
# 653) Caterham = PERSON
# 654) Bundle = PERSON
# 655) Seven = CARDINAL
# 656) Bundle = PERSON
# 657) one = CARDINAL
# 658) Gerry Wade = PERSON
# 659) first = ORDINAL
# 660) Bundle = PERSON
# 661) early hours = TIME
# 662) Bundle = PERSON
# 663) Bill Eversleigh = PERSON
# 664) Bundle = PERSON
# 665) Bundle = PERSON
# 666) DEAR BILL,-- = PERSON
# 667) half = CARDINAL
# 668) Bundle = PERSON
# 669) Bundle = PERSON
# 670) first = ORDINAL
# 671) first = ORDINAL
# 672) Bundle = PERSON
# 673) Sept. 21st = DATE
# 674) September 21st = DATE
# 675) Bundle = PERSON
# 676) The 22nd day = DATE
# 677) Gerry Wade = PERSON
# 678) evening = TIME
# 679) Bundle = PERSON
# 680) Wednesday = DATE
# 681) Seven Dials = ORG
# 682) Bundle = PERSON
# 683) Seven = CARDINAL
# 684) London = GPE
# 685) Seven = CARDINAL
# 686) two = CARDINAL
# 687) Gerry Wade = PERSON
# 688) Bundle = PERSON
# 689) Gerry Wade = PERSON
# 690) Bundle = PERSON
# 691) seven = CARDINAL
# 692) Bundle = PERSON
# 693) Caterham = PERSON
# 694) Hispano = GPE
# 695) yesterday = DATE
# 696) Caterham = PERSON
# 697) Caterham = PERSON
# 698) Tredwell = PERSON
# 699) morning = TIME
# 700) Tredwell = PERSON
# 701) Caterham = PERSON
# 702) four years ago = DATE
# 703) Caterham = PERSON
# 704) Bundle = PERSON
# 705) Caterham = PERSON
# 706) Bundle = PERSON
# 707) Caterham = PERSON
# 708) Hispano = GPE
# 709) Bundle = PERSON
# 710) Tredwell = PERSON
# 711) Boys Brigade = ORG
# 712) Caterham = PERSON
# 713) Caterham = PERSON
# 714) Tredwell = PERSON
# 715) Tredwell = PERSON
# 716) Bundle = PERSON
# 717) Klaxon = PERSON
# 718) Katie = PERSON
# 719) Bundle = PERSON
# 720) October = DATE
# 721) Bundle = PERSON
# 722) Gerald Wade 's = PERSON
# 723) Loraine Wade = PERSON
# 724) Deane Priory = PERSON
# 725) Bill Eversleigh = PERSON
# 726) morning = TIME
# 727) Hispano = PERSON
# 728) Bundle = PERSON
# 729) Hispano = PRODUCT
# 730) Mile mile = QUANTITY
# 731) Bundle = PERSON
# 732) Bundle = PERSON
# 733) Bundle = PERSON
# 734) Bundle = PERSON
# 735) half = CARDINAL
# 736) Bundle = PERSON
# 737) Seven = CARDINAL
# 738) Bundle = PERSON
# 739) Jimmy Thesiger = PERSON
# 740) Bundle = PERSON
# 741) first = ORDINAL
# 742) Hispano = PERSON
# 743) A couple miles = QUANTITY
# 744) Cassell = PERSON
# 745) Bundle = PERSON
# 746) Bundle = PERSON
# 747) Bundle = PERSON
# 748) Five minutes = TIME
# 749) ten minutes = TIME
# 750) quarter hour = TIME
# 751) twenty minutes = TIME
# 752) Cassell = PERSON
# 753) Bundle = PERSON
# 754) Bundle = PERSON
# 755) hedge = PERSON
# 756) pince nez = PERSON
# 757) one days = DATE
# 758) Bundle = PERSON
# 759) last three quarters hour = DATE
# 760) quite two minutes = TIME
# 761) Bundle = PERSON
# 762) Bundle = PERSON
# 763) Bundle = PERSON
# 764) Bundle = PERSON
# 765) Bundle = PERSON
# 766) Bundle = PERSON
# 767) Seven = CARDINAL
# 768) Cassell = PERSON
# 769) one = CARDINAL
# 770) Bundle = PERSON
# 771) Bundle = PERSON
# 772) Lads = PERSON
# 773) Lads = PERSON
# 774) Ronald Devereux = PERSON
# 775) Albany Bundle = PERSON
# 776) Ronald Devereux = PERSON
# 777) half = CARDINAL
# 778) Ronny Devereux = PERSON
# 779) Bill = PERSON
# 780) Foreign Office = ORG
# 781) Bill = PERSON
# 782) Gerald Wade = PERSON
# 783) Bundle = PERSON
# 784) First = ORDINAL
# 785) Gerald Wade = PERSON
# 786) Ronny Devereux = PERSON
# 787) Gerry Wade 's = PERSON
# 788) Ronny Devereux 's = PERSON
# 789) Bundle = PERSON
# 790) Seven = CARDINAL
# 791) Gerald Wade = PERSON
# 792) Seven = CARDINAL
# 793) night = TIME
# 794) Bundle = PERSON
# 795) Lord Caterham = PERSON
# 796) Bundle = PERSON
# 797) London = GPE
# 798) London = GPE
# 799) Bundle = PERSON
# 800) Caterham = PERSON
# 801) Bundle = PERSON
# 802) Caterham = PERSON
# 803) Bundle = PERSON
# 804) Caterham = PERSON
# 805) Caterham = PERSON
# 806) Bundle = PERSON
# 807) one = CARDINAL
# 808) Caterham = PERSON
# 809) East End = LOC
# 810) Seven = CARDINAL
# 811) Jimmy Thesiger = PERSON
# 812) Lord Caterham = PERSON
# 813) Seven Dials = WORK_OF_ART
# 814) Thesiger = PERSON
# 815) Thesiger = PERSON
# 816) One = CARDINAL
# 817) Caterham = PERSON
# 818) Yorkshire Thesigers = NORP
# 819) Devonshire Thesigers = PERSON
# 820) Selina = PERSON
# 821) Thesiger = PERSON
# 822) Bundle = PERSON
# 823) Caterham = PERSON
# 824) Bundle = PERSON
# 825) Bill Do = PERSON
# 826) Bundle = PERSON
# 827) Seven Dials = PERSON
# 828) Caterham = PERSON
# 829) Seven Dials = PERSON
# 830) George Lomax = PERSON
# 831) Tredwell = PERSON
# 832) Abbey = PERSON
# 833) next week = DATE
# 834) Seven = CARDINAL
# 835) Scotland Yard = ORG
# 836) George Bundle = PERSON
# 837) George Lomax = PERSON
# 838) State Foreign Affairs = ORG
# 839) Bill Eversleigh = PERSON
# 840) Gerald Wade 's = PERSON
# 841) Bundle = PERSON
# 842) Loraine Wade = PERSON
# 843) Gerald Wade = PERSON
# 844) Wade = PERSON
# 845) Gerry = PERSON
# 846) half = CARDINAL
# 847) Wade = PERSON
# 848) Wade = PERSON
# 849) second = ORDINAL
# 850) Wade = PERSON
# 851) Bundle = PERSON
# 852) Caterham = PERSON
# 853) Bundle = PERSON
# 854) First = ORDINAL
# 855) Jimmy Thesiger = PERSON
# 856) Bill = PERSON
# 857) Ronny Devereux = PERSON
# 858) Bill = PERSON
# 859) Jimmy Thesiger = PERSON
# 860) Ronny = PERSON
# 861) Bill = PERSON
# 862) Loraine Wade = PERSON
# 863) Seven = CARDINAL
# 864) Gerry Wade = PERSON
# 865) CHAPTER VII = EVENT
# 866) Bill = PERSON
# 867) morning = TIME
# 868) Bill = PERSON
# 869) day two = DATE
# 870) Bill = PERSON
# 871) Bill = PERSON
# 872) Bundle = PERSON
# 873) Bill = PERSON
# 874) Jimmy Thesiger = PERSON
# 875) Bundle = PERSON
# 876) Jimmy = PERSON
# 877) Bundle = PERSON
# 878) Jimmy = PERSON
# 879) Bundle = PERSON
# 880) Jimmy Thesiger = PERSON
# 881) Foreign Office = ORG
# 882) Bundle = PERSON
# 883) first = ORDINAL
# 884) Bill = PERSON
# 885) Ronny = PERSON
# 886) Ronny Devereux = PERSON
# 887) Thesiger = PERSON
# 888) Ronny-- = PERSON
# 889) Bundle = PERSON
# 890) Bill = PERSON
# 891) Bundle = PERSON
# 892) first = ORDINAL
# 893) morning = TIME
# 894) one = CARDINAL
# 895) one = CARDINAL
# 896) Bill = PERSON
# 897) Ronny = PERSON
# 898) week end = DATE
# 899) Gerry Wade = PERSON
# 900) Bundle = PERSON
# 901) Bill Ronny 's = PERSON
# 902) Bill = PERSON
# 903) Bill Hullo = PERSON
# 904) morrow night = TIME
# 905) Bundle = PERSON
# 906) Jimmy Thesiger 's = PERSON
# 907) Jimmy Thesiger = PERSON
# 908) Jermyn Street = FAC
# 909) Jermyn Street = FAC
# 910) one = CARDINAL
# 911) Jermyn Street = GPE
# 912) 103 = CARDINAL
# 913) Bill = PERSON
# 914) half hour = TIME
# 915) Sherlock = PERSON
# 916) one = CARDINAL
# 917) eleven = CARDINAL
# 918) every morning = TIME
# 919) morrow night = TIME
# 920) Bundle = PERSON
# 921) First = ORDINAL
# 922) five twenty minutes = TIME
# 923) twelve = DATE
# 924) Bill = PERSON
# 925) Thesiger = PERSON
# 926) London = GPE
# 927) one = CARDINAL
# 928) Bundle = PERSON
# 929) Bundle = PERSON
# 930) Thesiger = PERSON
# 931) morning = TIME
# 932) morning = TIME
# 933) Bundle = PERSON
# 934) morning = TIME
# 935) Bundle = PERSON
# 936) one = CARDINAL
# 937) Bundle = PERSON
# 938) Bundle = PERSON
# 939) second = ORDINAL
# 940) Bundle = PERSON
# 941) Loraine Wade = PERSON
# 942) Loraine = PERSON
# 943) Bundle = PERSON
# 944) yesterday = DATE
# 945) Bundle Brent = PERSON
# 946) Gerry = PERSON
# 947) Loraine = PERSON
# 948) Bundle = PERSON
# 949) Ronny Devereux = PERSON
# 950) Loraine = PERSON
# 951) day = DATE
# 952) Gerry = PERSON
# 953) two three = CARDINAL
# 954) Gerry = PERSON
# 955) Loraine = PERSON
# 956) Bundle = PERSON
# 957) day = DATE
# 958) Loraine = PERSON
# 959) weeks = DATE
# 960) Gerald = PERSON
# 961) Gerry = PERSON
# 962) Ronny = PERSON
# 963) Gerry = PERSON
# 964) Ronny = PERSON
# 965) Jimmy = PERSON
# 966) Ronny = PERSON
# 967) Bundle = PERSON
# 968) Seven = CARDINAL
# 969) Loraine = PERSON
# 970) Jimmy Thesiger = PERSON
# 971) JIMMY = PERSON
# 972) twenty minutes earlier = TIME
# 973) Jimmy Thesiger = PERSON
# 974) Jimmy = PERSON
# 975) Eh Stevens = PERSON
# 976) Jimmy = PERSON
# 977) Stevens = PERSON
# 978) Stevens = PERSON
# 979) Jimmy = PERSON
# 980) Jemima = PERSON
# 981) Jimmy Young = PERSON
# 982) Jimmy = PERSON
# 983) French = NORP
# 984) Stevens = PERSON
# 985) French = NORP
# 986) Stevens = PERSON
# 987) Stevens = PERSON
# 988) Jimmy = PERSON
# 989) Stevens = PERSON
# 990) Jimmy = PERSON
# 991) Stevens = PERSON
# 992) Morning Post = ORG
# 993) minutes = TIME
# 994) Jimmy = PERSON
# 995) Jimmy = PERSON
# 996) Stevens = PERSON
# 997) last night = TIME
# 998) five o'clock = TIME
# 999) Rule Britannia = PRODUCT
# 1000) Jimmy Rule Britannia = PERSON
# 1001) Rule Britannia = PRODUCT
# 1002) Mustard Cress = PRODUCT
# 1003) Stevens = PERSON
# 1004) Stevens = PERSON
# 1005) Two = CARDINAL
# 1006) Mustard Cress = PERSON
# 1007) day = DATE
# 1008) Jimmy = PERSON
# 1009) ten minutes = TIME
# 1010) first = ORDINAL
# 1011) Loraine = PERSON
# 1012) first = ORDINAL
# 1013) Eileen Brent Bundle = PERSON
# 1014) Bill Eversleigh = PERSON
# 1718) Alfred = PERSON
# 1719) Chimneys = FAC
# 1720) Alfred = PERSON
# 1721) three = CARDINAL
# 1722) four = CARDINAL
# 1723) Mosgorovsky = PERSON
# 1724) Chimneys = FAC
# 1725) one = CARDINAL
# 1726) Tredwell = PERSON
# 1727) Mosgorovsky = PERSON
# 1728) Bundle = PERSON
# 1729) Alfred = PERSON
# 1730) hundred pound = MONEY
# 1731) three = CARDINAL
# 1732) second = ORDINAL
# 1733) A hundred pounds = MONEY
# 1734) Bundle = PERSON
# 1735) Alfred = PERSON
# 1736) Chimneys = PERSON
# 1737) Mosgorovsky = PERSON
# 1738) Tredwell = PERSON
# 1739) Bundle = PERSON
# 1740) Mosgorovsky = PERSON
# 1741) Russian = NORP
# 1742) Bundle = PERSON
# 1743) A hundred pounds = MONEY
# 1744) Alfred Larger = PERSON
# 1745) Alfred = PERSON
# 1746) Alfred = PERSON
# 1747) Scotland Yard = ORG
# 1748) day = DATE
# 1749) yesterday = DATE
# 1750) Alfred = PERSON
# 1751) first = ORDINAL
# 1752) Bundle = PERSON
# 1753) Alfred = PERSON
# 1754) Alfred = PERSON
# 1755) Bundle = PERSON
# 1756) Alfred = PERSON
# 1757) Mosgorovsky = PERSON
# 1758) Bundle = PERSON
# 1759) one = CARDINAL
# 1760) Alfred = PERSON
# 1761) fourth = ORDINAL
# 1762) Bundle = PERSON
# 1763) Two = CARDINAL
# 1764) Alfred = PERSON
# 1765) one = CARDINAL
# 1766) Bundle = PERSON
# 1767) Alfred = PERSON
# 1768) first = ORDINAL
# 1769) seven = CARDINAL
# 1770) three = CARDINAL
# 1771) one = CARDINAL
# 1772) Bundle = PERSON
# 1773) Alfred = PERSON
# 1774) Mosgorovsky = PERSON
# 1775) Bundle = PERSON
# 1776) This morning = TIME
# 1777) Alfred = PERSON
# 1778) Next minute = TIME
# 1779) Alfred = PERSON
# 1780) Bundle = PERSON
# 1781) Alfred = PERSON
# 1782) Bundle = PERSON
# 1783) Alfred = PERSON
# 1784) Bundle = PERSON
# 1785) Alfred = PERSON
# 1786) Bundle = PERSON
# 1787) four inches = QUANTITY
# 1788) second = ORDINAL
# 1789) Bundle = PERSON
# 1790) Alfred = PERSON
# 1791) Bundle = PERSON
# 1792) Alfred = PERSON
# 1793) Mosgo = PERSON
# 1794) much midnight = TIME
# 1795) Alfred = PERSON
# 1796) Bundle = PERSON
# 1797) Alfred = PERSON
# 1798) Bundle = PERSON
# 1799) Alfred = PERSON
# 1800) Alfred = PERSON
# 1801) Bundle = PERSON
# 1802) Bundle = PERSON
# 1803) Mosgorovsky = PERSON
# 1804) Bundle = PERSON
# 1805) one = CARDINAL
# 1806) Alfred = PERSON
# 1807) Bundle = PERSON
# 1808) Alfred = PERSON
# 1809) Bundle = PERSON
# 1810) Alfred = PERSON
# 1811) Alfred = PERSON
# 1812) one = CARDINAL
# 1813) Bundle = PERSON
# 1814) morning = TIME
# 1815) Bundle = PERSON
# 1816) long hours = TIME
# 1817) SEVEN = CARDINAL
# 1818) next four hours = DATE
# 1819) Bundle = PERSON
# 1820) hours = TIME
# 1821) midnight = TIME
# 1822) 2 A.M. = TIME
# 1823) six o'clock morning = TIME
# 1824) another minute = TIME
# 1825) minute = TIME
# 1826) two = CARDINAL
# 1827) Bundle = PERSON
# 1828) another minute = TIME
# 1829) Bundle = PERSON
# 1830) one = CARDINAL
# 1831) night = TIME
# 1832) Alfred = PERSON
# 1833) Russian = NORP
# 1834) Mosgorovsky = PERSON
# 1835) Bundle = PERSON
# 1836) Russian = NORP
# 1837) minutes = TIME
# 1838) Bundle = PERSON
# 1839) two = CARDINAL
# 1840) six o'clock = TIME
# 1841) Bundle = PERSON
# 1842) seven = CARDINAL
# 1843) Mosgorovsky = PERSON
# 1844) Bundle = PERSON
# 1845) four o'clock five o'clock = TIME
# 1846) One = CARDINAL
# 1847) English = NORP
# 1848) Bundle = PERSON
# 1849) first = ORDINAL
# 1850) American = NORP
# 1851) Irish = NORP
# 1852) English = LANGUAGE
# 1853) night = TIME
# 1854) 4 = CARDINAL
# 1855) Bundle = PERSON
# 1856) French = NORP
# 1857) French = NORP
# 1858) Austrian = NORP
# 1859) Hungarian = NORP
# 1860) Russian = NORP
# 1861) American = NORP
# 1862) Bundle = PERSON
# 1863) One o'clock = TIME
# 1864) Five o'clock = TIME
# 1865) seven = CARDINAL
# 1866) Mosgorovsky = PERSON
# 1867) Russian = NORP
# 1868) Bundle = PERSON
# 1869) five o'clock = TIME
# 1870) third = ORDINAL
# 1871) Bundle = PERSON
# 1872) American = NORP
# 1873) 4 = CARDINAL
# 1874) two = CARDINAL
# 1875) two = CARDINAL
# 1876) second = ORDINAL
# 1877) one = CARDINAL
# 1878) Mosgorovsky = PERSON
# 1879) Bundle = PERSON
# 1880) Bundle = PERSON
# 1881) first = ORDINAL
# 1882) 7 = CARDINAL
# 1883) American = NORP
# 1884) seven o'clock--_I'm = TIME
# 1885) Russian = NORP
# 1886) Bundle = PERSON
# 1887) Bundle = PERSON
# 1888) Slavonic = NORP
# 1889) Russian = NORP
# 1890) First = ORDINAL
# 1891) 2 = CARDINAL
# 1892) 2 = CARDINAL
# 1893) night = TIME
# 1894) American = NORP
# 1895) five o'clock = TIME
# 1896) Russian = NORP
# 1897) Mosgorovsky = PERSON
# 1898) Anna = PERSON
# 1899) 7 = CARDINAL
# 1900) Russian = NORP
# 1901) Mosgorovsky = PERSON
# 1902) Mosgorovsky = PERSON
# 1903) 3 = CARDINAL
# 1904) Wyvern Abbey = ORG
# 1905) 3 = CARDINAL
# 1906) Englishman = NORP
# 1907) Mosgorovsky = PERSON
# 1908) Russian = NORP
# 1909) Stanley Digby = PERSON
# 1910) Terence O'Rourke = PERSON
# 1911) Oswald = PERSON
# 1912) Coote = PERSON
# 1913) Bateman = PERSON
# 1914) Anna Radzky = PERSON
# 1915) Macatta = PERSON
# 1916) James Thesiger-- = PERSON
# 1917) James Thesiger = PERSON
# 1918) American = NORP
# 1919) Russian = NORP
# 1920) Eberhard = PERSON
# 1921) Eversleigh = PERSON
# 2022) American = NORP
# 2023) Russian = NORP
# 2024) Jimmy = PERSON
# 2025) minute = TIME
# 2026) two = CARDINAL
# 2027) German = NORP
# 2028) Eberhard = PERSON
# 2029) Eberhard = PERSON
# 2030) Eberhard = PERSON
# 2031) Eberhard = PERSON
# 2032) Johnny = PERSON
# 2033) Eberhard = PERSON
# 2034) German = NORP
# 2035) lamb = PERSON
# 2036) Jimmy Eberhard = PERSON
# 2037) Oswald Coote = PERSON
# 2038) Oswald George = PERSON
# 2039) Eberhard Eberhard = PERSON
# 2040) Jimmy = PERSON
# 2041) Russian = NORP
# 2042) millions = CARDINAL
# 2043) Jimmy = PERSON
# 2044) Jimmy = PERSON
# 2045) Bundle = PERSON
# 2046) Ronny = PERSON
# 2047) Bundle = PERSON
# 2048) Seven = CARDINAL
# 2049) Jimmy Thesiger = PERSON
# 2050) Jimmy = PERSON
# 2051) one = CARDINAL
# 2052) Bauer = PERSON
# 2053) Gerry = PERSON
# 2054) Bundle = PERSON
# 2055) Jimmy = PERSON
# 2056) Loraine Wade = PERSON
# 2057) Jimmy = PERSON
# 2058) morning = TIME
# 2059) Bundle = PERSON
# 2060) Bundle = PERSON
# 2061) 5 = CARDINAL
# 2062) Bundle = PERSON
# 2063) Jimmy = PERSON
# 2064) George Lomax = PERSON
# 2065) Bundle = PERSON
# 2066) Jimmy = PERSON
# 2067) 7 = CARDINAL
# 2068) Jimmy = PERSON
# 2069) George Lomax = PERSON
# 2070) Bundle = PERSON
# 2071) Codders-- = PERSON
# 2072) Codders = PERSON
# 2073) Jimmy = PERSON
# 2074) Melrose = PERSON
# 2075) Jimmy = PERSON
# 2076) three = CARDINAL
# 2077) Melrose = PERSON
# 2078) Bundle = PERSON
# 2079) Melrose = PERSON
# 2080) Bundle = PERSON
# 2081) Chimneys = PRODUCT
# 2082) Jimmy Thesiger = PERSON
# 2083) London = GPE
# 2084) Bundle = PERSON
# 2085) Ronny = PERSON
# 2086) Loraine = PERSON
# 2087) minute two 's = TIME
# 2088) Jimmy = PERSON
# 2089) Loraine-- = PERSON
# 2090) Jimmy = PERSON
# 2091) nine = CARDINAL
# 2092) minute = TIME
# 2093) two = CARDINAL
# 2094) Stevens = PERSON
# 2095) Stevens = PERSON
# 2096) Stevens = PERSON
# 2097) Jimmy = PERSON
# 2098) American = NORP
# 2099) Stevens = PERSON
# 2100) American = NORP
# 2101) Jimmy Thesiger = PERSON
# 2102) CHAPTER XVI = PERSON
# 2103) Wyvern Abbey = FAC
# 2104) Friday = DATE
# 2105) George Lomax = PERSON
# 2106) Eileen = PERSON
# 2107) Caterham = PERSON
# 2108) Bundle = PERSON
# 2109) Macatta = PERSON
# 2110) George She = PERSON
# ...
# 3749) Caterham = PERSON
# 3750) George = PERSON
# 3751) Caterham = PERSON
# 3752) Eileen = PERSON
# 3753) Caterham = PERSON
# 3754) Bundle = PERSON
# 3755) Wade = PERSON
# 3756) George = PERSON
# 3757) Eileen = PERSON
# 3758) Caterham = PERSON
# 3759) George = PERSON
# 3760) Caterham = PERSON
# 3761) Eileen = PERSON
# 3762) Caterham = PERSON
# 3763) one = CARDINAL
# 3764) two = QUANTITY
# 3765) Eileen = PERSON
# 3766) Caterham = PERSON
# 3767) Caterham = PERSON
# 3768) George = PERSON
# 3769) Bundle = PERSON
# 3770) Lord Caterham = PERSON
# 3771) George = PERSON
# 3772) Caterham = ORG
# 3773) Eileen = PERSON
# 3774) Caterham = ORG
# 3775) Eileen = PERSON
# 3776) Caterham = PERSON
# 3777) Caterham = PERSON
# 3778) Caterham = PERSON
# 3779) Lomax = PERSON
# 3780) twenty = CARDINAL
# 3781) Caterham = PERSON
# 3782) Eileen = PERSON
# 3783) Caterham = PERSON
# 3784) Eileen = PERSON
# 3785) morrow = DATE
# 3786) George = PERSON
# 3787) Caterham = PERSON
# 3788) two minutes = TIME
# 3789) Wade = PERSON
# 3790) Caterham = PERSON
# 3791) Caterham = PERSON
# 3792) Tredwell = PERSON
# 3793) Lomax = PERSON
# 3794) Tredwell = PERSON
# 3795) George = PERSON
# 3796) Caterham = PERSON
# 3797) A thousand = CARDINAL
# 3798) Caterham = PERSON
# 3799) Eversleigh = PERSON
# 3800) Bill = PERSON
# 3801) Caterham = PERSON
# 3802) Hullo = PERSON
# 3803) Bill = PERSON
# 3804) Lomax = PERSON
# 3805) Cabinet = ORG
# 3806) Bill = PERSON
# 3807) Caterham = PERSON
# 3808) George = PERSON
# 3809) Caterham = PERSON
# 3810) Caterham = PERSON
# 3811) Bill = PERSON
# 3812) Lomax = PERSON
# 3813) Lomax = PERSON
# 3814) Hush = PERSON
# 3815) Caterham = PERSON
# 3816) Bundle = PERSON
# 3817) Bundle = PERSON
# 3818) Bill = PERSON
# 3819) Caterham = PERSON
# 3820) Bill = PERSON
# 3821) Caterham = PERSON
# 3822) five years younger = DATE
# 3823) Bundle = PERSON
# 3824) Bundle = PERSON
# 3825) Caterham = PERSON
# 3826) Caterham = PERSON
# 3827) Bundle Bundle = PERSON
# 3828) Bundle = PERSON
# 3829) George = PERSON
# 3830) Caterham = PERSON
# 3831) God = PERSON
# 3832) Bill = PERSON
# 3833) Bundle = PERSON
# 3834) Jimmy Thesiger = PERSON
# 3835) Cootes = PERSON
# 3836) yesterday = DATE
# 3837) Loraine = PERSON
# 3838) Saturday = DATE
# 3839) Bill = PERSON
# 3840) Caterham = PERSON
# 3841) Bill = PERSON
# 3842) Bill = PERSON
# 3843) London = GPE
# 3844) St. James 's Square = FAC
# 3845) Jimmy Thesiger 's = PERSON
# 3846) Jimmy = PERSON
# 3847) Hullo = GPE
# 3848) Bill = PERSON
# 3849) Jimmy = PERSON
# 3850) Bill = PERSON
# 3851) Jimmy = PERSON
# 3852) William = PERSON
# 3853) Seven = CARDINAL
# 3854) Seven = CARDINAL
# 3855) Ronny Devereux 's = PERSON
# 3856) exactly fortnight = DATE
# 3857) Bill = PERSON
# 3858) Jimmy = PERSON
# 3859) Bill = PERSON
# 3860) Jimmy = PERSON
# 3861) six = CARDINAL
# 3862) Stevens = PERSON
# 3863) Jimmy = PERSON
# 3864) Bill = PERSON
# 3865) Jimmy = PERSON
# 3866) Stevens = PERSON
# 3867) Bill = PERSON
# 3868) XXX = CARDINAL
# 3869) Loraine = PERSON
# 3870) Bundle = PERSON
# 3871) twenty minutes = TIME
# 3872) Bundle = PERSON
# 3873) Loraine = PERSON
# 3874) George = PERSON
# 3875) George Lomax = PERSON
# 3876) George = PERSON
# 3877) Bundle = PERSON
# 3878) George = PERSON
# 3879) George = PERSON
# 3880) George = PERSON
# 3881) one quarter going = DATE
# 3882) Loraine = PERSON
# 3883) Hallo = PERSON
# 3884) Caterham = PERSON
# 3885) Lomax = PERSON
# 3886) Bundle = PERSON
# 3887) George = PERSON
# 3888) Caterham = PERSON
# 3889) Bundle = PERSON
# 3890) George = PERSON
# 3891) Bundle = PERSON
# 3892) Caterham = PERSON
# 3893) Lomax = PERSON
# 3894) two = CARDINAL
# 3895) Bundle = PERSON
# 3896) Loraine = PERSON
# 3897) An hour = TIME
# 3898) three = CARDINAL
# 3899) Lomax = PERSON
# 3900) Tredwell = PERSON
# 3901) Caterham = PERSON
# 3902) Tredwell = PERSON
# 3903) Bundle = PERSON
# 3904) Bundle = PERSON
# 3905) CATERHAM-- = PERSON
# 3906) Eileen = PERSON
# 3907) Caterham = PERSON
# 3908) GEORGE LOMAX = PERSON
# 3909) Bundle = PERSON
# 3910) Caterham = PERSON
# 3911) Bundle = PERSON
# 3912) Cabinet = PERSON
# 3913) Bundle = PERSON
# 3914) Bundle = PERSON
# 3915) another minute = TIME
# 3916) George = PERSON
# 3917) Loraine Lord Caterham = PERSON
# 3918) Jimmy = PERSON
# 3919) Bundle = PERSON
# 3920) Jimmy = PERSON
# 3921) Loraine = PERSON
# 3922) Bill = PERSON
# 3923) Seven = CARDINAL
# 3924) Alfred Rather = PERSON
# 3925) Bill = PERSON
# 3926) Loraine = PERSON
# 3927) Splendidly = PERSON
# 3928) Jimmy = PERSON
# 3929) Bundle = PERSON
# 3930) Loraine = PERSON
# 3931) Loraine = PERSON
# 3932) Bundle = PERSON
# 3933) Loraine = PERSON
# 3934) Bundle = PERSON
# 3935) Bundle = PERSON
# 3936) Bundle = PERSON
# 3937) Hispano = PERSON
# 3938) London = GPE
# 3939) Bundle = PERSON
# 3940) Seven = CARDINAL
# 3941) Alfred Bundle = PERSON
# 3942) Loraine = PERSON
# 3943) Alfred = PERSON
# 3944) Bundle = PERSON
# 3945) Alfred = PERSON
# 3946) night = TIME
# 3947) Bundle = PERSON
# 3948) Mosgorovsky = PERSON
# 3949) ten pounds = MONEY
# 3950) three minutes = TIME
# 3951) Alfred = PERSON
# 3952) one = CARDINAL
# 3953) Bundle = PERSON
# 3954) Loraine = PERSON
# 3955) Bundle = PERSON
# 3956) Jimmy Bill = PERSON
# 3957) Alfred = PERSON
# 3958) Hallo = PERSON
# 3959) Alfred = PERSON
# 3960) Loraine Loraine = PERSON
# 3961) Jimmy Thesiger = PERSON
# 3962) Bill = PERSON
# 3963) Hallo = PERSON
# 3964) Bundle = PERSON
# 3965) one = CARDINAL
# 3966) three = CARDINAL
# 3967) Bundle = PERSON
# 3968) seven = CARDINAL
# 3969) Jimmy = PERSON
# 3970) minute two = DATE
# 3971) two = CARDINAL
# 3972) Bundle = PERSON
# 3973) Jimmy = PERSON
# 3974) Bill Loraine = PERSON
# 3975) Loraine = PERSON
# 3976) Bundle = PERSON
# 3977) Jimmy = PERSON
# 3978) Bill = PERSON
# 3979) Hallo = PERSON
# 3980) Loraine = PERSON
# 3981) Loraine = PERSON
# 3982) Bill = PERSON
# 3983) Bill = PERSON
# 3984) Bill = PERSON
# 3985) Bill = PERSON
# 3986) Jimmy = PERSON
# 3987) Loraine = PERSON
# 3988) Loraine = PERSON
# 3989) Bill = PERSON
# 3990) Jimmy = PERSON
# 3991) Bill = PERSON
# 3992) Jimmy = PERSON
# 3993) Loraine = PERSON
# 3994) Jimmy = PERSON
# 3995) Bill = PERSON
# 3996) Jimmy = PERSON
# 3997) Jimmy = PERSON
# 3998) Cheer = PERSON
# 3999) three = CARDINAL
# 4000) Bill = PERSON
# 4001) Genneman = PERSON
# 4002) Jimmy = PERSON
# 4003) Bundle = PERSON
# 4004) Jimmy = PERSON
# 4005) one = CARDINAL
# 4006) two = CARDINAL
# 4007) Bill Bundle = PERSON
# 4008) Loraine = PERSON
# 4009) Loraine = PERSON
# 4010) ages = DATE
# 4011) Jimmy = PERSON
# 4012) minute half = TIME
# 4013) Bundle = PERSON
# 4014) Jimmy = PERSON
# 4015) Loraine = PERSON
# 4016) Bundle = PERSON
# 4017) Loraine = PERSON
# 4018) Bundle = PERSON
# 4019) Bill = PERSON
# 4020) Loraine = PERSON
# 4021) Bundle = PERSON
# 4022) Loraine = PERSON
# 4023) Bundle = PERSON
# 4024) Bundle = PERSON
# 4025) Bundle = PERSON
# 4026) Bundle = PERSON
# 4027) Bundle = PERSON
# 4028) Bundle = PERSON
# 4029) Bundle = PERSON
# 4030) Bundle = PERSON
# 4031) Bundle = PERSON
# 4032) Bundle = PERSON
# 4033) Bundle = PERSON
# 4034) Bill = PERSON
# 4035) Bundle = PERSON
# 4036) Bundle = PERSON
# 4037) Bundle = PERSON
# 4038) Bundle = PERSON
# 4039) Bundle = PERSON
# 4040) Bundle = PERSON
# 4041) Bundle = PERSON
# 4042) Bill = PERSON
# 4043) Bundle = PERSON
# 4044) About five minutes ago = TIME
# 4045) Bill = PERSON
# 4046) Bundle = PERSON
# 4047) Bundle = PERSON
# 4048) George Lomax = PERSON
# 4049) Bundle = PERSON
# 4050) Codders = PERSON
# 4051) Bill = PERSON
# 4052) Bill = PERSON
# 4053) Bundle = PERSON
# 4054) Marry = PERSON
# 4055) Bundle = PERSON
# 4056) Bundle = PERSON
# 4057) Bill = PERSON
# 4058) Bill = PERSON
# 4059) Bundle = PERSON
# 4060) Bundle = PERSON
# 4061) Bundle = PERSON
# 4062) Bill = PERSON
# 4063) Bundle = PERSON
# 4064) Bill = PERSON
# 4065) Bundle = PERSON
# 4066) next ten minutes = TIME
# 4067) Bill = PERSON
# 4068) twentieth = ORDINAL
# 4069) first = ORDINAL
# 4070) Bundle = PERSON
# 4071) Bundle = PERSON
# 4072) Bill = PERSON
# 4073) Bill = PERSON
# 4074) Bundle = PERSON
# 4075) Bill = PERSON
# 4076) Bundle = PERSON
# 4077) Bill = PERSON
# 4078) Bundle = PERSON
# 4079) Bill = PERSON
# 4080) Bundle = PERSON
# 4081) Bill = PERSON
# 4082) Bill = PERSON
# 4083) another half hour = TIME
# 4084) Bill = PERSON
# 4085) Bundle = PERSON
# 4086) Bundle = PERSON
# 4087) Jimmy = PERSON
# 4088) Mosgorovsky = PERSON
# 4089) Bill = PERSON
# 4090) Bundle = PERSON
# 4091) Russian = NORP
# 4092) minute = TIME
# 4093) Bundle = PERSON
# 4094) Bill = PERSON
# 4095) Bundle = PERSON
# 4096) Bill = PERSON
# 4097) Bundle = PERSON
# 4098) Bill = PERSON
# 4099) sleeve = PERSON
# 4100) Russian = NORP
# 4101) Alfred = PERSON
# 4102) Mosgorovsky = PERSON
# 4103) Bundle = PERSON
# 4104) Bill = PERSON
# 4105) Bundle = PERSON
# 4106) Russian = NORP
# 4107) Mosgorovsky = PERSON
# 4108) Eileen Brent = PERSON
# 4109) Seven = CARDINAL
# 4110) Bundle = PERSON
# 4111) Bundle = PERSON
# 4112) second = ORDINAL
# 4113) first = ORDINAL
# 4114) Mosgorovsky = PERSON
# 4115) 7 = CARDINAL
# 4116) Bundle = PERSON
# 4117) Bundle = PERSON
# 4118) Mosgorovsky = PERSON
# 4119) Lady Eileen = PERSON
# 4120) 2 o'clock = TIME
# 4121) Bundle = PERSON
# 4122) Bundle Brent = PERSON
# 4123) Bill = PERSON
# 4124) Mosgorovsky = PERSON
# 4125) Eileen = PERSON
# 4126) Bundle = PERSON
# 4127) 7 o'clock = TIME
# 4128) Bundle = PERSON
# 4129) 7 = CARDINAL
# 4130) Bundle = PERSON
# 4131) Bundle = PERSON
# 4132) Battle = PERSON
# 4133) BUNDLE = PERSON
# 4134) Battle = PERSON
# 4135) Mosgorovsky = PERSON
# 4136) Bundle = PERSON
# 4137) Bundle = PERSON
# 4138) Battle = PERSON
# 4139) Eileen = PERSON
# 4140) Mosgorovsky = PERSON
# 4141) Bundle = PERSON
# 4142) Battle = PERSON
# 4143) two = CARDINAL
# 4144) Eileen = PERSON
# 4145) Eileen = PERSON
# 4146) Department = ORG
# 4147) First = ORDINAL
# 4148) First = ORDINAL
# 4149) Mosgorovsky = PERSON
# 4150) England = GPE
# 4151) Andras = PERSON
# 4152) Hungarian Embassy = ORG
# 4153) Gerald Wade = PERSON
# 4154) Hayward Phelps = PERSON
# 4155) American = NORP
# 4156) British = NORP
# 4157) 3 = CARDINAL
# 4158) Bundle = PERSON
# 4159) Bill Eversleigh = PERSON
# 4160) 2 = CARDINAL
# 4161) Battle = PERSON
# 4162) Ronald Devereux = PERSON
# 4163) 1 = CARDINAL
# 4164) 1 = CARDINAL
# 4165) Gerald Wade = PERSON
# 4166) 1 = CARDINAL
# 4368) Wade = PERSON
# 4369) London = GPE
# 4370) Eversleigh = PERSON
# 4371) two = CARDINAL
# 4372) Jermyn Street = FAC
# 4373) one = CARDINAL
# 4374) two = CARDINAL
# 4375) Thesiger = PERSON
# 4376) minutes = DATE
# 4377) Eversleigh = PERSON
# 4378) Seven = CARDINAL
# 4379) Alfred = PERSON
# 4380) Eversleigh = PERSON
# 4381) Wade = PERSON
# 4382) Eversleigh = PERSON
# 4383) Thesiger = PERSON
# 4384) Bill = PERSON
# 4385) Bill = PERSON
# 4386) Loraine = PERSON
# 4387) Thesiger = PERSON
# 4388) Loraine = PERSON
# 4389) Loraine = PERSON
# 4390) Jimmy = PERSON
# 4391) Bundle = PERSON
# 4392) Bundle = PERSON
# 4393) Battle = PERSON
# 4394) Thesiger = PERSON
# 4395) half = CARDINAL
# 4396) Still = PERSON
# 4397) Eileen = PERSON
# 4398) Bundle = PERSON
# 4399) Loraine = PERSON
# 4400) So Pentonville = PERSON
# 4401) five = CARDINAL
# 4402) Battle = PERSON
# 4403) Thesiger = PERSON
# 4404) Eileen = PERSON
# 4405) Bundle = PERSON
# 4406) Battle = PERSON
# 4407) Seven = CARDINAL
# 4408) Bill Hurrah = PERSON
# 4409) Battle = PERSON
# 4410) Battle = PERSON
# 4411) Bundle = PERSON
# 4412) Bill = PERSON
# 4413) CATERHAM = PERSON
# 4414) Bundle = PERSON
# 4415) Caterham = PERSON
# 4416) Bundle = PERSON
# 4417) Caterham = PERSON
# 4418) Lomax = PERSON
# 4419) Bundle = PERSON
# 4420) Yesterday morning = TIME
# 4421) hundred = CARDINAL
# 4422) George = PERSON
# 4423) Bundle = PERSON
# 4424) Caterham = PERSON
# 4425) Bundle = PERSON
# 4426) Thesiger = PERSON
# 4427) one = CARDINAL
# 4428) day = PERSON
# 4429) Bundle = PERSON
# 4430) Caterham = PERSON
# 4431) day = DATE
# 4432) half hour = TIME
# 4433) every day = DATE
# 4434) Caterham = PERSON
# 4435) Bundle = PERSON
# 4436) Caterham = PERSON
# 4437) Bundle = PERSON
# 4438) Bundle = PERSON
# 4439) Bill Eversleigh = PERSON
# The frequencies of unique named entity labels: {'CARDINAL': 381, 'PERSON': 3399, 'ORG': 55, 'DATE': 103, 'WORK_OF_ART': 6, 'GPE': 52, 'TIME': 210, 'ORDINAL': 77, 'NORP': 89, 'MONEY': 9, 'QUANTITY': 13, 'FAC': 18, 'PRODUCT': 9, 'LOC': 8, 'EVENT': 5, 'LAW': 1, 'LANGUAGE': 4}

# %%
from spacy import displacy
displacy.render(processed_book_1, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Seven Dials Mystery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agatha Christie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  PRINTING HISTORY _
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dodd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  edition published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 1929
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grosset &amp; Dunlap
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  edition published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 1930
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American Mercury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  edition published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 1942
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bantam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  edition
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     /January 1964
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _New
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bantam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  edition/
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 1976
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Agatha Christie Mystery Collection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# /
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 1986
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# _ _All rights reserved._ _Copyright
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1929
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dodd, Mead &amp; Company, Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# _ _Copyright renewed ©
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1957
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agatha Christie Mallowan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ._ PRINTED IN
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     THE UNITED STATES OF AMERICA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  CONTENTS I ON EARLY RISING
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  CONCERNING ALARUM CLOCKS
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     III
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  THE JOKE THAT FAILED IV A LETTER V THE MAN IN THE ROAD VI SEVEN DIALS AGAIN VII BUNDLE PAYS A CALL VIII VISITORS FOR JIMMY IX PLANS X BUNDLE VISITS
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SCOTLAND
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  YARD XI DINNER WITH BILL XII INQUIRIES AT CHIMNEYS XIII THE SEVEN DIALS CLUB XIV THE MEETING OF THE SEVEN DIALS XV THE INQUEST
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XVI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-l

# %% [markdown]
# NER on text out of lemmatised tokens withouth punctuation and stopwords

# %%
book_1_from_clean_lemmatised_tokens = " ".join(clean_lemmatised_tokens)
print(book_1_from_clean_lemmatised_tokens[:100])

# %%
ner_list = []

i = 1
entities_list = []
entities_freq_dict = {}

for ent in nlp(book_1_from_clean_tokens).ents:
    print(f'{i}) {ent.text} = {ent.label_}')
    i += 1
    entities_list.append(ent.label_)

for ent_label in entities_list:
  if ent_label not in entities_freq_dict:
    entities_freq_dict[ent_label] = 0
  entities_freq_dict[ent_label] += 1

print(f'The list of unique named entity labels: {entities_list}')
print(f'The frequencies of unique named entity labels: {entities_freq_dict}')

# %% [markdown]
# Inside:

# %% [markdown]
# ## 4. Cleaning and Preprocessing All Books

# %%
# functions for preprocessing
import spacy
nlp = spacy.load("en_core_web_trf")


def truecase_text(text):
    doc = nlp(text)
    truecased_tokens = []
    for token in doc:
        if token.ent_type_ in ["PERSON", "GPE", "ORG"]:  # Named Entities should be capitalized
            truecased_tokens.append(token.text.title())
        elif token.is_sent_start:  # Capitalize the first word of each sentence
            truecased_tokens.append(token.text.capitalize())
        else:
            truecased_tokens.append(token.text.lower())

    return " ".join(truecased_tokens)


def preprocess_book(book, stop_words, punctuation, lemmatisation = False):
  book_tokens = []
  clean_book_tokens = []
  processed_book = nlp(book)
  for token in processed_book:
    if lemmatisation == True:
       book_tokens.append(token.lemma_)
    else:
      book_tokens.append(token.text)
      for token in book_tokens:
      if token in punctuation or token in stop_words:
        continue
      else:
        clean_book_tokens.append(token)
  return clean_book_tokens

# %%
book_1 = final_db[0]

print(book_1)

# %%
book_id_to_extract = 1
book_mask = df['book_id'] == book_id_to_extract
one_book_df = df[book_mask]
print(one_book_df)

# %%
import nltk
import string
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)

#preprocessing 1 book
preprocessed_book_1 = preprocess_book(book_1, stop_words, punctuation, lemmatisation = False)
print(preprocessed_book_1[:100])

preprocessed_book_1_lemma = preprocess_book(book, stop_words, punctuation, lemmatisation = True)
print(preprocessed_book_1_lemma[:100]

# %%
#preprocessing each book

# %% [markdown]
# ##Creating an Inverted Index and Storimg it as a 'pickle' file

# %% [markdown]
# Inv Index: https://www.geeksforgeeks.org/inverted-index/
#
# File: https://docs.python.org/3/library/pickle.html#module-pickle

# %%
# Define the documents
document1 = "The quick brown fox jumped over the lazy dog."
document2 = "The lazy dog slept in the sun."

# Step 1: Tokenize the documents
# Convert each document to lowercase and split it into words
tokens1 = document1.lower().split()
tokens2 = document2.lower().split()

# Combine the tokens into a list of unique terms
terms = list(set(tokens1 + tokens2))

# Step 2: Build the inverted index
# Create an empty dictionary to store the inverted index
inverted_index = {}

# For each term, find the documents that contain it
for term in terms:
    documents = []
    if term in tokens1:
        documents.append("Document 1")
    if term in tokens2:
        documents.append("Document 2")
    inverted_index[term] = documents

# Step 3: Print the inverted index
for term, documents in inverted_index.items():
    print(term, "->", ", ".join(documents))

# %%
# Create a list where each element is the 'paragraph_text' from each row
documents = df['paragraph_text'].tolist()

all_tokens = [doc.lower().split() for doc in documents]
all_tokens = [process_book(doc, st) for doc in documents]

terms = set()
for tokens in all_tokens:
    terms.update(tokens)
terms = list(terms)

inverted_index = {}

for term in terms:
    document_ids = []
    for index, tokens in enumerate(all_tokens):
       if term in tokens:
          book_id = final_df.iloc[index]['book_id']
          chapter_id = df.iloc[index]['chapter_id']
          paragraph_id = df.iloc[index]['paragraph_id']
          document_identifier = f"Book {book_id}, Chapter {chapter_id}, Paragraph {paragraph_id}"
          document_ids.append(document_identifier)
       inverted_index[term] = list(set(document_ids)

# %%
i = 10
for term, document_ids in inverted_index.items():
    if i <= 10:
       print(term, "->", ", ".join(document_ids))
    else:
       break

# %%
#storing inverted index in a pickle file

import pickle

# Specify the filename for your pickle file
filename = "inverted_index.pkl"

# Step 1: Open the file in binary write mode ('wb')
with open(filename, 'wb') as f:
    # Step 2: Use pickle.dump() to serialize the inverted index to the file
    pickle.dump(inverted_index, f)

print(f"Inverted index has been successfully saved to '{filename}'")

# To load the inverted index back from the pickle file:

# Step 1: Open the file in binary read mode ('rb')
with open(filename, 'rb') as f:
    # Step 2: Use pickle.load() to deserialize the object from the file
    loaded_inverted_index = pickle.load(f)

print("\nInverted index loaded from the pickle file:")
print(loaded_inverted_index)
print(type(loaded_inverted_index))

# %% [markdown]
# ##Creating a database in SQLite

# %% [markdown]
# https://docs.python.org/3/library/sqlite3.html

# %%
import pandas as pd
import sqlite3

# Sample DataFrame
data = {'col1': [1, 2, 3], 'col2': ['a', 'b', 'c']}
df = pd.DataFrame(data)

# 1. Establish a connection to the SQLite database
#    - If the database file doesn't exist, it will be created.
conn = sqlite3.connect('my_database.db')

# 2. Write the DataFrame to the SQLite table
#    - 'my_table' is the name of the table you want to create in the database.
#    - 'conn' is the database connection object.
#    - 'if_exists' specifies how to handle the table if it already exists:
#      - 'fail': Raise a ValueError.
#      - 'replace': Drop the table before inserting new values.
#      - 'append': Add new values to the existing table.
#    - 'index' determines whether to write the DataFrame index as a column in the table (True/False).
df.to_sql('my_table', conn, if_exists='replace', index=False)

# 3. Close the database connection
conn.close()

print("DataFrame successfully written to my_database.db in the table 'my_table'.")

# %%
import pandas as pd
import sqlite3

# Establish a connection to the SQLite database
conn = sqlite3.connect('my_database.db')

# SQL query to retrieve all data from the 'my_table'
query = "SELECT * FROM my_table"

# Read the data into a pandas DataFrame
df_from_sql = pd.read_sql_query(query, conn)

# Close the database connection
conn.close()

print(df_from_sql)

# %% [markdown]
# ##Creating a Vector Database with SQLite-Vec

# %%
# !pip install sqlite_vec

# %%
import sqlite3
import sqlite_vec  # If installed via pip

# Or if you downloaded the library:
# conn.enable_load_extension(True)
# conn.load_extension("./path/to/libsqlitevec.so") # Adjust the path

conn = sqlite3.connect("your_database.db")
conn.enable_load_extension(True)
sqlite_vec.load(conn) # More convenient if installed via pip
cursor = conn.cursor()

# %%
CREATE TABLE IF NOT EXISTS vectors (
    id INTEGER PRIMARY KEY,
    original_id INTEGER, -- Link to your original data
    embedding VECTOR(your_vector_dimension) -- Specify the dimensionality of your vectors
);

# %%
# Assuming you have a list of original IDs and their corresponding embeddings
data_to_insert = [(1, [0.1, 0.2, ..., 0.9]), (2, [0.5, 0.3, ..., 0.1])] # Example

cursor = conn.cursor()
cursor.executemany("INSERT INTO vectors (original_id, embedding) VALUES (?, ?)", data_to_insert)
conn.commit()

# %%
-- Create an HNSW index
CREATE INDEX IF NOT EXISTS vectors_hnsw ON vectors(embedding USING hnsw(32, 2));
